# %% [markdown]
# # BRIDGET: Compas test

# %% [markdown]
# ## Dataset Preprocessing

# %% [markdown]
# ### Libraries, Retrieving data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import yaml
import joblib

import pickle

import copy


import pandas as pd



from river import tree

from river import preprocessing
from river import ensemble, forest, compose


from sklearn.preprocessing import MinMaxScaler
from bridget_utils import *
from orchestrator import *
from master_config import *
from classes import BetaUser
from bridget_main import BRIDGET, HiC, MiC

"""
from baselines.compare_confidence import *
from baselines.differentiable_triage import *
from baselines.lce_surrogate import *
from baselines.mix_of_exps import *
from baselines.one_v_all import *
from baselines.selective_prediction import *
"""
# Out:
# 26-Apr-14 19:25:14 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.
# '\nfrom baselines.compare_confidence import *\nfrom baselines.differentiable_triage import *\nfrom baselines.lce_surrogate import *\nfrom baselines.mix_of_exps import *\nfrom baselines.one_v_all import *\nfrom baselines.selective_prediction import *\n'

# %%
set_all_seeds(42)

# %%
ds_name= 'compas'

# %%
data= pd.read_csv(fr".\datasets\{ds_name}.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 14788 entries, 0 to 14787
# Data columns (total 10 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sex              14788 non-null  object
#  1   age              14788 non-null  int64
#  2   race             14788 non-null  object
#  3   juv_fel_count    14788 non-null  int64
#  4   juv_misd_count   14788 non-null  int64
#  5   juv_other_count  14788 non-null  int64
#  6   priors_count     14788 non-null  int64
#  7   c_charge_degree  14788 non-null  object
#  8   compas_score     14788 non-null  int64
#  9   did_recid        14788 non-null  int64
# dtypes: int64(7), object(3)
# memory usage: 1.1+ MB

# %%
for c in data:
    print(data[c].value_counts().sum)
# Out:
# <bound method Series.sum of sex
# Male      12093
# Female     2695
# Name: count, dtype: int64>
# <bound method Series.sum of age
# 22    780
# 21    762
# 26    741
# 24    738
# 25    724
#      ...
# 96      2
# 78      1
# 83      1
# 80      1
# 79      1
# Name: count, Length: 65, dtype: int64>
# <bound method Series.sum of race
# African-American    8004
# Caucasian           4848
# Hispanic            1083
# Other                763
# Asian                 57
# Native American       33
# Name: count, dtype: int64>
# <bound method Series.sum of juv_fel_count
# 0     14176
# 1       390
# 2       135
# 3        46
# 4        19
# 5         9
# 8         4
# 10        4
# 6         3
# 20        1
# 13        1
# Name: count, dtype: int64>
# <bound method Series.sum of juv_misd_count
# 0     13854
# 1       643
# 2       174
# 3        57
# 4        23
# 8        11
# 6         9
# 5         8
# 12        4
# 7         3
# 13        2
# Name: count, dtype: int64>
# <bound method Series.sum of juv_other_count
# 0     13494
# 1       902
# 2       251
# 3        81
# 4        38
# 5         7
# 7         5
# 11        3
# 9         3
# 6         3
# 10        1
# Name: count, dtype: int64>
# <bound method Series.sum of priors_count
# 0     4221
# 1     2570
# 2     1718
# 3     1160
# 4      811
# 5      731
# 6      525
# 7      492
# 8      395
# 9      388
# 10     259
# 11     213
# 13     195
# 12     186
# 14     143
# 15     112
# 16     111
# 17      79
# 19      76
# 18      72
# 20      65
# 21      48
# 23      39
# 22      37
# 24      25
# 25      21
# 28      16
# 27      15
# 26      15
# 31      14
# 29      11
# 33       8
# 30       8
# 36       5
# 38       2
# 37       1
# 35       1
# Name: count, dtype: int64>
# <bound method Series.sum of c_charge_degree
# (F3)     8812
# (M1)     3339
# (F2)     1208
# (M2)      991
# (F1)      183
# (F7)      123
# (MO3)     103
# (F5)        8
# (NI0)       8
# (CO3)       6
# (F6)        5
# (X)         1
# (TCX)       1
# Name: count, dtype: int64>
# <bound method Series.sum of compas_score
# 1    7750
# 0    7038
# Name: count, dtype: int64>
# <bound method Series.sum of did_recid
# 0    7528
# 1    7260
# Name: count, dtype: int64>

# %% [markdown]
# ### Preprocessing Pipeline
# 1. Drop duplicates
#
# 2. Map 'sex', 'race', 'c_charge_degree'

# %%
data= clean_compas(data, 'compas_score', col_to_strip= 'c_charge_degree', drop_duplicates=True)

# %%
data.info()
data.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 5417 entries, 0 to 5416
# Data columns (total 9 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   sex              5417 non-null   object
#  1   age              5417 non-null   int64
#  2   race             5417 non-null   object
#  3   juv_fel_count    5417 non-null   int64
#  4   juv_misd_count   5417 non-null   int64
#  5   juv_other_count  5417 non-null   int64
#  6   priors_count     5417 non-null   int64
#  7   c_charge_degree  5417 non-null   object
#  8   did_recid        5417 non-null   int64
# dtypes: int64(6), object(3)
# memory usage: 381.0+ KB
#       sex  age              race  juv_fel_count  juv_misd_count  \
# 0  Female   19  African-American              0               0
# 1  Female   19  African-American              0               0
# 2  Female   19  African-American              0               0
# 3  Female   19  African-American              0               0
# 4  Female   19  African-American              0               0
#
#    juv_other_count  priors_count c_charge_degree  did_recid
# 0                0             0              F3          0
# 1                0             0              M2          0
# 2                0             0              M2          1
# 3                0             1              F2          1
# 4                0             1              F3          1

# %%
mapping= { 'sex': {'Female':0, 'Male':1},
           
            'race': {'Native American': 0,
            'Asian': 1,
            'Other': 2,
            'Hispanic': 3,
            'Caucasian': 4,
            'African-American': 5  },

            'c_charge_degree': {
                'X': 0, 'TCX': 0, 'NI0': 0, 'MO3': 0, 'CO3': 0, 

                'M2': 1,   
                'M1': 2,  
                'F5': 3, 'F6': 3,'F3': 3,                    
                                    
                'F7': 4, 'F2': 4, # apparently lvl 7 felonies can get u up to 15 years in prison                                                  
                'F1': 5
                }

}

data= apply_map(data, mapping)

# %% [markdown]
# ### Splitting and Transforming data
#
# 1. Apply stratified sampling
#
# 2. Get pre-training/HiC/calibration/Mic data
#
# 3. Apply scaler
#
# 4. Get X, y

# %%
# Qui definiamo i vari split dei flussi 
#set_all_seeds(42)
data = data.sample(frac=1, random_state=42).reset_index(drop=True) # shuffle iniziale

class_0 = data[data['did_recid'] == 0]
class_1= data[data['did_recid'] == 1]

#  split ufficiale

splits= {
    'calibration': (0.6, 0.8),
    'mic': (0.8, 1.0),
    'avv_train': (0.0, 0.07),
    'avv_test': (0.07, 0.1),
    'hic_train': (0.1, 0.5),
    'hic_test': (0.5, 0.6)
}

dfs= {}

for name, (start, end) in splits.items():
    dfs[name]= stratif(start, end, class_0, class_1)

# %%
for name, df in dfs.items():
    print(f"{name} length: {len(df)}")
# Out:
# calibration length: 1083
# mic length: 1085
# avv_train length: 378
# avv_test length: 163
# hic_train length: 2167
# hic_test length: 541

# %%
target= 'did_recid'

categoricals= ['sex', 'race', 'c_charge_degree']
numericals= [c for c in data if c not in categoricals and c != target]


prepr_transf = (
    (compose.Select(*numericals, *categoricals) | preprocessing.MinMaxScaler())
)

# %%
## ora divisione in x e y

#set_all_seeds(42)

# avviamento 
X_avv_train, y_avv_train = x_y_split(dfs['avv_train'], target)
X_avv_test, y_avv_test = x_y_split(dfs['avv_test'], target)


# hic
X_hic_train, y_hic_train = x_y_split(dfs['hic_train'], target)
X_hic_test, y_hic_test = x_y_split(dfs['hic_test'], target)

# validation
X_val, y_val = x_y_split(dfs['calibration'], target)

# mic
X_mic, y_mic = x_y_split(dfs['mic'], target)

# %% [markdown]
# ## Calibration Phase: Experts and Incremental Model Selection

# %% [markdown]
# ### Calibrating Incremental Model
#
# The incremental model to be chosen for Bridget is trained on the X_avv, y_avv portion of the dataset,then evaluated on the X_avv_test and y_avv_test
#
# The calibration phase starts by assessing the results of the learning for several configurations:
#
#     - HoeffdingTreeClassifier
#
#     - ExtremelyFastDecisionTreeClassifier
#
#     - AdaBoostClassifier            (base= SGTClassifier)
#
#     - AdwinBaggingClassifier        (base= SGTClassifier)
#
#     - SRPClassifier                 (base= SGTClassifier)
#
#     - AdaptiveRandomForestClassifier
#
#
# The metrics observed are the Accuracy, the F1Score and the Counters for the classes

# %%
# since all River models work with dicts, lets first transform the dfs to dict
#set_all_seeds(42)
X_avv_dict= X_avv_train.to_dict(orient='records')
X_avv_dict_test= X_avv_test.to_dict(orient='records')

df_batch_1 = (dfs['hic_train']).reset_index(drop=True)
mic_data= dfs['mic'].reset_index(drop=True)
df_avv= pd.concat([dfs['avv_train'], dfs['avv_test']]).reset_index(drop=True)

test_batch_1= X_hic_test.copy()
test_batch_1[target]= y_hic_test


# setting the init params required by HIC class
RULE = False
PAST = True
SKEPT = True
GROUP = True
EVA=    True
N_BINS = 10
N_VAR = 3
MAX = 5

rule_att = 'priors_count' #random rule
rule_value = -0.7

protected= ['race', 'age', 'sex']

# %%
# then the models are instantiated and trained by the HiC.train function
# the HiC object is initialized by passing a random user model, its not relevant since it won't interact with the IL anyways

#set_all_seeds(42)

base = tree.HoeffdingTreeClassifier(grace_period=100)

htree= tree.HoeffdingAdaptiveTreeClassifier(grace_period= 100, seed= 42)
efdt= tree.ExtremelyFastDecisionTreeClassifier(grace_period=100)
ada= ensemble.AdaBoostClassifier(model= base, n_models= 15, seed= 42)  
adwin= ensemble.ADWINBaggingClassifier(model= base, n_models= 15, seed= 42)
srp= ensemble.SRPClassifier(model= base, n_models=15, seed= 42)
arf= forest.ARFClassifier(n_models= 15, grace_period= 100, max_features='sqrt', seed=42)

models= {
    'HoeffdingATC': htree, 
    "EFDT": efdt, 
    "AdaBoostCl":ada, 
    "ADWINBAGGING": adwin, 
    "SRPCL": srp, 
    "ARF":arf   
    }

prepr_dir= DATASETS[ds_name]['base_obj_paths']['preprocessors']
os.makedirs(prepr_dir, exist_ok=True)

model_dir= DATASETS[ds_name]['base_obj_paths']['incremental_learners']
os.makedirs(model_dir, exist_ok=True)

for model_name, model_obj in models.items():
    
    bridget_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 'placeholder', model_obj,
                start_performance= DATASETS[ds_name]['start_performance'],
                allocated_budget= DATASETS[ds_name]['allocated_budget'][0],
                skepticism_threshold= DATASETS[ds_name]['skepticism_threshold'],
                performance_delta= DATASETS[ds_name]['performance_delta'],
                dataset_name= ds_name,
                user_name= 'placeholder',
                batch1=df_batch_1, batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model='placeholder', 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= 0 
                )
    
    bridget_inst.train(X_avv_dict, y_avv_train, X_avv_dict_test, y_avv_test)

    base_preprocessor = bridget_inst.preprocessor
    base_model = bridget_inst.hic_model
    

    prepr_filename = f"{model_name}_preprocessor.pkl"
    model_filename = f"{model_name}_model.pkl"

    joblib.dump(base_preprocessor, os.path.join(prepr_dir, prepr_filename))
    joblib.dump(base_model, os.path.join(model_dir, model_filename))


trained_arf= arf
# Out:
# Accuracy: 65.03%
# F1: 42.42%
# Distribution of predictions: Counter({0: 131, 1: 32})
# HoeffdingAdaptiveTreeClassifier trained
# Accuracy: 58.90%
# F1: 0.00%
# Distribution of predictions: Counter({0: 163})
# ExtremelyFastDecisionTreeClassifier trained
# Accuracy: 66.87%
# F1: 46.00%
# Distribution of predictions: Counter({0: 130, 1: 33})
# AdaBoostClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 66.26%
# F1: 43.30%
# Distribution of predictions: Counter({0: 133, 1: 30})
# ADWINBaggingClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 65.03%
# F1: 38.71%
# Distribution of predictions: Counter({0: 137, 1: 26})
# SRPClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 64.42%
# F1: 40.82%
# Distribution of predictions: Counter({0: 132, 1: 31})
# ARFClassifier trained

# %% [markdown]
# ### Calibrating Experts

# %%
with open(fr".\experts_{ds_name}.yaml", "r") as f:
    config= yaml.safe_load(f)


params_dict= config['experts']['groups']['w_dict']

# %%
#set_all_seeds(42)
X_exp= X_hic_train.to_dict(orient='records')

X_exp_scaled= []

for x in X_exp:
    X_exp_scaled.append(prepr_transf.transform_one(x))

X_exp_final = pd.DataFrame(X_exp_scaled)

# %%
#set_all_seeds(42)
experts_obj= {}

expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

for name in expert_names:
    expert_type= config['experts']['groups'][name]

    experts_obj[name]= BetaUser(
        belief_level= expert_type['belief_value'],
        rethink_level= 0.8, # as suggested by the og FRANK implementation
        fairness= True,
        fpr= expert_type['target_FPR'],
        fnr= expert_type['target_FNR'],
        alpha= 0.9,
        features_dict= params_dict,
        seed= expert_type['group_seed']
        )
    res = experts_obj[name].fit(X_exp_final, y_hic_train, tol= 0.001)

    save_dir= fr".\trained_experts\{ds_name}"
    os.makedirs(save_dir, exist_ok= True)
    file_path = os.path.join(save_dir, f"{name}.pkl")

    with open(file_path, 'wb') as f:
        pickle.dump(experts_obj[name], f)
    print(f"Expert saved in: {file_path}")

    
    print(f"{'='*30}")
    print(f" EXPERT CALIBRATION REPORT ")
    print(f"{'='*30}")

    print(f"\n[EXPERT: {name}]")
    print(f"\n[FALSE POSITIVE RATE]")
    print(f"  - Iters:      {res['fpr iters number']}")
    print(f"  - Beta:       {res['calibrated_fpr_beta']:.4f}")
    print(f"  - Target:     {res['target_fpr']}")
    print(f"  - Achieved:   {res['achieved_fpr']:.4f}")

    print(f"\n[FALSE NEGATIVE RATE]")
    print(f"  - Iters:      {res['fnr iters number']}")
    print(f"  - Beta:       {res['calibrated_fnr_beta']:.4f}")
    print(f"  - Target:     {res['target_fnr']}")
    print(f"  - Achieved:   {res['achieved_fnr']:.4f}")
# Out:
# Expert saved in: .\trained_experts\compas\accurate_trusting.pkl
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: accurate_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      12
#   - Beta:       -3.1738
#   - Target:     0.05
#   - Achieved:   0.0495
#
# [FALSE NEGATIVE RATE]
#   - Iters:      12
#   - Beta:       -2.6855
#   - Target:     0.05
#   - Achieved:   0.0493
# Expert saved in: .\trained_experts\compas\accurate_not_trusting.pkl
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: accurate_not_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      12
#   - Beta:       -2.9785
#   - Target:     0.05
#   - Achieved:   0.0492
#
# [FALSE NEGATIVE RATE]
#   - Iters:      13
#   - Beta:       -2.9053
#   - Target:     0.05
#   - Achieved:   0.0499
# Expert saved in: .\trained_experts\compas\inaccurate_trusting.pkl
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: inaccurate_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      13
#   - Beta:       -1.2939
#   - Target:     0.3
#   - Achieved:   0.3000
#
# [FALSE NEGATIVE RATE]
#   - Iters:      14
#   - Beta:       -0.3296
#   - Target:     0.3
#   - Achieved:   0.3000
# Expert saved in: .\trained_experts\compas\inaccurate_not_trusting.pkl
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: inaccurate_not_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      15
#   - Beta:       -1.1414
#   - Target:     0.3
#   - Achieved:   0.2999
#
# [FALSE NEGATIVE RATE]
#   - Iters:      14
#   - Beta:       -0.5249
#   - Target:     0.3
#   - Achieved:   0.3007

# %% [markdown]
# ## BRIDGET decision making

# %%
# base params for all users
initial_ordering= [c for c in data if c != target]

# retrieve preprocessor and incremental learner
rules= FRANK_RULES


base_params= {
    "cats": categoricals, #lst
    "num": numericals, #lss
    "warm_up_set": df_avv.copy(),
    "batch1": df_batch_1.copy(),
    "batch1_test": test_batch_1.copy(),
    "batch3":dfs['mic'].copy(),
    "validation_set": dfs['calibration'].copy(), #obtained by hic
    "feature_order": initial_ordering.copy(), #without the label ?
    "incremental_learner_name":"ARF",
    "n_cols": len(initial_ordering), #obtained by hic
    "mic_model_name": "Def_Net",
    "strat_1_name": "Confidence",
    "strat_2_name": "Mao",
    
}


learner_path= DATASETS[ds_name]['base_obj_paths']['incremental_learners']
path= os.path.join(learner_path, f"{base_params["incremental_learner_name"]}_model.pkl")
trained_learner= joblib.load(path)

prepr_path= DATASETS[ds_name]['base_obj_paths']['preprocessors']
path= os.path.join(prepr_path, f"{base_params["incremental_learner_name"]}_preprocessor.pkl")
base_prepr= joblib.load(path)

base_objects = {
      "preprocessor": copy.deepcopy(base_prepr), #or take from path
      "incremental_learner":copy.deepcopy(trained_learner), # or take from path
      "scaler": None
} 

#device = torch.device("cuda" if torch.cuda.is_available() else "cpu")
device= torch.device("cpu")
#add these once you get to mic phase: "run_confidence": True, "run_mao": True

# %% [markdown]
# ### Expert: Accurate, Trusting

# %% [markdown]
# #### HIC

# %%
#setting up fixed params

current_user_name= "accurate_trusting"
user_suffix= 'acc_t'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})

# %%
run_hic(ds_name, params, objects)
# Out:
# 100%|██████████| 722/722 [01:53<00:00,  6.37it/s]
# 1.0391304347826087 0.9637096774193549
# 2026-04-13 18:43:17,515 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# Training Results - Epoch[1] Avg accuracy: 0.52 Avg loss: 0.71
# Validation Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.74
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.52 Avg loss: 0.70
# Validation Results - Epoch[2] Avg accuracy: 0.41 Avg loss: 0.73
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.52 Avg loss: 0.70
# Validation Results - Epoch[3] Avg accuracy: 0.41 Avg loss: 0.72
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.52 Avg loss: 0.70
# Validation Results - Epoch[4] Avg accuracy: 0.41 Avg loss: 0.72
# End of Epoch 4: Learning Rate 0.001
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2026-04-13 18:43:17,946 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.0391304347826087 0.9637096774193549
# Training Results - Epoch[1] Avg accuracy: 0.52 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.52 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.59 Avg loss: 0.69
# Validation Results - Epoch[3] Avg accuracy: 0.47 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.69
# Validation Results - Epoch[4] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[5] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[6] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[7] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 7: Learning Rate 0.001
# 2026-04-13 18:43:18,251 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.0391304347826087 0.9637096774193549
# Training Results - Epoch[1] Avg accuracy: 0.48 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.59 Avg loss: 0.68
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 4: Learning Rate 0.001
# 1.0391304347826087 0.9637096774193549
# Training Results - Epoch[1] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[1] Avg accuracy: 0.50 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.62 Avg loss: 0.66
# Validation Results - Epoch[2] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.65
# Validation Results - Epoch[3] Avg accuracy: 0.51 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.63 Avg loss: 0.64
# Validation Results - Epoch[4] Avg accuracy: 0.52 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.64 Avg loss: 0.63
# Validation Results - Epoch[5] Avg accuracy: 0.54 Avg loss: 0.68
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.66 Avg loss: 0.62
# Validation Results - Epoch[6] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.67 Avg loss: 0.61
# Validation Results - Epoch[7] Avg accuracy: 0.57 Avg loss: 0.67
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.67 Avg loss: 0.60
# Validation Results - Epoch[8] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.68 Avg loss: 0.59
# Validation Results - Epoch[9] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.68 Avg loss: 0.59
# Validation Results - Epoch[10] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.67 Avg loss: 0.58
# Validation Results - Epoch[11] Avg accuracy: 0.61 Avg loss: 0.67
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.67 Avg loss: 0.58
# Validation Results - Epoch[12] Avg accuracy: 0.61 Avg loss: 0.67
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.67 Avg loss: 0.58
# Validation Results - Epoch[13] Avg accuracy: 0.62 Avg loss: 0.68
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.67 Avg loss: 0.58
# Validation Results - Epoch[14] Avg accuracy: 0.62 Avg loss: 0.68
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.67 Avg loss: 0.58
# Validation Results - Epoch[15] Avg accuracy: 0.62 Avg loss: 0.68
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.67 Avg loss: 0.57
# Validation Results - Epoch[16] Avg accuracy: 0.63 Avg loss: 0.68
# End of Epoch 16: Learning Rate 0.00064
# Epoch[17], Iter[100] Loss: 0.54
# Training Results - Epoch[17] Avg accuracy: 0.68 Avg loss: 0.57
# Validation Results - Epoch[17] Avg accuracy: 0.62 Avg loss: 0.68
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.68 Avg loss: 0.57
# Validation Results - Epoch[18] Avg accuracy: 0.62 Avg loss: 0.69
# End of Epoch 18: Learning Rate 0.00064
# Training Results - Epoch[19] Avg accuracy: 0.68 Avg loss: 0.57
# Validation Results - Epoch[19] Avg accuracy: 0.63 Avg loss: 0.69
# End of Epoch 19: Learning Rate 0.00064
# Training Results - Epoch[20] Avg accuracy: 0.68 Avg loss: 0.57
# Validation Results - Epoch[20] Avg accuracy: 0.62 Avg loss: 0.69
# End of Epoch 20: Learning Rate 0.00064
# 100%|██████████| 722/722 [02:55<00:00,  4.12it/s]
# 2026-04-13 18:46:15,666 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.1305732484076434 0.8964646464646465
# Training Results - Epoch[1] Avg accuracy: 0.44 Avg loss: 0.70
# Validation Results - Epoch[1] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.44 Avg loss: 0.70
# Validation Results - Epoch[2] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.44 Avg loss: 0.70
# Validation Results - Epoch[3] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.44 Avg loss: 0.69
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2026-04-13 18:46:16,016 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.1305732484076434 0.8964646464646465
# Training Results - Epoch[1] Avg accuracy: 0.44 Avg loss: 0.70
# Validation Results - Epoch[1] Avg accuracy: 0.59 Avg loss: 0.66
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.44 Avg loss: 0.70
# Validation Results - Epoch[2] Avg accuracy: 0.59 Avg loss: 0.66
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.44 Avg loss: 0.69
# Validation Results - Epoch[3] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.44 Avg loss: 0.69
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 1.1305732484076434 0.8964646464646465
# Training Results - Epoch[1] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.58 Avg loss: 0.69
# Validation Results - Epoch[3] Avg accuracy: 0.45 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[5] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.63 Avg loss: 0.68
# Validation Results - Epoch[6] Avg accuracy: 0.52 Avg loss: 0.69
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.63 Avg loss: 0.67
# Validation Results - Epoch[7] Avg accuracy: 0.53 Avg loss: 0.69
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.63 Avg loss: 0.67
# Validation Results - Epoch[8] Avg accuracy: 0.53 Avg loss: 0.69
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.63 Avg loss: 0.67
# Validation Results - Epoch[9] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.65 Avg loss: 0.66
# Validation Results - Epoch[10] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.64 Avg loss: 0.66
# Validation Results - Epoch[11] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.64 Avg loss: 0.66
# Validation Results - Epoch[12] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.64 Avg loss: 0.65
# Validation Results - Epoch[13] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.65 Avg loss: 0.65
# Validation Results - Epoch[14] Avg accuracy: 0.58 Avg loss: 0.68
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.65 Avg loss: 0.64
# Validation Results - Epoch[15] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.66 Avg loss: 0.63
# Validation Results - Epoch[16] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 16: Learning Rate 0.00064
# Epoch[17], Iter[100] Loss: 0.63
# Training Results - Epoch[17] Avg accuracy: 0.66 Avg loss: 0.63
# Validation Results - Epoch[17] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.66 Avg loss: 0.63
# Validation Results - Epoch[18] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 18: Learning Rate 0.00064
# Training Results - Epoch[19] Avg accuracy: 0.67 Avg loss: 0.62
# Validation Results - Epoch[19] Avg accuracy: 0.60 Avg loss: 0.66
# End of Epoch 19: Learning Rate 0.00064
# Training Results - Epoch[20] Avg accuracy: 0.67 Avg loss: 0.62
# Validation Results - Epoch[20] Avg accuracy: 0.61 Avg loss: 0.66
# End of Epoch 20: Learning Rate 0.00064
# 1.1305732484076434 0.8964646464646465
# Training Results - Epoch[1] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.48 Avg loss: 0.70
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.67
# Validation Results - Epoch[4] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.62 Avg loss: 0.67
# Validation Results - Epoch[5] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.62 Avg loss: 0.66
# Validation Results - Epoch[6] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.63 Avg loss: 0.65
# Validation Results - Epoch[7] Avg accuracy: 0.52 Avg loss: 0.68
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.64 Avg loss: 0.64
# Validation Results - Epoch[8] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.66 Avg loss: 0.64
# Validation Results - Epoch[9] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.68 Avg loss: 0.63
# Validation Results - Epoch[10] Avg accuracy: 0.58 Avg loss: 0.67
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.68 Avg loss: 0.62
# Validation Results - Epoch[11] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.69 Avg loss: 0.61
# Validation Results - Epoch[12] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.69 Avg loss: 0.60
# Validation Results - Epoch[13] Avg accuracy: 0.61 Avg loss: 0.67
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.69 Avg loss: 0.60
# Validation Results - Epoch[14] Avg accuracy: 0.61 Avg loss: 0.67
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.70 Avg loss: 0.59
# Validation Results - Epoch[15] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 15: Learning Rate 0.0008
# 2026-04-13 18:46:17,582 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# Training Results - Epoch[16] Avg accuracy: 0.70 Avg loss: 0.58
# Validation Results - Epoch[16] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 16: Learning Rate 0.00064
# Epoch[17], Iter[100] Loss: 0.57
# Training Results - Epoch[17] Avg accuracy: 0.70 Avg loss: 0.58
# Validation Results - Epoch[17] Avg accuracy: 0.61 Avg loss: 0.68
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.69 Avg loss: 0.57
# Validation Results - Epoch[18] Avg accuracy: 0.61 Avg loss: 0.68
# End of Epoch 18: Learning Rate 0.00064
# 100%|██████████| 723/723 [02:18<00:00,  5.22it/s]
# 2026-04-13 18:48:38,289 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.144694533762058 0.8877805486284289
# Training Results - Epoch[1] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[3] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.56 Avg loss: 0.69
# Validation Results - Epoch[4] Avg accuracy: 0.41 Avg loss: 0.70
# End of Epoch 4: Learning Rate 0.001
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# c:\Users\virgm\anaconda3\Lib\site-packages\sklearn\metrics\_classification.py:1833: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# 2026-04-13 18:48:38,694 ignite.handlers.early_stopping.EarlyStopping INFO: EarlyStopping: Stop training
# 1.144694533762058 0.8877805486284289
# Training Results - Epoch[1] Avg accuracy: 0.46 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.60 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.69 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.64 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.70 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.54 Avg loss: 0.69
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.68 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.52 Avg loss: 0.69
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.68
# Validation Results - Epoch[5] Avg accuracy: 0.51 Avg loss: 0.69
# End of Epoch 5: Learning Rate 0.001
# 1.144694533762058 0.8877805486284289
# Training Results - Epoch[1] Avg accuracy: 0.58 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.44 Avg loss: 0.70
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.59 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.42 Avg loss: 0.70
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.44 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.67 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.67
# Validation Results - Epoch[5] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.67 Avg loss: 0.66
# Validation Results - Epoch[6] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.67 Avg loss: 0.66
# Validation Results - Epoch[7] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.67 Avg loss: 0.65
# Validation Results - Epoch[8] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.68 Avg loss: 0.64
# Validation Results - Epoch[9] Avg accuracy: 0.51 Avg loss: 0.69
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.68 Avg loss: 0.63
# Validation Results - Epoch[10] Avg accuracy: 0.52 Avg loss: 0.68
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.69 Avg loss: 0.62
# Validation Results - Epoch[11] Avg accuracy: 0.53 Avg loss: 0.68
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.70 Avg loss: 0.61
# Validation Results - Epoch[12] Avg accuracy: 0.54 Avg loss: 0.68
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.70 Avg loss: 0.60
# Validation Results - Epoch[13] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.70 Avg loss: 0.60
# Validation Results - Epoch[14] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.70 Avg loss: 0.59
# Validation Results - Epoch[15] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.71 Avg loss: 0.58
# Validation Results - Epoch[16] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 16: Learning Rate 0.00064
# Epoch[17], Iter[100] Loss: 0.61
# Training Results - Epoch[17] Avg accuracy: 0.71 Avg loss: 0.58
# Validation Results - Epoch[17] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.71 Avg loss: 0.58
# Validation Results - Epoch[18] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 18: Learning Rate 0.00064
# Training Results - Epoch[19] Avg accuracy: 0.72 Avg loss: 0.57
# Validation Results - Epoch[19] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 19: Learning Rate 0.00064
# Training Results - Epoch[20] Avg accuracy: 0.72 Avg loss: 0.57
# Validation Results - Epoch[20] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 20: Learning Rate 0.00064
# 1.144694533762058 0.8877805486284289
# Training Results - Epoch[1] Avg accuracy: 0.66 Avg loss: 0.68
# Validation Results - Epoch[1] Avg accuracy: 0.47 Avg loss: 0.71
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.67 Avg loss: 0.67
# Validation Results - Epoch[2] Avg accuracy: 0.49 Avg loss: 0.71
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.67 Avg loss: 0.65
# Validation Results - Epoch[3] Avg accuracy: 0.49 Avg loss: 0.70
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.67 Avg loss: 0.64
# Validation Results - Epoch[4] Avg accuracy: 0.50 Avg loss: 0.69
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.63
# Validation Results - Epoch[5] Avg accuracy: 0.50 Avg loss: 0.70
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.68 Avg loss: 0.61
# Validation Results - Epoch[6] Avg accuracy: 0.50 Avg loss: 0.70
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.70 Avg loss: 0.60
# Validation Results - Epoch[7] Avg accuracy: 0.53 Avg loss: 0.69
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.70 Avg loss: 0.59
# Validation Results - Epoch[8] Avg accuracy: 0.54 Avg loss: 0.70
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.70 Avg loss: 0.58
# Validation Results - Epoch[9] Avg accuracy: 0.55 Avg loss: 0.70
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.71 Avg loss: 0.57
# Validation Results - Epoch[10] Avg accuracy: 0.57 Avg loss: 0.69
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.71 Avg loss: 0.56
# Validation Results - Epoch[11] Avg accuracy: 0.57 Avg loss: 0.70
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.56
# Validation Results - Epoch[12] Avg accuracy: 0.59 Avg loss: 0.70
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.55
# Validation Results - Epoch[13] Avg accuracy: 0.59 Avg loss: 0.70
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.55
# Validation Results - Epoch[14] Avg accuracy: 0.60 Avg loss: 0.70
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[15] Avg accuracy: 0.60 Avg loss: 0.70
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[16] Avg accuracy: 0.60 Avg loss: 0.70
# End of Epoch 16: Learning Rate 0.00064
# Epoch[17], Iter[100] Loss: 0.59
# Training Results - Epoch[17] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[17] Avg accuracy: 0.60 Avg loss: 0.70
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[18] Avg accuracy: 0.60 Avg loss: 0.71
# End of Epoch 18: Learning Rate 0.00064
# Training Results - Epoch[19] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[19] Avg accuracy: 0.61 Avg loss: 0.71
# End of Epoch 19: Learning Rate 0.00064
# Training Results - Epoch[20] Avg accuracy: 0.72 Avg loss: 0.54
# Validation Results - Epoch[20] Avg accuracy: 0.61 Avg loss: 0.71
# End of Epoch 20: Learning Rate 0.00064

# %% [markdown]
# #### CALIB

# %%
#chosen nets: "large", 32/16

net_layers= [32,16]
hic_df_general_path= DATASETS[ds_name]['paths']['hic_df_save_path']
net_general_path= DATASETS[ds_name]['paths']['def_net_save_path']

# retrieving df and best net path
for i in range (1, 4):

    df_switch_path= os.path.join(hic_df_general_path,
                            f"iter_{i}",
                            f"results_{params['user_name']}",
                            f"hic_{params['user_name']}.parquet"
                            )
    
    df_switch= pd.read_parquet(df_switch_path)


    def_net_path= os.path.join(net_general_path,
                           f"iter_{i}",
                           f"{user_suffix}_models",
                           f"{net_layers[0]}_{net_layers[1]}"
                          )

    pattern = f"{net_layers[0]}_{net_layers[1]}_model_*.pt"
    search_query = os.path.join(def_net_path, pattern)
    matches = glob.glob(search_query)

    if matches:
        def_net_path = max(matches, key=os.path.getctime)
        run_calibration(def_net_path= def_net_path, 
                        df_switch=df_switch, 
                        ds_name=ds_name, 
                        params=params,
                        device=device, 
                        iteration=i,
                        def_net_layers=net_layers
                        ) #default had batch seize 128, epochs = 20

# %% [markdown]
# #### MIC

# %%
current_user_name= "accurate_trusting"
user_suffix= 'acc_t'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix,
    "run_confidence": True,
    "run_mao": True
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})


def_net_layers= [32, 16]
strat_1=None
strat_2=None

for i in range(1,4):

    strat_1, strat_2= run_mic( 
                            ds_name= ds_name,
                            device= device,
                            layers= def_net_layers,
                            params=params,
                            objects=objects,
                            iteration=i,
                            strat_1_res=strat_1,
                            strat_2_res=strat_2
                            )

# %% [markdown]
# ### Expert: Inaccurate, Trusting

# %% [markdown]
# #### HIC

# %%
#setting up fixed params

current_user_name= "inaccurate_trusting"
user_suffix= 'inacc_t'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})

# %%
run_hic(ds_name, params, objects)

# %% [markdown]
# #### Calib

# %%
#chosen nets: "large", 32/16

layers= [32,16]
hic_df_general_path= DATASETS[ds_name]['paths']['hic_df_save_path']
net_general_path= DATASETS[ds_name]['paths']['def_net_save_path']
# retrieving df and best net path

for i in range (1, 4):

    df_switch_path= os.path.join(hic_df_general_path,
                            f"iter_{i}",
                            f"results_{params['user_name']}",
                            f"hic_{params['user_name']}.parquet"
                            )
    
    df_switch= pd.read_parquet(df_switch_path)


    def_net_path= os.path.join(net_general_path,
                           f"iter_{i}",
                           f"{user_suffix}_models",
                           f"{layers[0]}_{layers[1]}"
                          )

    pattern = f"{layers[0]}_{layers[1]}_model_*.pt"
    search_query = os.path.join(def_net_path, pattern)
    matches = glob.glob(search_query)

    if matches:
        def_net_path = max(matches, key=os.path.getctime)
        run_calibration(def_net_path= def_net_path, 
                        df_switch=df_switch, 
                        ds_name=ds_name, 
                        params=params,
                        device=device, 
                        iteration=i,
                        def_net_layers=net_layers
                        ) #default had batch seize 128, epochs = 20

# %% [markdown]
# #### MIC

# %%
current_user_name= "inaccurate_trusting"
user_suffix= 'inacc_t'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix,
    "run_confidence": True,
    "run_mao": True
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})


def_net_layers= [32, 16]
strat_1=None
strat_2=None

for i in range(1,4):

    strat_1, strat_2= run_mic( 
                            ds_name= ds_name,
                            device= device,
                            layers= def_net_layers,
                            params=params,
                            objects=objects,
                            iteration=i,
                            strat_1_res=strat_1,
                            strat_2_res=strat_2)

# %% [markdown]
# ### Expert: Accurate, Not Trusting

# %% [markdown]
# #### HIC

# %%
#setting up fixed params

current_user_name= "accurate_not_trusting"
user_suffix= 'acc_nt'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})

# %%
run_hic(ds_name, params, objects)

# %% [markdown]
# #### CALIB

# %%
#chosen nets: "large", 32/16

layers= [32,16]
hic_df_general_path= DATASETS[ds_name]['paths']['hic_df_save_path']
net_general_path= DATASETS[ds_name]['paths']['def_net_save_path']
# retrieving df and best net path
for i in range (1, 4):

    df_switch_path= os.path.join(hic_df_general_path,
                            f"iter_{i}",
                            f"results_{params['user_name']}",
                            f"hic_{params['user_name']}.parquet"
                            )
    
    df_switch= pd.read_parquet(df_switch_path)


    def_net_path= os.path.join(net_general_path,
                           f"iter_{i}",
                           f"{user_suffix}_models",
                           f"{layers[0]}_{layers[1]}"
                          )

    pattern = f"{layers[0]}_{layers[1]}_model_*.pt"
    search_query = os.path.join(def_net_path, pattern)
    matches = glob.glob(search_query)

    if matches:
        def_net_path = max(matches, key=os.path.getctime)
        run_calibration(def_net_path= def_net_path, 
                        df_switch=df_switch, 
                        ds_name=ds_name, 
                        params=params,
                        device=device, 
                        iteration=i,
                        def_net_layers=net_layers
                        ) #default had batch seize 128, epochs = 20

# %% [markdown]
# #### MIC

# %%
current_user_name= "accurate_not_trusting"
user_suffix= 'acc_nt'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix,
    "run_confidence": True,
    "run_mao": True
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})


def_net_layers= [32, 16]
strat_1=None
strat_2=None

for i in range(1,4):

    strat_1, strat_2= run_mic( 
                            ds_name= ds_name,
                            device= device,
                            layers= def_net_layers,
                            params=params,
                            objects=objects,
                            iteration=i,
                            strat_1_res=strat_1,
                            strat_2_res=strat_2)

# %% [markdown]
# ### Expert: Inaccurate, Not Trusting

# %% [markdown]
# #### HIC

# %%
#setting up fixed params

current_user_name= "inaccurate_not_trusting"
user_suffix= 'inacc_nt'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})

# %%
run_hic(ds_name, params, objects)

# %% [markdown]
# #### CALIB

# %%
#chosen nets: "large", 32/16

layers= [32,16]
hic_df_general_path= DATASETS[ds_name]['paths']['hic_df_save_path']
net_general_path= DATASETS[ds_name]['paths']['def_net_save_path']

# retrieving df and best net path
for i in range (1, 4):

    df_switch_path= os.path.join(hic_df_general_path,
                            f"iter_{i}",
                            f"results_{params['user_name']}",
                            f"hic_{params['user_name']}.parquet"
                            )
    
    df_switch= pd.read_parquet(df_switch_path)


    def_net_path= os.path.join(net_general_path,
                           f"iter_{i}",
                           f"{user_suffix}_models",
                           f"{layers[0]}_{layers[1]}"
                          )

    pattern = f"{layers[0]}_{layers[1]}_model_*.pt"
    search_query = os.path.join(def_net_path, pattern)
    matches = glob.glob(search_query)

    if matches:
        def_net_path = max(matches, key=os.path.getctime)
        run_calibration(def_net_path= def_net_path, 
                        df_switch=df_switch, 
                        ds_name=ds_name, 
                        params=params,
                        device=device, 
                        iteration=i,
                        def_net_layers=net_layers
                        ) #default had batch seize 128, epochs = 20

# %% [markdown]
# #### MIC

# %%
current_user_name= "inaccurate_not_trusting"
user_suffix= 'inacc_nt'

exp_path= fr".\trained_experts\{ds_name}\{current_user_name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix,
    "run_confidence": True,
    "run_mao": True
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})


def_net_layers= [32, 16]
strat_1=None
strat_2=None

for i in range(1,4):

    strat_1, strat_2= run_mic( 
                            ds_name= ds_name,
                            device= device,
                            layers= def_net_layers,
                            params=params,
                            objects=objects,
                            iteration=i,
                            strat_1_res=strat_1,
                            strat_2_res=strat_2)

# %% [markdown]
# ## Benchmarking
#
# since COMPAS has their score already, lets test whether our experts are way off their prediction

# %% [markdown]
# ### Human in Command

# %%
experts_obj= {}

prepr_path= DATASETS[ds_name]['base_obj_paths']['preprocessors']
path= os.path.join(prepr_path, f"{base_params["incremental_learner_name"]}_preprocessor.pkl")
base_prepr= joblib.load(path)

expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

res= {}

for name in expert_names:

        res[name]= {}

        # retrieving trained exp
        exp_path= DATASETS[ds_name]['paths']['user_obj_path']['trained_experts']
        exp_path= os.path.join(exp_path, fr"{name}.pkl")
        trained_exp = joblib.load(exp_path)

        experts_obj[name]= trained_exp
        
        baseline_inst= Baseline(user=experts_obj[name],
                                label=DATASETS[ds_name]['target'],
                                train_set=dfs['hic_train'],
                                test_set=dfs['mic'],
                                val_set=dfs['calibration'],
                                x_train=X_hic_train,
                                y_train=y_hic_train,
                                x_test=X_mic,
                                y_test=y_mic,
                                x_val=X_val,
                                y_val=y_val
                                )
        
        train, test, val = baseline_inst.fit_expert(base_prepr)

        print(f"Train Predictions Unique Values: {train['expert prediction'].unique()}")
        
        print(f"Test Predictions Unique Values: {test['expert prediction'].unique()}")

        print(f"Val Predictions Unique Values: {val['expert prediction'].unique()}")

        res[name]['train']= train
        res[name]['test']= test
        res[name]['val']= val

        #################### SAVING STUFF

        ## 1. Train set
        train_path= DATASETS[ds_name]['user_test']['train_df_labeled_by_experts']
        os.makedirs(train_path, exist_ok=True)
        file_path = os.path.join(train_path, f"train_user_test_{name}.parquet")

        train.to_parquet(file_path, index=False)
        
        ## 2. Test set
        test_path= DATASETS[ds_name]['user_test']['test_df_for_mic']
        os.makedirs(test_path, exist_ok=True)
        file_path = os.path.join(test_path, f"test_user_test_{name}.parquet")

        test.to_parquet(file_path, index=False)

        ## 3. Validation set
        val_path= DATASETS[ds_name]['user_test']['validation_set_labeled']
        os.makedirs(val_path, exist_ok=True)
        file_path = os.path.join(val_path, f"val_user_test_{name}.parquet")

        val.to_parquet(file_path, index=False)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[23], line 17
#      14 res[name]= {}
#      16 # retrieving trained exp
# ---> 17 exp_path= DATASETS[ds_name]['paths']['user_obj_path']['trained_experts']
#      18 exp_path= os.path.join(exp_path, fr"{name}.pkl")
#      19 trained_exp = joblib.load(exp_path)
#
# TypeError: string indices must be integers, not 'str'

# %% [markdown]
# ### Machine in Command (anche qui la 32/16 palesemente)

# %% [markdown]
# #### Experts re-calibration and prediction

# %%
# a note: in the BRIDGET pipeline, the Machine in Command phase receives the information provided by a scaler from the River lib

# however, since the ablation study will focus on a neural network that has to learn on the Human-in-Command portion anyways, 
# it needs its own dedicated scaler (a standard sklearn Min Max Scaler)

# now do the fitting again with the Min Max scaler, then get the predictions using the baseline func

#set_all_seeds(42)

with open(fr".\experts_{ds_name}.yaml", "r") as f:
    config= yaml.safe_load(f)


params_dict= config['experts']['groups']['w_dict']

scaler= MinMaxScaler()
experts_obj= {}

X_scaled= scaler.fit_transform(X_hic_train)
X_scaled = pd.DataFrame(X_scaled, columns= X_hic_train.columns)

expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

for name in expert_names:
    expert_type= config['experts']['groups'][name]

    experts_obj[name]= BetaUser(
        belief_level= expert_type['belief_value'],
        rethink_level= 0.8, # as suggested by the og FRANK implementation
        fairness= True,
        fpr= expert_type['target_FPR'],
        fnr= expert_type['target_FNR'],
        alpha= 0.9,
        features_dict= params_dict,
        seed= expert_type['group_seed']
        )
    res = experts_obj[name].fit(X_scaled, y_hic_train, tol= 0.001)

    save_dir= fr".\baseline\experts\{ds_name}"
    os.makedirs(save_dir, exist_ok= True)
    file_path = os.path.join(save_dir, f"{name}.pkl")

    with open(file_path, 'wb') as f:
        pickle.dump(experts_obj[name], f)
    print(f"Expert saved in: {file_path}")

    
    print(f"{'='*30}")
    print(f" EXPERT CALIBRATION REPORT ")
    print(f"{'='*30}")

    print(f"\n[EXPERT: {name}]")
    print(f"\n[FALSE POSITIVE RATE]")
    print(f"  - Iters:      {res['fpr iters number']}")
    print(f"  - Beta:       {res['calibrated_fpr_beta']:.4f}")
    print(f"  - Target:     {res['target_fpr']}")
    print(f"  - Achieved:   {res['achieved_fpr']:.4f}")

    print(f"\n[FALSE NEGATIVE RATE]")
    print(f"  - Iters:      {res['fnr iters number']}")
    print(f"  - Beta:       {res['calibrated_fnr_beta']:.4f}")
    print(f"  - Target:     {res['target_fnr']}")
    print(f"  - Achieved:   {res['achieved_fnr']:.4f}")

# %%
## since each strategy requires the label produced by the users, lets produce them :) 

## we'll use the calibrated experts in the (trained experts) folder 
# (alternatively, since you gotta rerun the preprocessing and calibration, just use the experts obj dict)
# to make it more proper, lets just retrieve the paths

experts_obj= {}
scaler= MinMaxScaler()
expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

res= {}

for name in expert_names:

        res[name]= {}

        # retrieving trained exp
        exp_path= DATASETS[ds_name]['baseline_paths']['trained_experts']
        exp_path= os.path.join(exp_path, fr"{name}.pkl")
        trained_exp = joblib.load(exp_path)

        experts_obj[name]= trained_exp
        
        baseline_inst= Baseline(user=experts_obj[name],
                                label=DATASETS[ds_name]['target'],
                                train_set=dfs['hic_train'],
                                test_set=dfs['mic'],
                                val_set=dfs['calibration'],
                                x_train=X_hic_train,
                                y_train=y_hic_train,
                                x_test=X_mic,
                                y_test=y_mic,
                                x_val=X_val,
                                y_val=y_val
                                )
        
        train, test, val = baseline_inst.fit_expert(scaler)

        print(f"Train Predictions Unique Values: {train['expert prediction'].unique()}")
        
        print(f"Test Predictions Unique Values: {test['expert prediction'].unique()}")

        print(f"Val Predictions Unique Values: {val['expert prediction'].unique()}")

        res[name]['train']= train
        res[name]['test']= test
        res[name]['val']= val

        #################### SAVING STUFF

        ## 1. Train set
        train_path= DATASETS[ds_name]['baseline_paths']['train_df_labeled_by_experts']
        os.makedirs(train_path, exist_ok=True)
        file_path = os.path.join(train_path, f"train_baseline_{name}.parquet")

        train.to_parquet(file_path, index=False)
        
        ## 2. Test set
        test_path= DATASETS[ds_name]['baseline_paths']['test_df_for_mic']
        os.makedirs(test_path, exist_ok=True)
        file_path = os.path.join(test_path, f"test_baseline_{name}.parquet")

        test.to_parquet(file_path, index=False)

        ## 3. Validation set
        val_path= DATASETS[ds_name]['baseline_paths']['validation_set_labeled']
        os.makedirs(val_path, exist_ok=True)
        file_path = os.path.join(val_path, f"val_baseline_{name}.parquet")

        val.to_parquet(file_path, index=False)


        ## 4. Scaler 
        base_scaler_path= DATASETS[ds_name]['baseline_paths']['trained_scalers']
        os.makedirs(test_path, exist_ok=True)
        file_path = os.path.join(test_path, 
                                 f"mic",
                                 f"scaler_{name}.parquet")

        #################### TRAINING NN STRAIGHT AWAY
        log_dir = DATASETS[ds_name]['baseline_paths']['logs']
        user_log_path = os.path.join(log_dir, f"{name}.log")

        log= custom_log(name, user_log_path)
        for arch in ['small', 'medium', 'large', 'xl']:
                layers = NET_CONFIGS[arch]['layers']
                step_size= NET_CONFIGS[arch]['step_size']
                gamma= NET_CONFIGS[arch]['gamma']
                
                net_calibration(ds_name= ds_name,  
                        user_suffix= name, 
                        iter=None, 
                        target= DATASETS[ds_name]['target'] , 
                        train_set= train, 
                        val_set=val, 
                        feature_order=base_params['feature_order'], #without label 
                        net_layers=layers, 
                        net_params=DATASETS[ds_name]['net_params'], 
                        step_size=step_size,
                        gamma=gamma,
                        log=log,
                        device=device,
                        baseline= True)

# %%
base_params= {
    "cats": categoricals, #lst
    "num": numericals, #lss
    "warm_up_set": df_avv.copy(),
    "batch1": df_batch_1.copy(),
    "batch1_test": test_batch_1.copy(),
    "batch3":dfs['mic'].copy(),
    "validation_set": dfs['calibration'].copy(), #obtained by hic
    "feature_order": initial_ordering.copy(), #without the label ?
    "incremental_learner_name":"ARF",
    "n_cols": len(initial_ordering), #obtained by hic
    "mic_model_name": "Def_Net",
    "strat_1_name": "Confidence",
    "strat_2_name": "Mao",
    
}


learner_path= DATASETS[ds_name]['base_obj_paths']['incremental_learners']
path= os.path.join(learner_path, f"{base_params["incremental_learner_name"]}_model.pkl")
trained_learner= joblib.load(path)

prepr_path= DATASETS[ds_name]['base_obj_paths']['preprocessors']
path= os.path.join(prepr_path, f"{base_params["incremental_learner_name"]}_preprocessor.pkl")
base_prepr= joblib.load(path)

base_objects = {
      "preprocessor": copy.deepcopy(base_prepr), #or take from path
      "incremental_learner":copy.deepcopy(trained_learner), # or take from path
      "scaler": None
}

# %%
current_user_name= "accurate_trusting"
user_suffix= 'acc_t'

exp_path= fr".\trained_experts\{ds_name}\{name}.pkl"
current_expert= joblib.load(exp_path)


params = base_params.copy()  # Start with the base
params.update({
    "user_name": current_user_name,
    "user_suffix": user_suffix,
    "run_confidence": False,
    "run_mao": True
})

objects = base_objects.copy() # Start with the base clones
objects.update({
    "user_model": current_expert
})


def_net_layers= [32, 16]

batch3_path= DATASETS[ds_name]['paths']['scaled_mic_batch']
hic_df_general_path= DATASETS[ds_name]['paths']['hic_df_save_path']
mic_save_path = DATASETS[ds_name]['paths']['mic_df_save_path']

# %% [markdown]
# #### Tests

# %%
# retrieving assets 

current_dir = os.getcwd()
#repo_path = os.path.join(current_dir, "hdms-essai24", "L2Dcode")
repo_path = os.path.join(current_dir, "benchmark_helpers")
sys.path.append(repo_path)

from benchmark_helpers.lce_surrogate import LceSurrogate
from benchmark_helpers.basemethod import *

from benchmark_helpers.realizable_surrogate import RealizableSurrogate
from benchmark_helpers.metrics import *
from benchmark_helpers.functions import *

# %%
expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

net_layers= [32,16]
arch= 'medium'
params= base_params.copy()
params.update({
    "human_preds_col_name": "expert prediction",
})


methods= ['CrossEntropy']

for method in methods: 
    run_benchmark(ds_name=ds_name, 
                  users_lst= expert_names, 
                  method=method,  
                  layers=net_layers, 
                  architecture=arch,
                  device= device,
                  params=params)

# %%
experts_obj= {}
scaler= MinMaxScaler()
expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

res= {}
layers=[32, 16]

for name in expert_names:

        res[name]= {}

        #################### RETRIEVING OBJECTS

        # 1. NET PATHS
        net_path= DATASETS[ds_name]['baseline_paths']['trained_nets']
        net_path= os.path.join(net_path,
                               f"{name}_models",
                               f"{layers[0]}_{layers[1]}")
        pattern = f"{layers[0]}_{layers[1]}_model_*.pt"
        search_query = os.path.join(net_path, pattern)
        matches = glob.glob(search_query)

        if matches:
                net_path = max(matches, key=os.path.getctime)

        # 2. TEST DATA
        test_data_path= DATASETS[ds_name]['baseline_paths']['test_df_for_mic']
        test_data_path= os.path.join(test_data_path, 
                                     f"test_baseline_{name}.parquet")
        test_d= pd.read_parquet(test_data_path)


        # 4. BENCHMARKING LCE SURROGATE
        method= 'Realizable'
        _, real_test, real_def_metrics, real_clf_metrics, real_coverage_metrics= get_l2d_results_and_metrics(method= method, 
                                input_size= base_params['n_cols'],
                                layers=layers,
                                n_classes=NET_CONFIGS['output_size'], 
                                test_data= test_d,
                                device= device, 
                                path=net_path
                                )
        
        res[name][method]['deferral_metrics']= real_def_metrics
        res[name][method]['clf_metrics']= real_clf_metrics
        res[name][method]['coverage_metrics']= real_coverage_metrics

        # SAVING RESULTS

        save_dir= DATASETS[ds_name]['baseline_paths']['benchmark_res']
        os.makedirs(save_dir, exist_ok=True)
        save_dir= os.path.join(save_dir,
                               f"{method}", f"res_{name}.parquet"        
                               )
        
        results_df = pd.DataFrame(res[name][method])
        results_df.to_parquet(save_dir, index=False)
