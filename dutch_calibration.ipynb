# %% [markdown]
# # Dutch Census Dataset: Calibration ver
#
# In this notebook the optimal Deferral Net configuration is chosen, and the deferral tau threshold is calibrated.
#
# Following the BRIDGET experimental pipeline, the Deferral Net is trained on the data predicted by the Human-in-Command process, then subsequently tested on the validation data to produce the optimal Tau deferral coefficient.
#
# The architecture for the Nets to be tested are [(16, 8), (32, 16), (64, 32)].
#
# The optimizer used is ADAM
#
# The dropout rate was set to 0.2 to ensure the nets dont overfit initially, then tested up to 0.5

# %% [markdown]
# ### Libraries and functions

# %%
# retrieving all libraries
# %load_ext autoreload
# %autoreload 2




import os
import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optim
import seaborn as sns
import matplotlib.pyplot as plt
import random



from sklearn.metrics import accuracy_score, classification_report, confusion_matrix
from sklearn.preprocessing import StandardScaler, LabelEncoder
from sklearn.pipeline import Pipeline
from sklearn.compose import ColumnTransformer
from sklearn.model_selection import train_test_split
from sklearn.utils import shuffle

from river import rules, tree, datasets, drift, metrics, evaluate
from river import imblearn
from river import preprocessing
from river import metrics
from river import ensemble, linear_model, forest

from torchsummary import summary
from torch.utils.data import TensorDataset, DataLoader
from torch.optim.lr_scheduler import StepLR

from ignite.metrics import Accuracy, Loss
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator
from ignite.handlers import EarlyStopping, ModelCheckpoint
from ignite.contrib.handlers import global_step_from_engine


from xailib.models.sklearn_classifier_wrapper import sklearn_classifier_wrapper


from bridget_utils import *
from classes import BetaUser, DeferralNet, PyTorchWrapper, RiverModelWrapper
from b_xai_test import BRIDGET, HiC, MiC
# Out:
# The autoreload extension is already loaded. To reload it, use:
#   %reload_ext autoreload

# %%
def set_all_seeds(seed=42):
    
    random.seed(seed)
    np.random.seed(seed)
    os.environ['PYTHONHASHSEED'] = str(seed)
    
   
    try:
        import torch
        torch.manual_seed(seed)
        torch.cuda.manual_seed(seed)
        torch.cuda.manual_seed_all(seed)
        torch.backends.cudnn.deterministic = True
        torch.backends.cudnn.benchmark = False
    except ImportError:
        pass

set_all_seeds(42)

# %%
def plot_confusion_matrix(model, dataloader, device):
    model.eval()
    all_preds = []
    all_labels = []
    
    with torch.no_grad():
        for inputs, labels in dataloader:
            inputs, labels = inputs.to(device), labels.to(device)
            outputs = model(inputs)
            _, preds = torch.max(outputs, 1)
            all_preds.extend(preds.cpu().numpy())
            all_labels.extend(labels.cpu().numpy())
    
    cm = confusion_matrix(all_labels, all_preds)

    plt.figure(figsize=(6,4))
    sns.heatmap(cm, annot=True, fmt='d', cmap='Blues')
    plt.xlabel('Predictions')
    plt.ylabel('Ground Truths')
    plt.title('Confusion Matrix, DefNet')
    plt.show()
    
    print(classification_report(all_labels, all_preds))

# %%
device = torch.device("cuda" if torch.cuda.is_available() else "cpu")

# %% [markdown]
# ## Expert: Accurate, Trusting

# %% [markdown]
# ### Iter 1

# %%
# retrieving the calibration split 

iter=1
df_val= pd.read_csv(r"processed_data\dutch\calibration_datasets\iter_1\acc_t_calibration.csv")

# retrieving data

df_acc_t = pd.read_csv(r"processed_data\dutch\hic_results_ds\iter_1\hic_accurate_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_t_switch.csv")

df_acc_t.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_acc_t.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]


X_cal, y_cal, acc_t_loader = create_loader(df_acc_t, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1
#
# chosen_ 32/16 net

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.74

# %%
# Log config changes:

# stuck weights to zero, increased weight decay to 1e-4
# these nets dont need 50 epochs, they stabilize around 20/25
set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.0)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_t_models'
model_name= '16_8_acc_t'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, acc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=10, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.67 Avg loss: 0.68
# Validation Results - Epoch[1] Avg accuracy: 0.59 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.64 Avg loss: 0.67
# Validation Results - Epoch[2] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.66
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.66 Avg loss: 0.65
# Validation Results - Epoch[4] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Epoch[5], Iter[100] Loss: 0.66
# Training Results - Epoch[5] Avg accuracy: 0.70 Avg loss: 0.63
# Validation Results - Epoch[5] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.74 Avg loss: 0.61
# Validation Results - Epoch[6] Avg accuracy: 0.63 Avg loss: 0.66
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.76 Avg loss: 0.58
# Validation Results - Epoch[7] Avg accuracy: 0.64 Avg loss: 0.65
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.78 Avg loss: 0.56
# Validation Results - Epoch[8] Avg accuracy: 0.65 Avg loss: 0.64
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.81 Avg loss: 0.53
# Validation Results - Epoch[9] Avg accuracy: 0.67 Avg loss: 0.62
# End of Epoch 9: Learning Rate 0.001
# Epoch[10], Iter[200] Loss: 0.59
# Training Results - Epoch[10] Avg accuracy: 0.83 Avg loss: 0.50
# Validation Results - Epoch[10] Avg accuracy: 0.69 Avg loss: 0.60
# End of Epoch 10: Learning Rate 0.001
# Training Results - Epoch[11] Avg accuracy: 0.86 Avg loss: 0.47
# Validation Results - Epoch[11] Avg accuracy: 0.71 Avg loss: 0.59
# End of Epoch 11: Learning Rate 0.001
# Training Results - Epoch[12] Avg accuracy: 0.87 Avg loss: 0.44
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.58
# End of Epoch 12: Learning Rate 0.001
# Training Results - Epoch[13] Avg accuracy: 0.88 Avg loss: 0.42
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.58
# End of Epoch 13: Learning Rate 0.001
# Training Results - Epoch[14] Avg accuracy: 0.88 Avg loss: 0.40
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 14: Learning Rate 0.001
# Epoch[15], Iter[300] Loss: 0.56
# Training Results - Epoch[15] Avg accuracy: 0.88 Avg loss: 0.38
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.88 Avg loss: 0.37
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.88 Avg loss: 0.37
# Validation Results - Epoch[17] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.88 Avg loss: 0.36
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.88 Avg loss: 0.35
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 19: Learning Rate 0.0008
# Epoch[20], Iter[400] Loss: 0.57
# Training Results - Epoch[20] Avg accuracy: 0.88 Avg loss: 0.35
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.0008
#               precision    recall  f1-score   support
#
#            0       0.71      0.84      0.77      2026
#            1       0.75      0.59      0.66      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.71      0.72      3688
# weighted avg       0.73      0.73      0.72      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\acc_t_models\16_8_acc_t_model_20.pt' 
small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.76
# 0.8027003484320557

# %% [markdown]
# ##### Net 2: 32/16
#
# tau= 0.79

# %%
# Log config changes:

set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2

                    )

weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.00)
scheduler = StepLR(optimizer, step_size=10, gamma=0.8)

# %% [markdown]
# Training

# %%
set_all_seeds(42)
save_dir= fr'.\nets\dutch\iter_{iter}\acc_t_models'
model_name= '32_16_acc_t'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, acc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=10, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.64 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.56 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.64 Avg loss: 0.67
# Validation Results - Epoch[2] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.65
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.68 Avg loss: 0.63
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Epoch[5], Iter[100] Loss: 0.66
# Training Results - Epoch[5] Avg accuracy: 0.73 Avg loss: 0.61
# Validation Results - Epoch[5] Avg accuracy: 0.62 Avg loss: 0.66
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.76 Avg loss: 0.58
# Validation Results - Epoch[6] Avg accuracy: 0.64 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.80 Avg loss: 0.54
# Validation Results - Epoch[7] Avg accuracy: 0.66 Avg loss: 0.63
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.82 Avg loss: 0.49
# Validation Results - Epoch[8] Avg accuracy: 0.69 Avg loss: 0.60
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.86 Avg loss: 0.45
# Validation Results - Epoch[9] Avg accuracy: 0.71 Avg loss: 0.59
# End of Epoch 9: Learning Rate 0.001
# Epoch[10], Iter[200] Loss: 0.56
# Training Results - Epoch[10] Avg accuracy: 0.88 Avg loss: 0.41
# Validation Results - Epoch[10] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 10: Learning Rate 0.0008
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.39
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.58
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.88 Avg loss: 0.38
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.58
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.88 Avg loss: 0.37
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.88 Avg loss: 0.36
# Validation Results - Epoch[14] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 14: Learning Rate 0.0008
# Epoch[15], Iter[300] Loss: 0.58
# Training Results - Epoch[15] Avg accuracy: 0.88 Avg loss: 0.35
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 15: Learning Rate 0.0008
# Training Results - Epoch[16] Avg accuracy: 0.88 Avg loss: 0.35
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.88 Avg loss: 0.34
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.88 Avg loss: 0.34
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.62
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.34
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.62
# End of Epoch 19: Learning Rate 0.0008
# Epoch[20], Iter[400] Loss: 0.59
# Training Results - Epoch[20] Avg accuracy: 0.88 Avg loss: 0.34
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.62
# End of Epoch 20: Learning Rate 0.00064
#               precision    recall  f1-score   support
#
#            0       0.72      0.83      0.77      2026
#            1       0.74      0.61      0.67      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.72      0.72      3688
# weighted avg       0.73      0.73      0.72      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'nets\dutch\iter_{iter}\acc_t_models\32_16_acc_t_model_20.pt' 
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.79
# 0.8007008322382829

# %% [markdown]
# #### Deferral Strat 2
#
#
# thresh          acc           defer rate
#
# 38  0.318305       0.897519       0.169174
#
# 39  0.324576       0.891826       0.135014 <--- 5% def rate on real data
#
# 40  0.330847       0.888166       0.100447

# %%
set_all_seeds(42)
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_acc_t.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 
set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)


save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_acc_t.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.6412
# Epoch 2/20 - Loss: 0.5855
# Epoch 3/20 - Loss: 0.5426
# Epoch 4/20 - Loss: 0.5288
# Epoch 5/20 - Loss: 0.5276
# Epoch 6/20 - Loss: 0.5271
# Epoch 7/20 - Loss: 0.5281
# Epoch 8/20 - Loss: 0.5259
# Epoch 9/20 - Loss: 0.5279
# Epoch 10/20 - Loss: 0.5262
# Epoch 11/20 - Loss: 0.5228
# Epoch 12/20 - Loss: 0.5253
# Epoch 13/20 - Loss: 0.5244
# Epoch 14/20 - Loss: 0.5240
# Epoch 15/20 - Loss: 0.5236
# Epoch 16/20 - Loss: 0.5247
# Epoch 17/20 - Loss: 0.5232
# Epoch 18/20 - Loss: 0.5238
# Epoch 19/20 - Loss: 0.5218
# Epoch 20/20 - Loss: 0.5230
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_1

# %%
set_all_seeds(42)


p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

net_path= fr".\nets\dutch\iter_{iter}\acc_t_models\32_16_acc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.08, 0.45, 60)
calibration_results = []

for tr in thresholds:
    
    defer_mask = (p_defer_calib >= tr)
    
    # accuracy custom, applichi mask + fetch correct
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.080000       1.000000       0.999593
# 1   0.086271       1.000000       0.999593
# 2   0.092542       1.000000       0.999187
# 3   0.098814       1.000000       0.997967
# 4   0.105085       1.000000       0.995933
# 5   0.111356       1.000000       0.995933
# 6   0.117627       1.000000       0.994307
# 7   0.123898       1.000000       0.991460
# 8   0.130169       1.000000       0.987800
# 9   0.136441       1.000000       0.982513
# 10  0.142712       0.999593       0.975193
# 11  0.148983       0.999593       0.964620
# 12  0.155254       0.999187       0.952826
# 13  0.161525       0.997967       0.941846
# 14  0.167797       0.996747       0.925580
# 15  0.174068       0.996747       0.910126
# 16  0.180339       0.995933       0.891013
# 17  0.186610       0.994713       0.871899
# 18  0.192881       0.993087       0.840179
# 19  0.199153       0.990647       0.813339
# 20  0.205424       0.987393       0.787719
# 21  0.211695       0.986173       0.751525
# 22  0.217966       0.981293       0.713705
# 23  0.224237       0.976820       0.687678
# 24  0.230508       0.970720       0.659618
# 25  0.236780       0.967466       0.629931
# 26  0.243051       0.962586       0.596991
# 27  0.249322       0.956893       0.547784
# 28  0.255593       0.952826       0.501017
# 29  0.261864       0.943880       0.445710
# 30  0.268136       0.932900       0.384303
# 31  0.274407       0.924359       0.338349
# 32  0.280678       0.919479       0.307035
# 33  0.286949       0.912566       0.275722
# 34  0.293220       0.909719       0.252948
# 35  0.299492       0.908093       0.232208
# 36  0.305763       0.905653       0.211875
# 37  0.312034       0.901993       0.194795
# 38  0.318305       0.897519       0.169174
# 39  0.324576       0.891826       0.135014
# 40  0.330847       0.888166       0.100447
# 41  0.337119       0.886539       0.062627
# 42  0.343390       0.885319       0.028060
# 43  0.349661       0.884913       0.008133
# 44  0.355932       0.884913       0.001627
# 45  0.362203       0.884913       0.000000
# 46  0.368475       0.884913       0.000000
# 47  0.374746       0.884913       0.000000
# 48  0.381017       0.884913       0.000000
# 49  0.387288       0.884913       0.000000
# 50  0.393559       0.884913       0.000000
# 51  0.399831       0.884913       0.000000
# 52  0.406102       0.884913       0.000000
# 53  0.412373       0.884913       0.000000
# 54  0.418644       0.884913       0.000000
# 55  0.424915       0.884913       0.000000
# 56  0.431186       0.884913       0.000000
# 57  0.437458       0.884913       0.000000
# 58  0.443729       0.884913       0.000000
# 59  0.450000       0.884913       0.000000

# %% [markdown]
# ### Iter 2

# %%
# retrieving the calibration split 
iter=2

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 14: Learning Rate 0.0005
# Training Results - Epoch[15] Avg accuracy: 0.94 Avg loss: 0.34
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 15: Learning Rate 0.0005
# Epoch[16], Iter[300] Loss: 0.36
# Training Results - Epoch[16] Avg accuracy: 0.94 Avg loss: 0.33
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 16: Learning Rate 0.00025
# Training Results - Epoch[17] Avg accuracy: 0.94 Avg loss: 0.32
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 17: Learning Rate 0.00025
# Training Results - Epoch[18] Avg accuracy: 0.94 Avg loss: 0.31
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 18: Learning Rate 0.00025
# Training Results - Epoch[19] Avg accuracy: 0.95 Avg loss: 0.30
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 19: Learning Rate 0.00025
# Training Results - Epoch[20] Avg accuracy: 0.95 Avg loss: 0.30
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.00025
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.77      2026
#            1       0.73      0.65      0.68      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.72      0.72      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'.\nets\dutch\iter_2\acc_t_models\32_16_acc_t_model_20.pt'
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.77
# 0.7794806300553427

# %% [markdown]
# #### Deferral Strat 2
#
#
# 29  0.336735       0.957403       0.228288
#
# 30  0.344898       0.954508       0.196857
#
# 31  0.353061       0.951199       0.149297
#
# 32  0.361224       0.948718       0.098842

# %%
set_all_seeds(42)

def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_acc_t.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 

set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)

# %%
save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

set_all_seeds(42)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_acc_t.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.7060
# Epoch 2/20 - Loss: 0.6592
# Epoch 3/20 - Loss: 0.6234
# Epoch 4/20 - Loss: 0.6174
# Epoch 5/20 - Loss: 0.6174
# Epoch 6/20 - Loss: 0.6176
# Epoch 7/20 - Loss: 0.6173
# Epoch 8/20 - Loss: 0.6176
# Epoch 9/20 - Loss: 0.6173
# Epoch 10/20 - Loss: 0.6135
# Epoch 11/20 - Loss: 0.6140
# Epoch 12/20 - Loss: 0.6121
# Epoch 13/20 - Loss: 0.6105
# Epoch 14/20 - Loss: 0.6139
# Epoch 15/20 - Loss: 0.6131
# Epoch 16/20 - Loss: 0.6139
# Epoch 17/20 - Loss: 0.6109
# Epoch 18/20 - Loss: 0.6122
# Epoch 19/20 - Loss: 0.6116
# Epoch 20/20 - Loss: 0.6104
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_2

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\acc_t_models\32_16_acc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.5, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       0.999173       0.998759
# 1   0.108163       0.999173       0.998346
# 2   0.116327       0.998759       0.997105
# 3   0.124490       0.998346       0.995864
# 4   0.132653       0.998346       0.995451
# 5   0.140816       0.998346       0.995037
# 6   0.148980       0.998346       0.991729
# 7   0.157143       0.998346       0.988420
# 8   0.165306       0.998346       0.981390
# 9   0.173469       0.998346       0.975186
# 10  0.181633       0.997519       0.964433
# 11  0.189796       0.996278       0.948718
# 12  0.197959       0.995037       0.930108
# 13  0.206122       0.993797       0.897022
# 14  0.214286       0.992142       0.849876
# 15  0.222449       0.990488       0.803143
# 16  0.230612       0.989247       0.758065
# 17  0.238776       0.987179       0.738627
# 18  0.246939       0.985112       0.714227
# 19  0.255102       0.984285       0.691894
# 20  0.263265       0.982630       0.663358
# 21  0.271429       0.980976       0.633581
# 22  0.279592       0.980149       0.597188
# 23  0.287755       0.973532       0.522746
# 24  0.295918       0.967742       0.447477
# 25  0.304082       0.964020       0.369727
# 26  0.312245       0.961952       0.306038
# 27  0.320408       0.960298       0.275021
# 28  0.328571       0.959057       0.253515
# 29  0.336735       0.957403       0.228288
# 30  0.344898       0.954508       0.196857
# 31  0.353061       0.951199       0.149297
# 32  0.361224       0.948718       0.098842
# 33  0.369388       0.947477       0.045906
# 34  0.377551       0.946650       0.004136
# 35  0.385714       0.946650       0.000000
# 36  0.393878       0.946650       0.000000
# 37  0.402041       0.946650       0.000000
# 38  0.410204       0.946650       0.000000
# 39  0.418367       0.946650       0.000000
# 40  0.426531       0.946650       0.000000
# 41  0.434694       0.946650       0.000000
# 42  0.442857       0.946650       0.000000
# 43  0.451020       0.946650       0.000000
# 44  0.459184       0.946650       0.000000
# 45  0.467347       0.946650       0.000000
# 46  0.475510       0.946650       0.000000
# 47  0.483673       0.946650       0.000000
# 48  0.491837       0.946650       0.000000
# 49  0.500000       0.946650       0.000000

# %% [markdown]
# ### Iter 3

# %%
# retrieving the calibration split 
iter=3

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\acc_t_calibration.csv")

df_acc_t = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_accurate_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_t_switch.csv")

df_acc_t.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_acc_t.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, acc_t_loader = create_loader(df_acc_t, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.81

# %%
# Log config changes:


set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.15)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=8, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_t_models'
model_name= '16_8_acc_t'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, acc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.69 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.61 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.70 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.63 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.68 Avg loss: 0.67
# Validation Results - Epoch[3] Avg accuracy: 0.62 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.69 Avg loss: 0.66
# Validation Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.71 Avg loss: 0.64
# Validation Results - Epoch[5] Avg accuracy: 0.64 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.63
# Training Results - Epoch[6] Avg accuracy: 0.75 Avg loss: 0.61
# Validation Results - Epoch[6] Avg accuracy: 0.65 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.83 Avg loss: 0.59
# Validation Results - Epoch[7] Avg accuracy: 0.69 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.86 Avg loss: 0.55
# Validation Results - Epoch[8] Avg accuracy: 0.70 Avg loss: 0.62
# End of Epoch 8: Learning Rate 0.0008
# Training Results - Epoch[9] Avg accuracy: 0.90 Avg loss: 0.52
# Validation Results - Epoch[9] Avg accuracy: 0.72 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.0008
# Training Results - Epoch[10] Avg accuracy: 0.92 Avg loss: 0.49
# Validation Results - Epoch[10] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 10: Learning Rate 0.0008
# Epoch[11], Iter[200] Loss: 0.49
# Training Results - Epoch[11] Avg accuracy: 0.94 Avg loss: 0.45
# Validation Results - Epoch[11] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 11: Learning Rate 0.0008
# Training Results - Epoch[12] Avg accuracy: 0.94 Avg loss: 0.42
# Validation Results - Epoch[12] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 12: Learning Rate 0.0008
# Training Results - Epoch[13] Avg accuracy: 0.95 Avg loss: 0.39
# Validation Results - Epoch[13] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 13: Learning Rate 0.0008
# Training Results - Epoch[14] Avg accuracy: 0.95 Avg loss: 0.36
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.56
# End of Epoch 14: Learning Rate 0.0008
# Training Results - Epoch[15] Avg accuracy: 0.95 Avg loss: 0.34
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 15: Learning Rate 0.0008
# Epoch[16], Iter[300] Loss: 0.34
# Training Results - Epoch[16] Avg accuracy: 0.95 Avg loss: 0.32
# Validation Results - Epoch[16] Avg accuracy: 0.74 Avg loss: 0.57
# End of Epoch 16: Learning Rate 0.00064
# Training Results - Epoch[17] Avg accuracy: 0.95 Avg loss: 0.30
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 17: Learning Rate 0.00064
# Training Results - Epoch[18] Avg accuracy: 0.95 Avg loss: 0.29
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 18: Learning Rate 0.00064
# Training Results - Epoch[19] Avg accuracy: 0.96 Avg loss: 0.28
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 19: Learning Rate 0.00064
# Training Results - Epoch[20] Avg accuracy: 0.96 Avg loss: 0.27
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.00064
#               precision    recall  f1-score   support
#
#            0       0.74      0.79      0.77      2026
#            1       0.73      0.66      0.69      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.73      0.73      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\acc_t_models\16_8_acc_t_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.81
# 0.78965819456617

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.81

# %%
## instantiating the Deferral Net structures + Dropout rate 0.2 e Early Stopping
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.2)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=8, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_t_models'
model_name= '32_16_acc_t'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, acc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.52 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.60 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.63 Avg loss: 0.66
# Validation Results - Epoch[3] Avg accuracy: 0.58 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_3

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= 11, hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\acc_t_models\32_16_acc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.45, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       1.000000       1.000000
# 1   0.107143       1.000000       1.000000
# 2   0.114286       1.000000       1.000000
# 3   0.121429       1.000000       1.000000
# 4   0.128571       1.000000       1.000000
# 5   0.135714       1.000000       0.999170
# 6   0.142857       1.000000       0.999170
# 7   0.150000       1.000000       0.998340
# 8   0.157143       1.000000       0.996680
# 9   0.164286       1.000000       0.992946
# 10  0.171429       1.000000       0.989627
# 11  0.178571       1.000000       0.984647
# 12  0.185714       0.999585       0.980083
# 13  0.192857       0.999170       0.971784
# 14  0.200000       0.999170       0.963071
# 15  0.207143       0.997510       0.950207
# 16  0.214286       0.996680       0.937344
# 17  0.221429       0.996680       0.922407
# 18  0.228571       0.995436       0.907054
# 19  0.235714       0.995021       0.891286
# 20  0.242857       0.992531       0.876349
# 21  0.250000       0.991286       0.853527
# 22  0.257143       0.989627       0.829046
# 23  0.264286       0.987552       0.801660
# 24  0.271429       0.984232       0.762241
# 25  0.278571       0.983402       0.730705
# 26  0.285714       0.980498       0.692531
# 27  0.292857       0.976763       0.648548
# 28  0.300000       0.975104       0.602075
# 29  0.307143       0.973444       0.563485
# 30  0.314286       0.971369       0.526141
# 31  0.321429       0.970539       0.485477
# 32  0.328571       0.968050       0.445643
# 33  0.335714       0.965560       0.390456
# 34  0.342857       0.962241       0.337759
# 35  0.350000       0.959751       0.273029
# 36  0.357143       0.957261       0.199170
# 37  0.364286       0.955602       0.148133
# 38  0.371429       0.953527       0.100415
# 39  0.378571       0.952697       0.051867
# 40  0.385714       0.952282       0.025311
# 41  0.392857       0.950622       0.003320
# 42  0.400000       0.950622       0.000000
# 43  0.407143       0.950622       0.000000
# 44  0.414286       0.950622       0.000000
# 45  0.421429       0.950622       0.000000
# 46  0.428571       0.950622       0.000000
# 47  0.435714       0.950622       0.000000
# 48  0.442857       0.950622       0.000000
# 49  0.450000       0.950622       0.000000

# %% [markdown]
# ## Expert: Inaccurate, Trusting

# %% [markdown]
# ### Iter 1

# %%
iter=1
df_val= pd.read_csv(r"processed_data\dutch\calibration_datasets\iter_1\inacc_t_calibration.csv")

# retrieving data

df_inacc_t = pd.read_csv(r"processed_data\dutch\hic_results_ds\iter_1\hic_inaccurate_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_switch.csv")

df_inacc_t.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_t.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, inacc_t_loader = create_loader(df_inacc_t, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1
#
# chosen_ 32/16 net

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.53

# %%
# the signal from the user this time is not good, more weight is needed for class 1
set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.3)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.0005,
                       weight_decay=1e-3

                    )


weights = torch.tensor([1.0, 2.2]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=7, gamma=0.5)

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_t_models'
model_name= '16_8_inacc_t'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, inacc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=10, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.41 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.49 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.0005
# Training Results - Epoch[2] Avg accuracy: 0.45 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.51 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.0005
# Training Results - Epoch[3] Avg accuracy: 0.50 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.0005
# Training Results - Epoch[4] Avg accuracy: 0.58 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.60 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.75
# 0.7828746177370031

# %% [markdown]
# #### Deferral Strat 2
#
#
#     thresh         acc           defer rate
#
# 37  0.444915       0.888166       0.178935
#
# 38  0.454237       0.883693       0.138674
#
# 39  0.463559       0.882879       0.116307
#
# 40  0.472881       0.882066       0.100447

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_t.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 
set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)


save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_t.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.6757
# Epoch 2/20 - Loss: 0.6642
# Epoch 3/20 - Loss: 0.6629
# Epoch 4/20 - Loss: 0.6612
# Epoch 5/20 - Loss: 0.6593
# Epoch 6/20 - Loss: 0.6582
# Epoch 7/20 - Loss: 0.6573
# Epoch 8/20 - Loss: 0.6551
# Epoch 9/20 - Loss: 0.6543
# Epoch 10/20 - Loss: 0.6540
# Epoch 11/20 - Loss: 0.6514
# Epoch 12/20 - Loss: 0.6516
# Epoch 13/20 - Loss: 0.6505
# Epoch 14/20 - Loss: 0.6492
# Epoch 15/20 - Loss: 0.6485
# Epoch 16/20 - Loss: 0.6477
# Epoch 17/20 - Loss: 0.6472
# Epoch 18/20 - Loss: 0.6465
# Epoch 19/20 - Loss: 0.6460
# Epoch 20/20 - Loss: 0.6453

# %%
set_all_seeds(42)


p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

net_path= fr".\nets\dutch\iter_{iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.65, 60)
calibration_results = []

for tr in thresholds:
    
    defer_mask = (p_defer_calib >= tr)
    
    # accuracy custom, applichi mask + fetch correct
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       1.000000       0.996747
# 1   0.109322       1.000000       0.995120
# 2   0.118644       1.000000       0.993900
# 3   0.127966       1.000000       0.992680
# 4   0.137288       1.000000       0.990240
# 5   0.146610       0.999187       0.984953
# 6   0.155932       0.999187       0.982107
# 7   0.165254       0.997967       0.977227
# 8   0.174576       0.997153       0.973566
# 9   0.183898       0.997153       0.968686
# 10  0.193220       0.995933       0.959740
# 11  0.202542       0.995120       0.950793
# 12  0.211864       0.994307       0.938186
# 13  0.221186       0.991867       0.924766
# 14  0.230508       0.990647       0.912973
# 15  0.239831       0.990647       0.903619
# 16  0.249153       0.989833       0.891013
# 17  0.258475       0.988613       0.877186
# 18  0.267797       0.986173       0.860512
# 19  0.277119       0.981700       0.841399
# 20  0.286441       0.977633       0.812525
# 21  0.295763       0.971940       0.780805
# 22  0.305085       0.967873       0.749898
# 23  0.314407       0.963806       0.720618
# 24  0.323729       0.961366       0.690931
# 25  0.333051       0.958113       0.660838
# 26  0.342373       0.953233       0.626678
# 27  0.351695       0.942253       0.588044
# 28  0.361017       0.931273       0.542497
# 29  0.370339       0.925986       0.507930
# 30  0.379661       0.919886       0.457910
# 31  0.388983       0.917039       0.417649
# 32  0.398305       0.912566       0.372916
# 33  0.407627       0.908906       0.331436
# 34  0.416949       0.905246       0.298495
# 35  0.426271       0.899553       0.258642
# 36  0.435593       0.893859       0.221228
# 37  0.444915       0.888166       0.178935
# 38  0.454237       0.883693       0.138674
# 39  0.463559       0.882879       0.116307
# 40  0.472881       0.882066       0.100447
# 41  0.482203       0.880846       0.084994
# 42  0.491525       0.880846       0.068727
# 43  0.500847       0.879626       0.058560
# 44  0.510169       0.877999       0.047987
# 45  0.519492       0.876779       0.038634
# 46  0.528814       0.872712       0.000000
# 47  0.538136       0.872712       0.000000
# 48  0.547458       0.872712       0.000000
# 49  0.556780       0.872712       0.000000
# 50  0.566102       0.872712       0.000000
# 51  0.575424       0.872712       0.000000
# 52  0.584746       0.872712       0.000000
# 53  0.594068       0.872712       0.000000
# 54  0.603390       0.872712       0.000000
# 55  0.612712       0.872712       0.000000
# 56  0.622034       0.872712       0.000000
# 57  0.631356       0.872712       0.000000
# 58  0.640678       0.872712       0.000000
# 59  0.650000       0.872712       0.000000

# %% [markdown]
# ### Iter 2

# %%
# retrieving the calibration split 
iter=2

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\inacc_t_calibration.csv")

df_inacc_t = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_inaccurate_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_switch.csv")

df_inacc_t.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_t.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, inacc_t_loader = create_loader(df_inacc_t, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.54

# %%
# Log config changes:
# lowered weightss for class 1

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.3)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.0005,
                       weight_decay=1e-3

                    )


weights = torch.tensor([1.0, 1.8]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=7, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_t_models'
model_name= '16_8_inacc_t'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, inacc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.43 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.48 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.0005
# Training Results - Epoch[2] Avg accuracy: 0.45 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.51 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.0005
# Training Results - Epoch[3] Avg accuracy: 0.52 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 3: Learning Rate 0.0005
# Training Results - Epoch[4] Avg accuracy: 0.61 Avg loss: 0.68
# Validation Results - Epoch[4] Avg accuracy: 0.60 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.0005
# Training Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.68
# Validation Results - Epoch[5] Avg accuracy: 0.63 Avg loss: 0.68
# End of Epoch 5: Learning Rate 0.0005
# Epoch[6], Iter[100] Loss: 0.67
# Training Results - Epoch[6] Avg accuracy: 0.76 Avg loss: 0.67
# Validation Results - Epoch[6] Avg accuracy: 0.68 Avg loss: 0.68
# End of Epoch 6: Learning Rate 0.0005
# Training Results - Epoch[7] Avg accuracy: 0.83 Avg loss: 0.66
# Validation Results - Epoch[7] Avg accuracy: 0.70 Avg loss: 0.68
# End of Epoch 7: Learning Rate 0.00025
# Training Results - Epoch[8] Avg accuracy: 0.84 Avg loss: 0.66
# Validation Results - Epoch[8] Avg accuracy: 0.70 Avg loss: 0.67
# End of Epoch 8: Learning Rate 0.00025
# Training Results - Epoch[9] Avg accuracy: 0.83 Avg loss: 0.65
# Validation Results - Epoch[9] Avg accuracy: 0.69 Avg loss: 0.67
# End of Epoch 9: Learning Rate 0.00025
# Training Results - Epoch[10] Avg accuracy: 0.84 Avg loss: 0.65
# Validation Results - Epoch[10] Avg accuracy: 0.69 Avg loss: 0.67
# End of Epoch 10: Learning Rate 0.00025
# Epoch[11], Iter[200] Loss: 0.66
# Training Results - Epoch[11] Avg accuracy: 0.85 Avg loss: 0.64
# Validation Results - Epoch[11] Avg accuracy: 0.70 Avg loss: 0.67
# End of Epoch 11: Learning Rate 0.00025
# Training Results - Epoch[12] Avg accuracy: 0.85 Avg loss: 0.64
# Validation Results - Epoch[12] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 12: Learning Rate 0.00025
# Training Results - Epoch[13] Avg accuracy: 0.86 Avg loss: 0.63
# Validation Results - Epoch[13] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 13: Learning Rate 0.00025
# Training Results - Epoch[14] Avg accuracy: 0.86 Avg loss: 0.62
# Validation Results - Epoch[14] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 14: Learning Rate 0.000125
# Training Results - Epoch[15] Avg accuracy: 0.86 Avg loss: 0.62
# Validation Results - Epoch[15] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 15: Learning Rate 0.000125
# Epoch[16], Iter[300] Loss: 0.62
# Training Results - Epoch[16] Avg accuracy: 0.87 Avg loss: 0.61
# Validation Results - Epoch[16] Avg accuracy: 0.70 Avg loss: 0.65
# End of Epoch 16: Learning Rate 0.000125
# Training Results - Epoch[17] Avg accuracy: 0.87 Avg loss: 0.61
# Validation Results - Epoch[17] Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 17: Learning Rate 0.000125
# Training Results - Epoch[18] Avg accuracy: 0.87 Avg loss: 0.61
# Validation Results - Epoch[18] Avg accuracy: 0.70 Avg loss: 0.65
# End of Epoch 18: Learning Rate 0.000125
# Training Results - Epoch[19] Avg accuracy: 0.87 Avg loss: 0.60
# Validation Results - Epoch[19] Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 19: Learning Rate 0.000125
# Training Results - Epoch[20] Avg accuracy: 0.87 Avg loss: 0.60
# Validation Results - Epoch[20] Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 20: Learning Rate 0.000125
#               precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75      2026
#            1       0.71      0.59      0.64      1662
#
#     accuracy                           0.71      3688
#    macro avg       0.71      0.70      0.70      3688
# weighted avg       0.71      0.71      0.70      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\inacc_t_models\16_8_inacc_t_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.54
# 0.7615550755939525

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.74

# %%
# Log:

# reduced gamma to 0.5
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2
                    )

weights = torch.tensor([1.0, 2.0]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=8, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_t_models'
model_name= '32_16_inacc_t'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, inacc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.35 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.45 Avg loss: 0.68
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.35 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.45 Avg loss: 0.67
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.36 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.46 Avg loss: 0.67
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.58 Avg loss: 0.67
# Validation Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.76 Avg loss: 0.65
# Validation Results - Epoch[5] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.65
# Training Results - Epoch[6] Avg accuracy: 0.85 Avg loss: 0.63
# Validation Results - Epoch[6] Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.87 Avg loss: 0.59
# Validation Results - Epoch[7] Avg accuracy: 0.70 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.88 Avg loss: 0.54
# Validation Results - Epoch[8] Avg accuracy: 0.71 Avg loss: 0.62
# End of Epoch 8: Learning Rate 0.0005
# Training Results - Epoch[9] Avg accuracy: 0.88 Avg loss: 0.52
# Validation Results - Epoch[9] Avg accuracy: 0.71 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.0005
# Training Results - Epoch[10] Avg accuracy: 0.88 Avg loss: 0.49
# Validation Results - Epoch[10] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 10: Learning Rate 0.0005
# Epoch[11], Iter[200] Loss: 0.48
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.46
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 11: Learning Rate 0.0005
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.44
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 12: Learning Rate 0.0005
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.42
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 13: Learning Rate 0.0005
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.40
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 14: Learning Rate 0.0005
# Training Results - Epoch[15] Avg accuracy: 0.89 Avg loss: 0.39
# Validation Results - Epoch[15] Avg accuracy: 0.72 Avg loss: 0.61
# End of Epoch 15: Learning Rate 0.0005
# Epoch[16], Iter[300] Loss: 0.37
# Training Results - Epoch[16] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 16: Learning Rate 0.00025
# Training Results - Epoch[17] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 17: Learning Rate 0.00025
# Training Results - Epoch[18] Avg accuracy: 0.89 Avg loss: 0.36
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 18: Learning Rate 0.00025
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.36
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 19: Learning Rate 0.00025
# Training Results - Epoch[20] Avg accuracy: 0.89 Avg loss: 0.35
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 20: Learning Rate 0.00025
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76      2026
#            1       0.72      0.64      0.68      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.72      0.72      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'.\nets\dutch\iter_2\inacc_t_models\32_16_inacc_t_model_20.pt'
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.74
# 0.7728265618173875

# %% [markdown]
# #### Deferral Strat 2
#
# 23  0.387755       0.911911       0.246898
#
# 24  0.395918       0.905707       0.190240
#
# 25  0.404082       0.901158       0.143921
#
# 26  0.412245       0.897022       0.098015

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_t.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 

set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.20)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)

save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_t.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.7816
# Epoch 2/20 - Loss: 0.7556
# Epoch 3/20 - Loss: 0.7440
# Epoch 4/20 - Loss: 0.7451
# Epoch 5/20 - Loss: 0.7442
# Epoch 6/20 - Loss: 0.7431
# Epoch 7/20 - Loss: 0.7436
# Epoch 8/20 - Loss: 0.7417
# Epoch 9/20 - Loss: 0.7427
# Epoch 10/20 - Loss: 0.7390
# Epoch 11/20 - Loss: 0.7402
# Epoch 12/20 - Loss: 0.7393
# Epoch 13/20 - Loss: 0.7406
# Epoch 14/20 - Loss: 0.7397
# Epoch 15/20 - Loss: 0.7399
# Epoch 16/20 - Loss: 0.7404
# Epoch 17/20 - Loss: 0.7383
# Epoch 18/20 - Loss: 0.7378
# Epoch 19/20 - Loss: 0.7406
# Epoch 20/20 - Loss: 0.7391
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_2

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= 11, hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.2, 0.6, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.200000       1.000000       1.000000
# 1   0.208163       1.000000       1.000000
# 2   0.216327       1.000000       1.000000
# 3   0.224490       1.000000       0.999173
# 4   0.232653       0.999586       0.998759
# 5   0.240816       0.998759       0.997932
# 6   0.248980       0.998346       0.995864
# 7   0.257143       0.998346       0.991729
# 8   0.265306       0.997932       0.986766
# 9   0.273469       0.997519       0.977667
# 10  0.281633       0.996691       0.969810
# 11  0.289796       0.995451       0.954921
# 12  0.297959       0.992142       0.932589
# 13  0.306122       0.988834       0.889165
# 14  0.314286       0.983871       0.837469
# 15  0.322449       0.980149       0.783706
# 16  0.330612       0.974773       0.733664
# 17  0.338776       0.967328       0.669562
# 18  0.346939       0.952026       0.583540
# 19  0.355102       0.939620       0.496278
# 20  0.363265       0.930521       0.420596
# 21  0.371429       0.923490       0.358974
# 22  0.379592       0.917287       0.301075
# 23  0.387755       0.911911       0.246898
# 24  0.395918       0.905707       0.190240
# 25  0.404082       0.901158       0.143921
# 26  0.412245       0.897022       0.098015
# 27  0.420408       0.893300       0.043838
# 28  0.428571       0.887510       0.008271
# 29  0.436735       0.887510       0.000827
# 30  0.444898       0.887510       0.000000
# 31  0.453061       0.887510       0.000000
# 32  0.461224       0.887510       0.000000
# 33  0.469388       0.887510       0.000000
# 34  0.477551       0.887510       0.000000
# 35  0.485714       0.887510       0.000000
# 36  0.493878       0.887510       0.000000
# 37  0.502041       0.887510       0.000000
# 38  0.510204       0.887510       0.000000
# 39  0.518367       0.887510       0.000000
# 40  0.526531       0.887510       0.000000
# 41  0.534694       0.887510       0.000000
# 42  0.542857       0.887510       0.000000
# 43  0.551020       0.887510       0.000000
# 44  0.559184       0.887510       0.000000
# 45  0.567347       0.887510       0.000000
# 46  0.575510       0.887510       0.000000
# 47  0.583673       0.887510       0.000000
# 48  0.591837       0.887510       0.000000
# 49  0.600000       0.887510       0.000000

# %% [markdown]
# ### Iter 3

# %%
# retrieving the calibration split 
iter=3

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\inacc_t_calibration.csv")

df_inacc_t = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_inaccurate_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_switch.csv")

df_inacc_t.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_t.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, acc_t_loader = create_loader(df_inacc_t, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.54

# %%
set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.3)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0
Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 20: Learning Rate 0.000125
#               precision    recall  f1-score   support
#
#            0       0.70      0.81      0.75      2026
#            1       0.71      0.59      0.64      1662
#
#     accuracy                           0.71      3688
#    macro avg       0.71      0.70      0.70      3688
# weighted avg       0.71      0.71      0.70      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\inacc_t_models\16_8_inacc_t_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.54
# 0.7615550755939525

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.74

# %%
## instantiating the Deferral Net structures + Dropout rate 0.2 e Early Stopping
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2
                    )

weights = torch.tensor([1.0, 2.0]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=8, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_t_models'
model_name= '32_16_inacc_t'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, inacc_t_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.35 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.45 Avg loss: 0.68
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.35 Avg loss: 0.69
# Validation Results - Epoch[2] Avg accuracy: 0.45 Avg loss: 0.67
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.36 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.46 Avg loss: 0.67
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.58 Avg loss: 0.67
# Validation Results - Epoch[4] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.76 Avg loss: 0.65
# Validation Results - Epoch[5] Avg accuracy: 0.70 Avg loss: 0.66
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.65
# Training Results - Epoch[6] Avg accuracy: 0.85 Avg loss: 0.63
# Validation Results - Epoch[6] Avg accuracy: 0.71 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.87 Avg loss: 0.59
# Validation Results - Epoch[7] Avg accuracy: 0.70 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.88 Avg loss: 0.54
# Validation Results - Epoch[8] Avg accuracy: 0.71 Avg loss: 0.62
# End of Epoch 8: Learning Rate 0.0005
# Training Results - Epoch[9] Avg accuracy: 0.88 Avg loss: 0.52
# Validation Results - Epoch[9] Avg accuracy: 0.71 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.0005
# Training Results - Epoch[10] Avg accuracy: 0.88 Avg loss: 0.49
# Validation Results - Epoch[10] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 10: Learning Rate 0.0005
# Epoch[11], Iter[200] Loss: 0.48
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.46
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 11: Learning Rate 0.0005
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.44
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 12: Learning Rate 0.0005
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.42
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 13: Learning Rate 0.0005
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.40
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 14: Learning Rate 0.0005
# Training Results - Epoch[15] Avg accuracy: 0.89 Avg loss: 0.39
# Validation Results - Epoch[15] Avg accuracy: 0.72 Avg loss: 0.61
# End of Epoch 15: Learning Rate 0.0005
# Epoch[16], Iter[300] Loss: 0.37
# Training Results - Epoch[16] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 16: Learning Rate 0.00025
# Training Results - Epoch[17] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 17: Learning Rate 0.00025
# Training Results - Epoch[18] Avg accuracy: 0.89 Avg loss: 0.36
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 18: Learning Rate 0.00025
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.36
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 19: Learning Rate 0.00025
# Training Results - Epoch[20] Avg accuracy: 0.89 Avg loss: 0.35
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.61
# End of Epoch 20: Learning Rate 0.00025
#               precision    recall  f1-score   support
#
#            0       0.73      0.80      0.76      2026
#            1       0.72      0.64      0.68      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.72      0.72      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'.\nets\dutch\iter_3\inacc_t_models\32_16_inacc_t_model_20.pt'
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.74
# 0.7728265618173875

# %% [markdown]
# #### Deferral Strat 2
#
# tau             acc           def rate
#
# 24  0.395918       0.928216       0.250622
#
# 25  0.404082       0.923237       0.216598
#
# 26  0.412245       0.917842       0.177593
#
# 27  0.420408       0.914108       0.130705

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_t.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 

set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)

# %%
save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_t.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.7645
# Epoch 2/20 - Loss: 0.7397
# Epoch 3/20 - Loss: 0.7322
# Epoch 4/20 - Loss: 0.7296
# Epoch 5/20 - Loss: 0.7298
# Epoch 6/20 - Loss: 0.7291
# Epoch 7/20 - Loss: 0.7283
# Epoch 8/20 - Loss: 0.7271
# Epoch 9/20 - Loss: 0.7285
# Epoch 10/20 - Loss: 0.7255
# Epoch 11/20 - Loss: 0.7286
# Epoch 12/20 - Loss: 0.7271
# Epoch 13/20 - Loss: 0.7269
# Epoch 14/20 - Loss: 0.7270
# Epoch 15/20 - Loss: 0.7252
# Epoch 16/20 - Loss: 0.7280
# Epoch 17/20 - Loss: 0.7274
# Epoch 18/20 - Loss: 0.7269
# Epoch 19/20 - Loss: 0.7235
# Epoch 20/20 - Loss: 0.7253
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_3

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.2, 0.6, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.200000       1.000000       1.000000
# 1   0.208163       1.000000       1.000000
# 2   0.216327       1.000000       0.999585
# 3   0.224490       1.000000       0.999585
# 4   0.232653       1.000000       0.999170
# 5   0.240816       0.999170       0.997925
# 6   0.248980       0.999170       0.995851
# 7   0.257143       0.998340       0.993361
# 8   0.265306       0.998340       0.985062
# 9   0.273469       0.997925       0.975934
# 10  0.281633       0.997925       0.966805
# 11  0.289796       0.997510       0.955602
# 12  0.297959       0.996266       0.940664
# 13  0.306122       0.993361       0.900000
# 14  0.314286       0.990871       0.857261
# 15  0.322449       0.987552       0.805809
# 16  0.330612       0.984232       0.755187
# 17  0.338776       0.981328       0.708299
# 18  0.346939       0.979253       0.663485
# 19  0.355102       0.974689       0.608714
# 20  0.363265       0.969710       0.540249
# 21  0.371429       0.953942       0.434025
# 22  0.379592       0.939834       0.337759
# 23  0.387755       0.931950       0.282573
# 24  0.395918       0.928216       0.250622
# 25  0.404082       0.923237       0.216598
# 26  0.412245       0.917842       0.177593
# 27  0.420408       0.914108       0.130705
# 28  0.428571       0.908299       0.076349
# 29  0.436735       0.904149       0.041079
# 30  0.444898       0.902905       0.016183
# 31  0.453061       0.900830       0.003320
# 32  0.461224       0.900000       0.000000
# 33  0.469388       0.900000       0.000000
# 34  0.477551       0.900000       0.000000
# 35  0.485714       0.900000       0.000000
# 36  0.493878       0.900000       0.000000
# 37  0.502041       0.900000       0.000000
# 38  0.510204       0.900000       0.000000
# 39  0.518367       0.900000       0.000000
# 40  0.526531       0.900000       0.000000
# 41  0.534694       0.900000       0.000000
# 42  0.542857       0.900000       0.000000
# 43  0.551020       0.900000       0.000000
# 44  0.559184       0.900000       0.000000
# 45  0.567347       0.900000       0.000000
# 46  0.575510       0.900000       0.000000
# 47  0.583673       0.900000       0.000000
# 48  0.591837       0.900000       0.000000
# 49  0.600000       0.900000       0.000000

# %% [markdown]
# ## Expert: Accurate, Not Trusting

# %% [markdown]
# ### Iter 1

# %%
# retrieving the calibration split 

iter=1
df_val= pd.read_csv(r"processed_data\dutch\calibration_datasets\iter_1\acc_nt_calibration.csv")

# retrieving data

df_acc_nt = pd.read_csv(r"processed_data\dutch\hic_results_ds\iter_1\hic_accurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_switch.csv")

df_acc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_acc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, acc_nt_loader = create_loader(df_acc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1
#
# chosen_ 32/16 net

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.69

# %%
# Log:
# same net as acc t

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.0)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_nt_models'
model_name= '16_8_acc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, acc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=10, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.67 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.61 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.71 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.66 Avg loss: 0.68
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.73 Avg loss: 0.67
# Validation Results - Epoch[3] Avg accuracy: 0.67 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.74 Avg loss: 0.67
# Validation Results - Epoch[4] Avg accuracy: 0.67 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Epoch[5], Iter[100] Loss: 0.67
# Training Results - Epoch[5] Avg accuracy: 0.74 Avg loss: 0.65
# Validation Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0
Avg accuracy: 0.74 Avg loss: 0.55
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.83 Avg loss: 0.44
# Validation Results - Epoch[18] Avg accuracy: 0.74 Avg loss: 0.55
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.83 Avg loss: 0.44
# Validation Results - Epoch[19] Avg accuracy: 0.74 Avg loss: 0.55
# End of Epoch 19: Learning Rate 0.0008
# Epoch[20], Iter[400] Loss: 0.57
# Training Results - Epoch[20] Avg accuracy: 0.83 Avg loss: 0.44
# Validation Results - Epoch[20] Avg accuracy: 0.74 Avg loss: 0.55
# End of Epoch 20: Learning Rate 0.00064
#               precision    recall  f1-score   support
#
#            0       0.74      0.81      0.77      2026
#            1       0.73      0.65      0.69      1662
#
#     accuracy                           0.74      3688
#    macro avg       0.74      0.73      0.73      3688
# weighted avg       0.74      0.74      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'nets\dutch\iter_{iter}\acc_nt_models\32_16_acc_nt_model_20.pt' 
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.73
# 0.797723292469352

# %% [markdown]
# #### Deferral Strat 2
#
#
#     thresh          acc           defer rate
#
# 41  0.202034       0.846686       0.159414
#
# 42  0.205254       0.843432       0.143148
#
# 43  0.208475       0.840179       0.126474
#
# 44  0.211695       0.838959       0.117527
#
# 45  0.214915       0.836926       0.104107

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_acc_nt.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 
set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)


save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_acc_nt.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.4591
# Epoch 2/20 - Loss: 0.4162
# Epoch 3/20 - Loss: 0.4081
# Epoch 4/20 - Loss: 0.4084
# Epoch 5/20 - Loss: 0.4075
# Epoch 6/20 - Loss: 0.4064
# Epoch 7/20 - Loss: 0.4071
# Epoch 8/20 - Loss: 0.4067
# Epoch 9/20 - Loss: 0.4062
# Epoch 10/20 - Loss: 0.4067
# Epoch 11/20 - Loss: 0.4022
# Epoch 12/20 - Loss: 0.4043
# Epoch 13/20 - Loss: 0.4047
# Epoch 14/20 - Loss: 0.4034
# Epoch 15/20 - Loss: 0.4012
# Epoch 16/20 - Loss: 0.4028
# Epoch 17/20 - Loss: 0.4032
# Epoch 18/20 - Loss: 0.4022
# Epoch 19/20 - Loss: 0.4016
# Epoch 20/20 - Loss: 0.4028
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_1

# %%
set_all_seeds(42)


p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

net_path= fr".\nets\dutch\iter_{iter}\acc_nt_models\32_16_acc_nt_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.07, 0.26, 60) # ofc adjusted the zooming only to interesting areas of the search
calibration_results = []

for tr in thresholds:
    
    defer_mask = (p_defer_calib >= tr)
    
    # accuracy custom, applichi mask + fetch correct
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.070000       0.999187       0.988207
# 1   0.073220       0.999187       0.986173
# 2   0.076441       0.999187       0.983327
# 3   0.079661       0.998780       0.977633
# 4   0.082881       0.998780       0.971940
# 5   0.086102       0.998780       0.968686
# 6   0.089322       0.998373       0.964620
# 7   0.092542       0.997967       0.960960
# 8   0.095763       0.997560       0.954046
# 9   0.098983       0.997560       0.944693
# 10  0.102203       0.997153       0.935746
# 11  0.105424       0.996340       0.924359
# 12  0.108644       0.995527       0.908906
# 13  0.111864       0.995120       0.896299
# 14  0.115085       0.992680       0.881253
# 15  0.118305       0.991053       0.864172
# 16  0.121525       0.990647       0.847499
# 17  0.124746       0.989020       0.832452
# 18  0.127966       0.986987       0.812119
# 19  0.131186       0.984140       0.790159
# 20  0.134407       0.981700       0.767792
# 21  0.137627       0.976413       0.738918
# 22  0.140847       0.969093       0.712485
# 23  0.144068       0.963400       0.680765
# 24  0.147288       0.958926       0.653111
# 25  0.150508       0.953233       0.626678
# 26  0.153729       0.949573       0.604311
# 27  0.156949       0.945100       0.574624
# 28  0.160169       0.941033       0.550224
# 29  0.163390       0.935340       0.525010
# 30  0.166610       0.929646       0.494103
# 31  0.169831       0.916226       0.452216
# 32  0.173051       0.905246       0.413176
# 33  0.176271       0.897113       0.381456
# 34  0.179492       0.890606       0.349736
# 35  0.182712       0.884506       0.319642
# 36  0.185932       0.876779       0.284262
# 37  0.189153       0.869459       0.256608
# 38  0.192373       0.861732       0.227328
# 39  0.195593       0.858072       0.208215
# 40  0.198814       0.852379       0.181781
# 41  0.202034       0.846686       0.159414
# 42  0.205254       0.843432       0.143148
# 43  0.208475       0.840179       0.126474
# 44  0.211695       0.838959       0.117527
# 45  0.214915       0.836926       0.104107
# 46  0.218136       0.836112       0.091501
# 47  0.221356       0.835299       0.078487
# 48  0.224576       0.833672       0.065880
# 49  0.227797       0.832046       0.049614
# 50  0.231017       0.831232       0.045140
# 51  0.234237       0.831232       0.041480
# 52  0.237458       0.830826       0.036600
# 53  0.240678       0.830012       0.031720
# 54  0.243898       0.829606       0.029280
# 55  0.247119       0.829199       0.026027
# 56  0.250339       0.829199       0.025214
# 57  0.253559       0.829199       0.021960
# 58  0.256780       0.829199       0.020333
# 59  0.260000       0.828792       0.017893

# %% [markdown]
# ### Iter 2

# %%
# retrieving the calibration split 
iter=2

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\acc_nt_calibration.csv")

df_acc_nt = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_accurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_switch.csv")

df_acc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_acc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, acc_nt_loader = create_loader(df_acc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.79

# %%
# Log config changes:

# questa rete non ha neanche bisogno di label smoothing nè peso in più alla classe 1, produce risultati discreti

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.15)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_nt_models'
model_name= '16_8_acc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, acc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.68 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.60 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.73 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.65 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.74 Avg loss: 0.67
# Validation Results - Epoch[3] Avg accuracy: 0.66 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.76 Avg loss: 0.66
# Validation Results - Epoch[4] Avg accuracy: 0.66 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.76 Avg loss: 0.64
# Validation Results - Epoch[5] Avg accuracy: 0.66 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.65
# Training Results - Epoch[6] Avg accuracy: 0.76 Avg loss: 0.62
# Validation Results - Epoch[6] Avg accuracy: 0.66 Avg loss: 0.66
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.82 Avg loss: 0.60
# Validation Results - Epoch[7] Avg accuracy: 0.68 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.86 Avg loss: 0.57
# Validation Results - Epoch[8] Avg accuracy: 0.71 Avg loss: 0.63
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.87 Avg loss: 0.54
# Validation Results - Epoch[9] Avg accuracy: 0.71 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.001
# Training Results - Epoch[10] Avg accuracy: 0.89 Avg loss: 0.50
# Validation Results - Epoch[10] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 10: Learning Rate 0.001
# Epoch[11], Iter[200] Loss: 0.52
# Training Results - Epoch[11] Avg accuracy: 0.90 Avg loss: 0.47
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.58
# End of Epoch 11: Learning Rate 0.001
# Training Results - Epoch[12] Avg accuracy: 0.90 Avg loss: 0.43
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.57
# End of Epoch 12: Learning Rate 0.001
# Training Results - Epoch[13] Avg accuracy: 0.90 Avg loss: 0.40
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.57
# End of Epoch 13: Learning Rate 0.001
# Training Results - Epoch[14] Avg accuracy: 0.90 Avg loss: 0.38
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 14: Learning Rate 0.001
# Training Results - Epoch[15] Avg accuracy: 0.90 Avg loss: 0.36
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 15: Learning Rate 0.0008
# Epoch[16], Iter[300] Loss: 0.39
# Training Results - Epoch[16] Avg accuracy: 0.91 Avg loss: 0.35
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.90 Avg loss: 0.34
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.90 Avg loss: 0.33
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.90 Avg loss: 0.32
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 19: Learning Rate 0.0008
# Training Results - Epoch[20] Avg accuracy: 0.90 Avg loss: 0.31
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 20: Learning Rate 0.0008
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77      2026
#            1       0.73      0.65      0.69      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.73      0.73      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\acc_nt_models\16_8_acc_nt_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.79
# 0.7923351158645277

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.81

# %%
## instantiating the Deferral Net structures + Dropout rate 0.2 e Early Stopping
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.25)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2

                    )

weights = torch.tensor([1.0, 1.0]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.00)
scheduler = StepLR(optimizer, step_size=10, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc
 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       0.999586       0.997105
# 1   0.106122       0.999173       0.993797
# 2   0.112245       0.998346       0.986352
# 3   0.118367       0.997932       0.981390
# 4   0.124490       0.997105       0.976013
# 5   0.130612       0.996691       0.968983
# 6   0.136735       0.994624       0.949132
# 7   0.142857       0.993383       0.927626
# 8   0.148980       0.991729       0.906534
# 9   0.155102       0.988420       0.869727
# 10  0.161224       0.986352       0.825889
# 11  0.167347       0.982217       0.769231
# 12  0.173469       0.978908       0.711745
# 13  0.179592       0.976013       0.658395
# 14  0.185714       0.971878       0.591811
# 15  0.191837       0.963606       0.517370
# 16  0.197959       0.952026       0.428453
# 17  0.204082       0.943342       0.354425
# 18  0.210204       0.936725       0.302316
# 19  0.216327       0.933002       0.265509
# 20  0.222449       0.929280       0.229115
# 21  0.228571       0.923077       0.185277
# 22  0.234694       0.917287       0.150538
# 23  0.240816       0.914806       0.117039
# 24  0.246939       0.912324       0.076923
# 25  0.253061       0.910670       0.040943
# 26  0.259184       0.908602       0.016543
# 27  0.265306       0.906121       0.004963
# 28  0.271429       0.905294       0.000000
# 29  0.277551       0.905294       0.000000
# 30  0.283673       0.905294       0.000000
# 31  0.289796       0.905294       0.000000
# 32  0.295918       0.905294       0.000000
# 33  0.302041       0.905294       0.000000
# 34  0.308163       0.905294       0.000000
# 35  0.314286       0.905294       0.000000
# 36  0.320408       0.905294       0.000000
# 37  0.326531       0.905294       0.000000
# 38  0.332653       0.905294       0.000000
# 39  0.338776       0.905294       0.000000
# 40  0.344898       0.905294       0.000000
# 41  0.351020       0.905294       0.000000
# 42  0.357143       0.905294       0.000000
# 43  0.363265       0.905294       0.000000
# 44  0.369388       0.905294       0.000000
# 45  0.375510       0.905294       0.000000
# 46  0.381633       0.905294       0.000000
# 47  0.387755       0.905294       0.000000
# 48  0.393878       0.905294       0.000000
# 49  0.400000       0.905294       0.000000

# %% [markdown]
# ### Iter 3

# %%
# retrieving the calibration split 
iter=3

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\acc_nt_calibration.csv")

df_acc_nt = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_accurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_switch.csv")

df_acc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_acc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, acc_nt_loader = create_loader(df_acc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.8

# %%
# Log config changes:
# nothing
set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.15)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\acc_nt_models'
model_name= '16_8_acc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, acc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.69 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.61 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.70 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.63 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.68 Avg loss: 0.67
# Validation Results - Epoch[3] Avg accuracy: 0.61 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.70 Avg loss: 0.66
# Validation Results - Epoch[4] Avg accuracy: 0.63 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.71 Avg loss: 0.64
# Validation Results - Epoch[5] Avg accuracy: 0.64 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.63
# Training Results - Epoch[6] Avg accuracy: 0.76 Avg loss: 0.62
# Validation Results - Epoch[6] Avg accuracy: 0.65 Avg loss: 0.66
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.82 Avg loss: 0.60
# Validation Results - Epoch[7] Avg accuracy: 0.68 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.84 Avg loss: 0.57
# Validation Results - Epoch[8] Avg accuracy: 0.69 Avg loss: 0.63
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.87 Avg loss: 0.54
# Validation Results - Epoch[9] Avg accuracy: 0.71 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.001
# Training Results - Epoch[10] Avg accuracy: 0.89 Avg loss: 0.50
# Validation Results - Epoch[10] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 10: Learning Rate 0.001
# Epoch[11], Iter[200] Loss: 0.56
# Training Results - Epoch[11] Avg accuracy: 0.90 Avg loss: 0.47
# Validation Results - Epoch[11] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 11: Learning Rate 0.001
# Training Results - Epoch[12] Avg accuracy: 0.90 Avg loss: 0.43
# Validation Results - Epoch[12] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 12: Learning Rate 0.001
# Training Results - Epoch[13] Avg accuracy: 0.91 Avg loss: 0.41
# Validation Results - Epoch[13] Avg accuracy: 0.73 Avg loss: 0.56
# End of Epoch 13: Learning Rate 0.001
# Training Results - Epoch[14] Avg accuracy: 0.91 Avg loss: 0.38
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.56
# End of Epoch 14: Learning Rate 0.001
# Training Results - Epoch[15] Avg accuracy: 0.91 Avg loss: 0.37
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 15: Learning Rate 0.0008
# Epoch[16], Iter[300] Loss: 0.45
# Training Results - Epoch[16] Avg accuracy: 0.91 Avg loss: 0.35
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.91 Avg loss: 0.35
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.57
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.91 Avg loss: 0.34
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.91 Avg loss: 0.33
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch
model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.5, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       1.000000       1.000000
# 1   0.108163       1.000000       0.999585
# 2   0.116327       1.000000       0.997095
# 3   0.124490       1.000000       0.995851
# 4   0.132653       1.000000       0.992946
# 5   0.140816       1.000000       0.982573
# 6   0.148980       1.000000       0.975104
# 7   0.157143       0.998755       0.956017
# 8   0.165306       0.994606       0.901660
# 9   0.173469       0.991701       0.867635
# 10  0.181633       0.991286       0.842739
# 11  0.189796       0.985477       0.779253
# 12  0.197959       0.978423       0.699170
# 13  0.206122       0.971784       0.638174
# 14  0.214286       0.958506       0.520332
# 15  0.222449       0.945643       0.385062
# 16  0.230612       0.936515       0.311618
# 17  0.238776       0.931120       0.270124
# 18  0.246939       0.923237       0.219917
# 19  0.255102       0.917842       0.149793
# 20  0.263265       0.912448       0.070539
# 21  0.271429       0.911203       0.032780
# 22  0.279592       0.908714       0.008299
# 23  0.287755       0.907884       0.000415
# 24  0.295918       0.907469       0.000000
# 25  0.304082       0.907469       0.000000
# 26  0.312245       0.907469       0.000000
# 27  0.320408       0.907469       0.000000
# 28  0.328571       0.907469       0.000000
# 29  0.336735       0.907469       0.000000
# 30  0.344898       0.907469       0.000000
# 31  0.353061       0.907469       0.000000
# 32  0.361224       0.907469       0.000000
# 33  0.369388       0.907469       0.000000
# 34  0.377551       0.907469       0.000000
# 35  0.385714       0.907469       0.000000
# 36  0.393878       0.907469       0.000000
# 37  0.402041       0.907469       0.000000
# 38  0.410204       0.907469       0.000000
# 39  0.418367       0.907469       0.000000
# 40  0.426531       0.907469       0.000000
# 41  0.434694       0.907469       0.000000
# 42  0.442857       0.907469       0.000000
# 43  0.451020       0.907469       0.000000
# 44  0.459184       0.907469       0.000000
# 45  0.467347       0.907469       0.000000
# 46  0.475510       0.907469       0.000000
# 47  0.483673       0.907469       0.000000
# 48  0.491837       0.907469       0.000000
# 49  0.500000       0.907469       0.000000

# %% [markdown]
# ## Expert: Inaccurate, Not Trusting

# %% [markdown]
# ### Iter 1

# %%
# retrieving the calibration split 

iter=1
df_val= pd.read_csv(r"processed_data\dutch\calibration_datasets\iter_1\inacc_nt_calibration.csv")

# retrieving data

df_inacc_nt = pd.read_csv(r"processed_data\dutch\hic_results_ds\iter_1\hic_inaccurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_switch.csv")

df_inacc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, inacc_nt_loader = create_loader(df_inacc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1
#
# chosen_ 32/16 net

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.6

# %%
# Log:
# same config as accurate models. it seems the inaccurate, trusting user did some real damage

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.0)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_nt_models'
model_name= '16_8_inacc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, inacc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=10, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.66 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.61 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.69 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.65 Avg loss: 0.68
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.71 Avg loss: 0.68
# Validation Results - Epoch[3] Avg accuracy: 0.66 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.72 Avg loss: 0.67
# Validation Results - Epoch[4] Avg accuracy: 0.67 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Epoch[5], Iter[100] Loss: 0.66
# Training Results - Epoch[5] Avg accuracy: 0.72 Avg loss: 0.66
# Validation Results - Epoch[5] Avg accuracy: 0.67 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Training Results - Epoch[6] Avg accuracy: 0.74 Avg loss: 0.64
# Validation Results - Epoch[6] Avg accuracy: 0.68 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.75 Avg loss: 0.63
# Validation Results - Epoch[7] Avg accuracy: 0.70 Avg loss: 0.64
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.76 Avg loss: 0.61
# Validation Results - Epoch[8] Avg accuracy: 0.71 Avg loss: 0.63
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.6799999999999999
# 0.7953242170269078

# %% [markdown]
# #### Deferral Strat 2
#
#
#     thresh          acc           defer rate
#
# 44  0.249153       0.806425       0.176901
#
# 45  0.252542       0.795852       0.126881
#
# 46  0.255932       0.784465       0.089061

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_nt.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 
set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)


save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(30):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_nt.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.5129
# Epoch 2/20 - Loss: 0.4836
# Epoch 3/20 - Loss: 0.4773
# Epoch 4/20 - Loss: 0.4761
# Epoch 5/20 - Loss: 0.4743
# Epoch 6/20 - Loss: 0.4749
# Epoch 7/20 - Loss: 0.4774
# Epoch 8/20 - Loss: 0.4749
# Epoch 9/20 - Loss: 0.4751
# Epoch 10/20 - Loss: 0.4767
# Epoch 11/20 - Loss: 0.4735
# Epoch 12/20 - Loss: 0.4742
# Epoch 13/20 - Loss: 0.4732
# Epoch 14/20 - Loss: 0.4736
# Epoch 15/20 - Loss: 0.4722
# Epoch 16/20 - Loss: 0.4727
# Epoch 17/20 - Loss: 0.4707
# Epoch 18/20 - Loss: 0.4728
# Epoch 19/20 - Loss: 0.4732
# Epoch 20/20 - Loss: 0.4729
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_1

# %%
set_all_seeds(42)


p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

net_path= fr".\nets\dutch\iter_{iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.30, 60) # ofc adjusted the zooming only to interesting areas of the search
calibration_results = []

for tr in thresholds:
    
    defer_mask = (p_defer_calib >= tr)
    
    # accuracy custom, applichi mask + fetch correct
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       1.000000       0.997967
# 1   0.103390       1.000000       0.997967
# 2   0.106780       1.000000       0.997967
# 3   0.110169       1.000000       0.997153
# 4   0.113559       0.999593       0.994713
# 5   0.116949       0.998780       0.993493
# 6   0.120339       0.998780       0.992680
# 7   0.123729       0.998780       0.991867
# 8   0.127119       0.998780       0.991460
# 9   0.130508       0.998373       0.990240
# 10  0.133898       0.997967       0.989020
# 11  0.137288       0.997967       0.987800
# 12  0.140678       0.997967       0.986580
# 13  0.144068       0.997560       0.985360
# 14  0.147458       0.997560       0.984547
# 15  0.150847       0.997560       0.982920
# 16  0.154237       0.997153       0.979667
# 17  0.157627       0.997153       0.978040
# 18  0.161017       0.997153       0.976007
# 19  0.164407       0.996340       0.972753
# 20  0.167797       0.995120       0.968686
# 21  0.171186       0.993493       0.964620
# 22  0.174576       0.992680       0.959333
# 23  0.177966       0.991460       0.953640
# 24  0.181356       0.989427       0.949166
# 25  0.184746       0.989427       0.942660
# 26  0.188136       0.988207       0.935746
# 27  0.191525       0.985767       0.925986
# 28  0.194915       0.982920       0.912566
# 29  0.198305       0.979667       0.895893
# 30  0.201695       0.976820       0.875153
# 31  0.205085       0.973566       0.855632
# 32  0.208475       0.969500       0.838959
# 33  0.211864       0.964620       0.810492
# 34  0.215254       0.954453       0.780399
# 35  0.218644       0.942660       0.733225
# 36  0.222034       0.932900       0.683205
# 37  0.225424       0.919886       0.626271
# 38  0.228814       0.904026       0.558357
# 39  0.232203       0.887353       0.488817
# 40  0.235593       0.870679       0.430256
# 41  0.238983       0.857259       0.366002
# 42  0.242373       0.840179       0.303782
# 43  0.245763       0.823912       0.236682
# 44  0.249153       0.806425       0.176901
# 45  0.252542       0.795852       0.126881
# 46  0.255932       0.784465       0.089061
# 47  0.259322       0.779992       0.057747
# 48  0.262712       0.777552       0.038227
# 49  0.266102       0.771858       0.021147
# 50  0.269492       0.769825       0.012200
# 51  0.272881       0.769012       0.006507
# 52  0.276271       0.768605       0.002033
# 53  0.279661       0.768198       0.000000
# 54  0.283051       0.768198       0.000000
# 55  0.286441       0.768198       0.000000
# 56  0.289831       0.768198       0.000000
# 57  0.293220       0.768198       0.000000
# 58  0.296610       0.768198       0.000000
# 59  0.300000       0.768198       0.000000

# %% [markdown]
# ### Iter 2

# %%
# retrieving the calibration split 
iter=2

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\inacc_nt_calibration.csv")

df_inacc_nt = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_inaccurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_switch.csv")

df_inacc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, inacc_nt_loader = create_loader(df_inacc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.76

# %%
# Log config changes:

# ok in this setting i actually had to weigh up the majority class
# the res highlights the negative feedback the inaccurate, not trusting user is providing the net
# the most aggravating of the two is probably not trusting HiC

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.0)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_nt_models'
model_name= '16_8_inacc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, inacc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.68 Avg loss: 0.68
# Validation Results - Epoch[1] Avg accuracy: 0.60 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.64 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.56 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.66
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.66 Avg loss: 0.65
# Validation Results - Epoch[4] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.70 Avg loss: 0.63
# Validation Results - Epoch[5] Avg accuracy: 0.60 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.63
# Training Results - Epoch[6] Avg accuracy: 0.74 Avg loss: 0.61
# Validation Results - Epoch[6] Avg accuracy: 0.63 Avg loss: 0.66
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.76 Avg loss: 0.59
# Validation Results - Epoch[7] Avg accuracy: 0.63 Avg loss: 0.65
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.76 Avg loss: 0.57
# Validation Results - Epoch[8] Avg accuracy: 0.64 Avg loss: 0.64
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.78 Avg loss: 0.54
# Validation Results - Epoch[9] Avg accuracy: 0.65 Avg loss: 0.63
# End of Epoch 9: Learning Rate 0.001
# Training Results - Epoch[10] Avg accuracy: 0.82 Avg loss: 0.51
# Validation Results - Epoch[10] Avg accuracy: 0.68 Avg loss: 0.62
# End of Epoch 10: Learning Rate 0.001
# Epoch[11], Iter[200] Loss: 0.49
# Training Results - Epoch[11] Avg accuracy: 0.87 Avg loss: 0.48
# Validation Results - Epoch[11] Avg accuracy: 0.71 Avg loss: 0.60
# End of Epoch 11: Learning Rate 0.001
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.45
# Validation Results - Epoch[12] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 12: Learning Rate 0.001
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.42
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 13: Learning Rate 0.001
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.40
# Validation Results - Epoch[14] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 14: Learning Rate 0.001
# Training Results - Epoch[15] Avg accuracy: 0.89 Avg loss: 0.38
# Validation Results - Epoch[15] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 15: Learning Rate 0.0008
# Epoch[16], Iter[300] Loss: 0.36
# Training Results - Epoch[16] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[16] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.89 Avg loss: 0.36
# Validation Results - Epoch[17] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.89 Avg loss: 0.35
# Validation Results - Epoch[18] Avg accuracy: 0.72 Avg loss: 0.61
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.34
# Validation Results - Epoch[19] Avg accuracy: 0.72 Avg loss: 0.61
# End of Epoch 19: Learning Rate 0.0008
# Training Results - Epoch[20] Avg accuracy: 0.89 Avg loss: 0.33
# Validation Results - Epoch[20] Avg accuracy: 0.72 Avg loss: 0.62
# End of Epoch 20: Learning Rate 0.0008
#               precision    recall  f1-score   support
#
#            0       0.70      0.84      0.77      2026
#            1       0.75      0.57      0.65      1662
#
#     accuracy                           0.72      3688
#    macro avg       0.73      0.71      0.71      3688
# weighted avg       0.72      0.72      0.71      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\inacc_nt_models\16_8_inacc_nt_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.76
# 0.7842881944444444

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.72

# %%
# only increased dropout to 0.25, decreased step size to 7 and gamma to 0.5
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2

                    )

weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.00)
scheduler = StepLR(optimizer, step_size=7, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_nt_models'
model_name= '32_16_inacc_nt'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, inacc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.63 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.56 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.63 Avg loss: 0.67
# Validation Results - Epoch[2] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.66
# Validation Results - Epoch[3] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.68 Avg loss: 0.64
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.73 Avg loss: 0.62
# Validation Results - Epoch[5] Avg accuracy: 0.62 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.62
# Training Results - Epoch[6] Avg accuracy: 0.76 Avg loss: 0.58
# Validation Results - Epoch[6] Avg accuracy: 0.64 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.77 Avg loss: 0.55
# Validation Results - Epoch[7] Avg accuracy: 0.65 Avg loss: 0.63
# End of Epoch 7: Learning Rate 0.0005
# Training Results - Epoch[8] Avg accuracy: 0.79 Avg loss: 0.52
# Validation Results - Epoch[8] Avg accuracy: 0.66 Avg loss: 0.62
# End of Epoch 8: Learning Rate 0.0005
# Training Results - Epoch[9] Avg accuracy: 0.80 Avg loss: 0.50
# Validation Results - Epoch[9] Avg accuracy: 0.67 Avg loss: 0.62
# End of Epoch 9: Learning Rate 0.0005
# Training Results - Epoch[10] Avg accuracy: 0.84 Avg loss: 0.48
# Validation Results - Epoch[10] Avg accuracy: 0.68 Avg loss: 0.61
# End of Epoch 10: Learning Rate 0.0005
# Epoch[11], Iter[200] Loss: 0.46
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.46
# Validation Results - Epoch[11] Avg accuracy: 0.70 Avg loss: 0.60
# End of Epoch 11: Learning Rate 0.0005
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.44
# Validation Results - Epoch[12] Avg accuracy: 0.71 Avg loss: 0.60
# End of Epoch 12: Learning Rate 0.0005
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.42
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 13: Learning Rate 0.0005
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.40
# Validation Results - Epoch[14] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 14: Learning Rate 0.00025
# Training Results - Epoch[15] Avg accuracy: 0.89 Avg loss: 0.40
# Validation Results - Epoch[15] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 15: Learning Rate 0.00025
# Epoch[16], Iter[300] Loss: 0.39
# Training Results - Epoch[16] Avg accuracy: 0.89 Avg loss: 0.39
# Validation Results - Epoch[16] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 16: Learning Rate 0.00025
# Training Results - Epoch[17] Avg accuracy: 0.89 Avg loss: 0.38
# Validation Results - Epoch[17] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 17: Learning Rate 0.00025
# Training Results - Epoch[18] Avg accuracy: 0.89 Avg loss: 0.38
# Validation Results - Epoch[18] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 18: Learning Rate 0.00025
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[19] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 19: Learning Rate 0.00025
# Training Results - Epoch[20] Avg accuracy: 0.89 Avg loss: 0.37
# Validation Results - Epoch[20] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.00025
#               precision    recall  f1-score   support
#
#            0       0.70      0.85      0.77      2026
#            1       0.75      0.56      0.64      1662
#
#     accuracy                           0.72      3688
#    macro avg       0.73      0.70      0.70      3688
# weighted avg       0.72      0.72      0.71      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'.\nets\dutch\iter_2\inacc_nt_models\32_16_inacc_nt_model_20.pt'
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.72
# 0.7817236899090515

# %% [markdown]
# #### Deferral Strat 2
#
#     tau             acc          defer rate
#
# 28  0.271429       0.906121       0.208437
#
# 29  0.277551       0.899504       0.174111
#
# 30  0.283673       0.896195       0.129859

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_nt.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 

set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)

# %%
save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_nt.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.6314
# Epoch 2/20 - Loss: 0.5740
# Epoch 3/20 - Loss: 0.5251
# Epoch 4/20 - Loss: 0.5063
# Epoch 5/20 - Loss: 0.5064
# Epoch 6/20 - Loss: 0.5092
# Epoch 7/20 - Loss: 0.5057
# Epoch 8/20 - Loss: 0.5102
# Epoch 9/20 - Loss: 0.5091
# Epoch 10/20 - Loss: 0.5045
# Epoch 11/20 - Loss: 0.5055
# Epoch 12/20 - Loss: 0.5050
# Epoch 13/20 - Loss: 0.5050
# Epoch 14/20 - Loss: 0.5052
# Epoch 15/20 - Loss: 0.5041
# Epoch 16/20 - Loss: 0.5066
# Epoch 17/20 - Loss: 0.5061
# Epoch 18/20 - Loss: 0.5044
# Epoch 19/20 - Loss: 0.5055
# Epoch 20/20 - Loss: 0.5043
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_2

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.1, 0.4, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.100000       1.000000       1.000000
# 1   0.106122       1.000000       1.000000
# 2   0.112245       1.000000       1.000000
# 3   0.118367       0.999586       0.998759
# 4   0.124490       0.999586       0.998759
# 5   0.130612       0.999586       0.996278
# 6   0.136735       0.999173       0.994210
# 7   0.142857       0.999173       0.991315
# 8   0.148980       0.998759       0.985112
# 9   0.155102       0.997105       0.978081
# 10  0.161224       0.997105       0.971464
# 11  0.167347       0.994624       0.959057
# 12  0.173469       0.993797       0.938379
# 13  0.179592       0.990488       0.909429
# 14  0.185714       0.984285       0.871381
# 15  0.191837       0.980149       0.833333
# 16  0.197959       0.976840       0.782051
# 17  0.204082       0.972705       0.742763
# 18  0.210204       0.968569       0.698925
# 19  0.216327       0.962779       0.641853
# 20  0.222449       0.953267       0.576510
# 21  0.228571       0.943342       0.501654
# 22  0.234694       0.932589       0.421009
# 23  0.240816       0.927213       0.357734
# 24  0.246939       0.922663       0.322167
# 25  0.253061       0.919355       0.293631
# 26  0.259184       0.917287       0.268817
# 27  0.265306       0.914806       0.237800
# 28  0.271429       0.906121       0.208437
# 29  0.277551       0.899504       0.174111
# 30  0.283673       0.896195       0.129859
# 31  0.289796       0.892887       0.088916
# 32  0.295918       0.891646       0.051282
# 33  0.302041       0.889992       0.025227
# 34  0.308163       0.889578       0.011993
# 35  0.314286       0.889578       0.004963
# 36  0.320408       0.888751       0.000414
# 37  0.326531       0.888337       0.000000
# 38  0.332653       0.888337       0.000000
# 39  0.338776       0.888337       0.000000
# 40  0.344898       0.888337       0.000000
# 41  0.351020       0.888337       0.000000
# 42  0.357143       0.888337       0.000000
# 43  0.363265       0.888337       0.000000
# 44  0.369388       0.888337       0.000000
# 45  0.375510       0.888337       0.000000
# 46  0.381633       0.888337       0.000000
# 47  0.387755       0.888337       0.000000
# 48  0.393878       0.888337       0.000000
# 49  0.400000       0.888337       0.000000

# %% [markdown]
# ### Iter 3

# %%
# retrieving the calibration split 
iter=3

df_val= pd.read_csv(fr".\processed_data\dutch\calibration_datasets\iter_{iter}\inacc_nt_calibration.csv")

df_inacc_nt = pd.read_csv(fr"processed_data\dutch\hic_results_ds\iter_{iter}\hic_inaccurate_not_trusting.csv")

path= f".\processed_data\dutch\switch_ds\iter_{iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_switch.csv")

df_inacc_nt.to_csv(file_path, index=False)

# %%
feat_order = [c for c in df_inacc_nt.columns if c not in [
    'occupation', 'ground truth', 
    'proba_model', 'provider', 'machine prediction', 'expert prediction']]

X_cal, y_cal, inacc_nt_loader = create_loader(df_inacc_nt, feat_order, 'occupation', batch_size=128, shuffle=False)

X_val, y_val, val_loader = create_loader(df_val, feat_order, 'occupation', batch_size=128, shuffle=False)

# %% [markdown]
# #### Deferral Strat 1

# %% [markdown]
# ##### Net 1: 16/8
#
# tau= 0.77

# %%
# Log config changes:
# needs weight again and 3.0 is too little
# this one's going nowhere

set_all_seeds(42)

small_net= DeferralNet(input_size=X_cal.shape[1], hidden_layer1= 16, hidden_layer2= 8, output_size=2, dropout_coeff=0.0)

small_net.to(device)

optimizer = optim.Adam(params=small_net.parameters(),
                       lr=0.001,
                       weight_decay=1e-2

                    )


weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.0)
scheduler = StepLR(optimizer, step_size=15, gamma=0.8)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_nt_models'
model_name= '16_8_inacc_nt'

training_history, validation_history = net_trainer(small_net, optimizer,
                                             criterion, device, inacc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(small_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.68 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.60 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.64 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.57 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.64 Avg loss: 0.67
# Validation Results - Epoch[3] Avg accuracy: 0.57 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.66 Avg loss: 0.66
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.68
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.70 Avg loss: 0.64
# Validation Results - Epoch[5] Avg accuracy: 0.61 Avg loss: 0.67
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.63
# Training Results - Epoch[6] Avg accuracy: 0.72 Avg loss: 0.62
# Validation Results - Epoch[6] Avg accuracy: 0.63 Avg loss: 0.66
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.74 Avg loss: 0.60
# Validation Results - Epoch[7] Avg accuracy: 0.65 Avg loss: 0.65
# End of Epoch 7: Learning Rate 0.001
# Training Results - Epoch[8] Avg accuracy: 0.79 Avg loss: 0.58
# Validation Results - Epoch[8] Avg accuracy: 0.67 Avg loss: 0.64
# End of Epoch 8: Learning Rate 0.001
# Training Results - Epoch[9] Avg accuracy: 0.83 Avg loss: 0.54
# Validation Results - Epoch[9] Avg accuracy: 0.69 Avg loss: 0.62
# End of Epoch 9: Learning Rate 0.001
# Training Results - Epoch[10] Avg accuracy: 0.86 Avg loss: 0.51
# Validation Results - Epoch[10] Avg accuracy: 0.71 Avg loss: 0.60
# End of Epoch 10: Learning Rate 0.001
# Epoch[11], Iter[200] Loss: 0.50
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.48
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 11: Learning Rate 0.001
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.45
# Validation Results - Epoch[12] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 12: Learning Rate 0.001
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.43
# Validation Results - Epoch[13] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 13: Learning Rate 0.001
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.41
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 14: Learning Rate 0.001
# Training Results - Epoch[15] Avg accuracy: 0.90 Avg loss: 0.39
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 15: Learning Rate 0.0008
# Epoch[16], Iter[300] Loss: 0.42
# Training Results - Epoch[16] Avg accuracy: 0.90 Avg loss: 0.38
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.58
# End of Epoch 16: Learning Rate 0.0008
# Training Results - Epoch[17] Avg accuracy: 0.90 Avg loss: 0.37
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 17: Learning Rate 0.0008
# Training Results - Epoch[18] Avg accuracy: 0.90 Avg loss: 0.36
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 18: Learning Rate 0.0008
# Training Results - Epoch[19] Avg accuracy: 0.90 Avg loss: 0.36
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 19: Learning Rate 0.0008
# Training Results - Epoch[20] Avg accuracy: 0.90 Avg loss: 0.35
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.0008
#               precision    recall  f1-score   support
#
#            0       0.74      0.80      0.77      2026
#            1       0.73      0.65      0.69      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.73      0.73      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
model_path = fr'.\nets\dutch\iter_{iter}\inacc_nt_models\16_8_inacc_nt_model_20.pt' 

small_net.load_state_dict(torch.load(model_path))
small_net.eval()

with torch.no_grad():
   probas= small_net.predict_proba_nn(X_val, device)
   y_pred= small_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.77
# 0.7803234501347709

# %% [markdown]
# ##### Net 2: 32/16
#
# tau 0.72

# %%
# yet again, need to weigh class 0 to 5.0 + introduce label smoothing

# terrible results but possibly justified by the user
set_all_seeds(42)

large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.0)

large_net.to(device)

optimizer = optim.Adam(params=large_net.parameters(),
                       lr=0.001,
                       weight_decay= 1e-2

                    )

weights = torch.tensor([1.0, 1.25]).to(device)
criterion= nn.CrossEntropyLoss(weight=weights, label_smoothing=0.00)
scheduler = StepLR(optimizer, step_size=7, gamma=0.5)

# %% [markdown]
# Training

# %%
save_dir= fr'.\nets\dutch\iter_{iter}\inacc_nt_models'
model_name= '32_16_inacc_nt'

training_history, validation_history = net_trainer(large_net, optimizer,
                                             criterion, device, inacc_nt_loader, val_loader,
                                             scheduler, iter, model_name, save_dir,
                                             log_interval=100, patience=8, max_epochs=20)


fig, axes = plt.subplots(nrows=1, ncols=2, figsize=(10, 3))
axes[0].plot(training_history['accuracy'], label='train')
axes[0].plot(validation_history['accuracy'], label='val')
axes[0].set_xlabel('Epochs')
axes[0].set_ylabel('Accuracy')
axes[0].legend()

axes[1].plot(training_history['loss'], label='train')
axes[1].plot(validation_history['loss'], label='val')
axes[1].set_xlabel('Epochs')
axes[1].set_ylabel('Loss')
axes[1].legend()
fig.tight_layout()

plt.show()

plot_confusion_matrix(large_net, val_loader, device)
# Out:
# Training Results - Epoch[1] Avg accuracy: 0.61 Avg loss: 0.69
# Validation Results - Epoch[1] Avg accuracy: 0.57 Avg loss: 0.69
# End of Epoch 1: Learning Rate 0.001
# Training Results - Epoch[2] Avg accuracy: 0.62 Avg loss: 0.68
# Validation Results - Epoch[2] Avg accuracy: 0.55 Avg loss: 0.69
# End of Epoch 2: Learning Rate 0.001
# Training Results - Epoch[3] Avg accuracy: 0.63 Avg loss: 0.66
# Validation Results - Epoch[3] Avg accuracy: 0.56 Avg loss: 0.68
# End of Epoch 3: Learning Rate 0.001
# Training Results - Epoch[4] Avg accuracy: 0.66 Avg loss: 0.65
# Validation Results - Epoch[4] Avg accuracy: 0.59 Avg loss: 0.67
# End of Epoch 4: Learning Rate 0.001
# Training Results - Epoch[5] Avg accuracy: 0.71 Avg loss: 0.63
# Validation Results - Epoch[5] Avg accuracy: 0.62 Avg loss: 0.66
# End of Epoch 5: Learning Rate 0.001
# Epoch[6], Iter[100] Loss: 0.62
# Training Results - Epoch[6] Avg accuracy: 0.74 Avg loss: 0.60
# Validation Results - Epoch[6] Avg accuracy: 0.65 Avg loss: 0.65
# End of Epoch 6: Learning Rate 0.001
# Training Results - Epoch[7] Avg accuracy: 0.81 Avg loss: 0.56
# Validation Results - Epoch[7] Avg accuracy: 0.68 Avg loss: 0.63
# End of Epoch 7: Learning Rate 0.0005
# Training Results - Epoch[8] Avg accuracy: 0.81 Avg loss: 0.54
# Validation Results - Epoch[8] Avg accuracy: 0.68 Avg loss: 0.62
# End of Epoch 8: Learning Rate 0.0005
# Training Results - Epoch[9] Avg accuracy: 0.83 Avg loss: 0.52
# Validation Results - Epoch[9] Avg accuracy: 0.69 Avg loss: 0.61
# End of Epoch 9: Learning Rate 0.0005
# Training Results - Epoch[10] Avg accuracy: 0.85 Avg loss: 0.50
# Validation Results - Epoch[10] Avg accuracy: 0.70 Avg loss: 0.61
# End of Epoch 10: Learning Rate 0.0005
# Epoch[11], Iter[200] Loss: 0.48
# Training Results - Epoch[11] Avg accuracy: 0.88 Avg loss: 0.48
# Validation Results - Epoch[11] Avg accuracy: 0.72 Avg loss: 0.60
# End of Epoch 11: Learning Rate 0.0005
# Training Results - Epoch[12] Avg accuracy: 0.89 Avg loss: 0.46
# Validation Results - Epoch[12] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 12: Learning Rate 0.0005
# Training Results - Epoch[13] Avg accuracy: 0.89 Avg loss: 0.44
# Validation Results - Epoch[13] Avg accuracy: 0.72 Avg loss: 0.59
# End of Epoch 13: Learning Rate 0.0005
# Training Results - Epoch[14] Avg accuracy: 0.89 Avg loss: 0.42
# Validation Results - Epoch[14] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 14: Learning Rate 0.00025
# Training Results - Epoch[15] Avg accuracy: 0.89 Avg loss: 0.41
# Validation Results - Epoch[15] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 15: Learning Rate 0.00025
# Epoch[16], Iter[300] Loss: 0.45
# Training Results - Epoch[16] Avg accuracy: 0.89 Avg loss: 0.41
# Validation Results - Epoch[16] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 16: Learning Rate 0.00025
# Training Results - Epoch[17] Avg accuracy: 0.90 Avg loss: 0.40
# Validation Results - Epoch[17] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 17: Learning Rate 0.00025
# Training Results - Epoch[18] Avg accuracy: 0.90 Avg loss: 0.39
# Validation Results - Epoch[18] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 18: Learning Rate 0.00025
# Training Results - Epoch[19] Avg accuracy: 0.89 Avg loss: 0.39
# Validation Results - Epoch[19] Avg accuracy: 0.73 Avg loss: 0.59
# End of Epoch 19: Learning Rate 0.00025
# Training Results - Epoch[20] Avg accuracy: 0.90 Avg loss: 0.38
# Validation Results - Epoch[20] Avg accuracy: 0.73 Avg loss: 0.60
# End of Epoch 20: Learning Rate 0.00025
#               precision    recall  f1-score   support
#
#            0       0.73      0.81      0.77      2026
#            1       0.73      0.63      0.68      1662
#
#     accuracy                           0.73      3688
#    macro avg       0.73      0.72      0.72      3688
# weighted avg       0.73      0.73      0.73      3688

# %% [markdown]
# Tau Threshold

# %%
# dopo avere scelto la net migliore

model_path = fr'.\nets\dutch\iter_3\inacc_nt_models\32_16_inacc_nt_model_20.pt'
large_net.load_state_dict(torch.load(model_path))
large_net.eval()

with torch.no_grad():
   probas= large_net.predict_proba_nn(X_val, device)
   y_pred= large_net.predict(X_val,device)

max_conf= probas.max(axis=1)

taus= np.linspace(0.50, 0.99, 50)
y_val_np= y_val.cpu().numpy() if torch.is_tensor(y_val) else np.array(y_val)

res= [evaluate_threshold(t, max_conf, y_pred, y_val_np) for t in taus]

best_tau = None
best_acc = -1
for tau, (acc_sel, cov, _) in zip(taus, res):
   if cov >= 0.6 and acc_sel > best_acc:
      best_acc = acc_sel 
      best_tau = tau


print(best_tau)
print(best_acc)
# Out:
# 0.72
# 0.7723367697594502

# %% [markdown]
# #### Deferral Strat 2
#
#     tau             acc           def rate
#
# 22  0.264286       0.919917       0.285477
#
# 23  0.268571       0.914523       0.224066
#
# 24  0.272857       0.908299       0.163900
#
# 25  0.277143       0.902905       0.115353

# %%
def_data = []
pred_correct = []
C = []
alpha = 1.0  
beta = 0.1


for idx, row in df_inacc_nt.iterrows():

    x_i = row[feat_order].values.tolist()
    #x_i = list(entry['dict_form'].values())
    
    # 1 se la macchina ha indovinato, 0 se ha sbagliato
    corr = 1.0 if row['machine prediction'] == row['ground truth'] else 0.0 # la ground truth originale
    
    # Costo di deferral C
    if row['provider'] == "H":
        c_i = beta # L'umano è stato scelto ed era utile
    else:
        c_i = alpha + beta # L'umano non è stato scelto, chiamarlo sarebbe un costo extra
    
    def_data.append(x_i)
    pred_correct.append(corr)
    C.append(c_i)

X_def = torch.tensor(def_data, dtype=torch.float32)
pred_correct = torch.tensor(pred_correct, dtype=torch.float32)
C = torch.tensor(C, dtype=torch.float32)

# %%
# sulla base di x_def chiamo la rete 
# same configuration as iter 2
set_all_seeds(42)
r_net= DeferralNet(input_size=X_def.shape[1], hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff= 0.2)


optimizer = torch.optim.Adam(r_net.parameters(), lr=1e-3)
dataset = torch.utils.data.TensorDataset(X_def, pred_correct, C)
loader = torch.utils.data.DataLoader(dataset, batch_size=128, shuffle=False)

# %%
save_dir = fr'.\r_nets\dutch\iter_{iter}'
os.makedirs(save_dir, exist_ok=True)

r_net.to(device)
r_net.train()

for epoch in range(20):
    running_loss = 0.0
    for xb, pc_b, c_b in loader:
      
        xb, pc_b, c_b = xb.to(device), pc_b.to(device), c_b.to(device)
        
        r_vals = r_net(xb).view(-1) # .view(-1) assicura che r sia un vettore piatto
    
        loss = deferral_loss(r_vals, pc_b, c_b)
        
        optimizer.zero_grad()
        loss.backward()
        optimizer.step()
        
        running_loss += loss.item()
    

    print(f"Epoch {epoch+1}/20 - Loss: {running_loss/len(loader):.4f}")
    
torch.save(r_net.state_dict(), os.path.join(save_dir, 'r_net_inacc_nt.pth'))
print("✅ r_net salvata correttamente in", save_dir)
# Out:
# Epoch 1/20 - Loss: 0.6383
# Epoch 2/20 - Loss: 0.5845
# Epoch 3/20 - Loss: 0.5383
# Epoch 4/20 - Loss: 0.5290
# Epoch 5/20 - Loss: 0.5267
# Epoch 6/20 - Loss: 0.5275
# Epoch 7/20 - Loss: 0.5264
# Epoch 8/20 - Loss: 0.5258
# Epoch 9/20 - Loss: 0.5267
# Epoch 10/20 - Loss: 0.5240
# Epoch 11/20 - Loss: 0.5224
# Epoch 12/20 - Loss: 0.5274
# Epoch 13/20 - Loss: 0.5254
# Epoch 14/20 - Loss: 0.5262
# Epoch 15/20 - Loss: 0.5233
# Epoch 16/20 - Loss: 0.5248
# Epoch 17/20 - Loss: 0.5237
# Epoch 18/20 - Loss: 0.5243
# Epoch 19/20 - Loss: 0.5231
# Epoch 20/20 - Loss: 0.5242
# ✅ r_net salvata correttamente in .\r_nets\dutch\iter_3

# %%
p_defer_calib = p_defer(X_cal.to('cuda'), r_net).flatten()

#richiamo la net 
large_net= DeferralNet(input_size= X_cal.shape[1], hidden_layer1= 32, hidden_layer2= 16, output_size=2, dropout_coeff=0.3)

net_path= fr".\nets\dutch\iter_{iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
large_net.load_state_dict(torch.load(net_path, map_location=device))
large_net.to(device)
large_net.eval()

y_h_calib = large_net.predict(X_cal.to('cuda'), device)
y_gt_calib = y_cal.numpy()

thresholds = np.linspace(0.17, 0.38, 50)
calibration_results = []

for tr in thresholds:
    # Maschera di chi viene mandato all'umano
    defer_mask = (p_defer_calib >= tr)
    
    # ACCURATEZZA TEAM:
    # Se defer_mask è True (H), diamo 1 (assumiamo che l'umano indovini)
    # Se defer_mask è False (M), verifichiamo se h ha indovinato il target vero
    correct_decisions = np.where(defer_mask, 1.0, (y_h_calib == y_gt_calib))
    team_acc = np.mean(correct_decisions)
    
    # Tasso di Deferral: quante istanze la r_net ha "scartato"
    defer_rate = np.mean(defer_mask)
    
    calibration_results.append({
        'tau_r': tr,
        'team_accuracy': team_acc,
        'deferral_rate': defer_rate
    })

print(pd.DataFrame(calibration_results))
# Out:
#        tau_r  team_accuracy  deferral_rate
# 0   0.170000       0.995021       0.972614
# 1   0.174286       0.994606       0.965145
# 2   0.178571       0.992531       0.956432
# 3   0.182857       0.991701       0.949793
# 4   0.187143       0.990871       0.939834
# 5   0.191429       0.988382       0.924481
# 6   0.195714       0.984232       0.901245
# 7   0.200000       0.979253       0.874689
# 8   0.204286       0.975934       0.849793
# 9   0.208571       0.974689       0.829046
# 10  0.212857       0.973444       0.805394
# 11  0.217143       0.971369       0.777178
# 12  0.221429       0.969710       0.757676
# 13  0.225714       0.967635       0.739004
# 14  0.230000       0.966390       0.715353
# 15  0.234286       0.961826       0.683817
# 16  0.238571       0.957261       0.644813
# 17  0.242857       0.951867       0.591286
# 18  0.247143       0.946473       0.532365
# 19  0.251429       0.942324       0.480083
# 20  0.255714       0.934855       0.417842
# 21  0.260000       0.928216       0.353527
# 22  0.264286       0.919917       0.285477
# 23  0.268571       0.914523       0.224066
# 24  0.272857       0.908299       0.163900
# 25  0.277143       0.902905       0.115353
# 26  0.281429       0.900415       0.082988
# 27  0.285714       0.897925       0.053112
# 28  0.290000       0.895851       0.026971
# 29  0.294286       0.895851       0.012033
# 30  0.298571       0.895851       0.005809
# 31  0.302857       0.895021       0.002075
# 32  0.307143       0.895021       0.001245
# 33  0.311429       0.895021       0.000415
# 34  0.315714       0.895021       0.000000
# 35  0.320000       0.895021       0.000000
# 36  0.324286       0.895021       0.000000
# 37  0.328571       0.895021       0.000000
# 38  0.332857       0.895021       0.000000
# 39  0.337143       0.895021       0.000000
# 40  0.341429       0.895021       0.000000
# 41  0.345714       0.895021       0.000000
# 42  0.350000       0.895021       0.000000
# 43  0.354286       0.895021       0.000000
# 44  0.358571       0.895021       0.000000
# 45  0.362857       0.895021       0.000000
# 46  0.367143       0.895021       0.000000
# 47  0.371429       0.895021       0.000000
# 48  0.375714       0.895021       0.000000
# 49  0.380000       0.895021       0.000000
