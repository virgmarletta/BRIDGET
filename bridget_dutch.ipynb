# %% [markdown]
# # BRIDGET: DUTCH CENSUS
#
# From: https://github.com/tailequy/fairness_dataset/tree/main/Dutch_census
#
# Paper: [A survey on datasets for fairness-aware machine learning (Tai Le Quy et al.)](https://arxiv.org/abs/2110.00530)

# %% [markdown]
# ## Dataset Preprocessing

# %% [markdown]
# ### Libraries, Retrieving data

# %%
# %load_ext autoreload
# %autoreload 2

# %%
import os
import json
import yaml
import joblib
import random
import time
import functools
import pickle
import re
import orjson
import alibi
import ignite
import copy

from IPython import display
from itertools import combinations, product
from tqdm import tqdm
from matplotlib import pyplot as plt
from collections import Counter

import numpy as np
import pandas as pd
import torch.nn as nn
import torch.optim as optimizer

import fatf.utils.data.datasets as fatf_datasets
import fatf.fairness.data.measures as fatf_dfm
import fatf.utils.data.tools as fatf_data_tools

from river import rules, tree, datasets, drift, metrics, evaluate
from river import imblearn
from river import preprocessing
from river import optim
from river import metrics
from river import feature_extraction, feature_selection
from river import ensemble, linear_model, forest, compose

from torchsummary import summary
from torch.utils.data import TensorDataset, DataLoader

from ignite.metrics import Accuracy, Loss
from ignite.engine import Engine, Events, create_supervised_trainer, create_supervised_evaluator
from ignite.handlers import EarlyStopping, ModelCheckpoint
from ignite.contrib.handlers import global_step_from_engine


from xailib.models.sklearn_classifier_wrapper import sklearn_classifier_wrapper

from alibi.explainers.cfproto import CounterFactualProto

from bridget_utils import *
from classes import BetaUser, DeferralNet, PyTorchWrapper, RiverModelWrapper, PriorityManager
from b_xai_test import BRIDGET, HiC, MiC
# Out:
# c:\Users\virgm\anaconda3\Lib\site-packages\keras\src\export\tf2onnx_lib.py:8: FutureWarning: In the future `np.object` will be defined as the corresponding NumPy scalar.
#   if not hasattr(np, "object"):
# WARNING:tensorflow:From c:\Users\virgm\anaconda3\Lib\site-packages\alibi\utils\tf.py:11: The name tf.Session is deprecated. Please use tf.compat.v1.Session instead.
# 26-Feb-23 11:31:53 fatf.utils.array.tools INFO     Using numpy's numpy.lib.recfunctions.structured_to_unstructured as fatf.utils.array.tools.structured_to_unstructured and fatf.utils.array.tools.structured_to_unstructured_row.

# %%
set_all_seeds(42)

# %%
data= pd.read_csv(r".\datasets\dutch.csv")
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 60420 entries, 0 to 60419
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sex                   60420 non-null  object
#  1   age                   60420 non-null  int64
#  2   household_position    60420 non-null  int64
#  3   household_size        60420 non-null  int64
#  4   prev_residence_place  60420 non-null  int64
#  5   citizenship           60420 non-null  int64
#  6   country_birth         60420 non-null  int64
#  7   edu_level             60420 non-null  int64
#  8   economic_status       60420 non-null  int64
#  9   cur_eco_activity      60420 non-null  int64
#  10  marital_status        60420 non-null  int64
#  11  occupation            60420 non-null  int64
# dtypes: int64(11), object(1)
# memory usage: 5.5+ MB

# %%
for c in data:
    print(data[c].value_counts().sum)
# Out:
# <bound method Series.sum of sex
# female    30273
# male      30147
# Name: count, dtype: int64>
# <bound method Series.sum of age
# 8     8748
# 9     8478
# 7     8289
# 10    7880
# 11    7021
# 6     6292
# 5     4770
# 12    3881
# 4     3801
# 13    1022
# 14     176
# 15      62
# Name: count, dtype: int64>
# <bound method Series.sum of household_position
# 1122    26225
# 1121     9975
# 1110     7229
# 1210     6529
# 1131     5818
# 1132     2291
# 1140     1824
# 1220      529
# Name: count, dtype: int64>
# <bound method Series.sum of household_size
# 112    17237
# 114    16370
# 113    12238
# 111     6529
# 125     6179
# 126     1867
# Name: count, dtype: int64>
# <bound method Series.sum of prev_residence_place
# 1    58943
# 2     1477
# Name: count, dtype: int64>
# <bound method Series.sum of citizenship
# 1    59225
# 2      843
# 3      352
# Name: count, dtype: int64>
# <bound method Series.sum of country_birth
# 1    56058
# 3     2821
# 2     1541
# Name: count, dtype: int64>
# <bound method Series.sum of edu_level
# 3    22672
# 5    18109
# 2    12326
# 1     4513
# 4     2580
# 0      220
# Name: count, dtype: int64>
# <bound method Series.sum of economic_status
# 111    51340
# 120     4771
# 112     4309
# Name: count, dtype: int64>
# <bound method Series.sum of cur_eco_activity
# 131    11621
# 135    10239
# 138     8168
# 122     6505
# 137     5862
# 136     4294
# 133     3062
# 139     2661
# 132     2616
# 134     1940
# 111     1738
# 124     1714
# Name: count, dtype: int64>
# <bound method Series.sum of marital_status
# 2    36655
# 1    19656
# 4     3566
# 3      543
# Name: count, dtype: int64>
# <bound method Series.sum of occupation
# 0    31657
# 1    28763
# Name: count, dtype: int64>

# %% [markdown]
# ### Preprocessing Pipeline
# 1. Drop duplicates
#
# 2. Map 'sex'

# %%
data= clean_compas(data, drop_duplicates=True)

# %%
data.info()
data.head(n=5)
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 18438 entries, 0 to 18437
# Data columns (total 12 columns):
#  #   Column                Non-Null Count  Dtype
# ---  ------                --------------  -----
#  0   sex                   18438 non-null  object
#  1   age                   18438 non-null  int64
#  2   household_position    18438 non-null  int64
#  3   household_size        18438 non-null  int64
#  4   prev_residence_place  18438 non-null  int64
#  5   citizenship           18438 non-null  int64
#  6   country_birth         18438 non-null  int64
#  7   edu_level             18438 non-null  int64
#  8   economic_status       18438 non-null  int64
#  9   cur_eco_activity      18438 non-null  int64
#  10  marital_status        18438 non-null  int64
#  11  occupation            18438 non-null  int64
# dtypes: int64(11), object(1)
# memory usage: 1.7+ MB
#       sex  age  household_position  household_size  prev_residence_place  \
# 0    male    6                1131             112                     1
# 1  female   10                1122             113                     1
# 2    male    8                1122             113                     1
# 3    male   12                1121             112                     1
# 4  female    4                1110             114                     1
#
#    citizenship  country_birth  edu_level  economic_status  cur_eco_activity  \
# 0            1              1          5              111               135
# 1            1              1          2              111               122
# 2            1              1          2              111               122
# 3            1              1          1              111               137
# 4            1              1          2              111               138
#
#    marital_status  occupation
# 0               1           1
# 1               2           0
# 2               2           1
# 3               2           0
# 4               1           0

# %%
map= { 'sex': {'male': 0, 'female': 1}
}

data= apply_map(data, map)

# %% [markdown]
# ### Splitting and Transforming data
#
# 1. Apply stratified sampling
#
# 2. Get pre-training/HiC/calibration/Mic data
#
# 3. Apply scaler
#
# 4. Get X, y

# %%
# Qui definiamo i vari split dei flussi 
set_all_seeds(42)
data = data.sample(frac=1, random_state=42).reset_index(drop=True) # shuffle iniziale

class_0 = data[data['occupation'] == 0]
class_1= data[data['occupation'] == 1]

#  split ufficiale

splits= {
    'calibration': (0.6, 0.8),
    'mic': (0.8, 1.0),
    'avv_train': (0.0, 0.07),
    'avv_test': (0.07, 0.1),
    'hic_train': (0.1, 0.5),
    'hic_test': (0.5, 0.6)
}

dfs= {}

for name, (start, end) in splits.items():
    dfs[name]= stratif(start, end, class_0, class_1)

# %%
for name, df in dfs.items():
    print(f"{name} length: {len(df)}")
# Out:
# calibration length: 3688
# mic length: 3688
# avv_train length: 1290
# avv_test length: 552
# hic_train length: 7376
# hic_test length: 1844

# %%
target= 'occupation'
categoricals= ['sex', 'prev_residence_place']
numericals= [c for c in data if c not in categoricals and c != target]


prepr_transf = (
    (compose.Select(*numericals) | preprocessing.MinMaxScaler()) +
    compose.Select(*categoricals)
)

# %%
## ora divisione in x e y

set_all_seeds(42)

# avviamento 
X_avv_train, y_avv_train = x_y_split(dfs['avv_train'], target)
X_avv_test, y_avv_test = x_y_split(dfs['avv_test'], target)


# hic
X_hic_train, y_hic_train = x_y_split(dfs['hic_train'], target)
X_hic_test, y_hic_test = x_y_split(dfs['hic_test'], target)

# validation
X_val, y_val = x_y_split(dfs['calibration'], target)

# mic
X_mic, y_mic = x_y_split(dfs['mic'], target)

# %% [markdown]
# ## Calibration Phase: Experts and Incremental Model Selection

# %% [markdown]
# ### Calibrating Incremental Model
#
# The incremental model to be chosen for Bridget is trained on the X_avv, y_avv portion of the dataset,then evaluated on the X_avv_test and y_avv_test
#
# The calibration phase starts by assessing the results of the learning for several configurations:
#
#     - HoeffdingTreeClassifier
#
#     - ExtremelyFastDecisionTreeClassifier
#
#     - AdaBoostClassifier            (base= SGTClassifier)
#
#     - AdwinBaggingClassifier        (base= SGTClassifier)
#
#     - SRPClassifier                 (base= SGTClassifier)
#
#     - AdaptiveRandomForestClassifier
#
#
# The metrics observed are the Accuracy, the F1Score and the Counters for the classes

# %%
# since all River models work with dicts, lets first transform the dfs to dict
set_all_seeds(42)
X_avv_dict= X_avv_train.to_dict(orient='records')
X_avv_dict_test= X_avv_test.to_dict(orient='records')

df_batch_1 = (dfs['hic_train']).reset_index(drop=True)
mic_data= dfs['mic'].reset_index(drop=True)
df_avv= pd.concat([dfs['avv_train'], dfs['avv_test']]).reset_index(drop=True)

test_batch_1= X_hic_test.copy()
test_batch_1[target]= y_hic_test


# setting the init params required by HIC class
RULE = False
PAST = True
SKEPT = True
GROUP = True
EVA=    True
N_BINS = 10
N_VAR = 3
MAX = 5

rule_att = 'edu_level' #random rule
rule_value = 0.1

protected= ['sex', 'age', 'citizenship']

# %%
# then the models are instantiated and trained by the HiC.train function
# the HiC object is initialized by passing a random user model, its not relevant since it won't interact with the IL anyways

set_all_seeds(42)

expert= 'accurate_trusting'

base = tree.HoeffdingTreeClassifier(grace_period=100)

htree= tree.HoeffdingAdaptiveTreeClassifier(grace_period= 100, seed= 42)
efdt= tree.ExtremelyFastDecisionTreeClassifier(grace_period=100)
ada= ensemble.AdaBoostClassifier(model= base, n_models= 15, seed= 42)  
adwin= ensemble.ADWINBaggingClassifier(model= base, n_models= 15, seed= 42)
srp= ensemble.SRPClassifier(model= base, n_models=15, seed= 42)
arf= forest.ARFClassifier(n_models= 15, grace_period= 100, max_features='sqrt', seed=42)

models= [htree, efdt, ada, adwin, srp, arf]


for model in models:
    
    bridget_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 'placeholder', model,
                start_performance= 65,
                allocated_budget= 722,
                skepticism_threshold= 0.6,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= 'placeholder',
                df_batch1=df_batch_1, df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model='placeholder', 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= 0 
                )
    
    bridget_inst.train(X_avv_dict, y_avv_train, X_avv_dict_test, y_avv_test)

trained_arf= arf
# Out:
# Accuracy: 72.64%
# F1: 64.30%
# Distribution of predictions: Counter({0: 378, 1: 174})
# HoeffdingAdaptiveTreeClassifier trained
# Accuracy: 71.92%
# F1: 65.93%
# Distribution of predictions: Counter({0: 346, 1: 206})
# ExtremelyFastDecisionTreeClassifier trained
# Accuracy: 73.91%
# F1: 70.00%
# Distribution of predictions: Counter({0: 321, 1: 231})
# AdaBoostClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 72.10%
# F1: 62.25%
# Distribution of predictions: Counter({0: 393, 1: 159})
# ADWINBaggingClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 76.27%
# F1: 73.10%
# Distribution of predictions: Counter({0: 314, 1: 238})
# SRPClassifier(HoeffdingTreeClassifier) trained
# Accuracy: 75.72%
# F1: 71.37%
# Distribution of predictions: Counter({0: 333, 1: 219})
# ARFClassifier trained

# %% [markdown]
# ### Calibrating Experts
#
# For the Adult dataset the .search_bounds function was not capable to find the bounds at all, even after doubling the search range and running 10 iters
#
# Thus i pre-trained the IL models first, which update the scaler, then transformed the columns for the expert to be fitted on

# %%
with open(r".\experts_dutch.yaml", "r") as f:
    config= yaml.safe_load(f)


params_dict= config['experts']['groups']['w_dict']

# %%
set_all_seeds(42)
X_exp= X_hic_train.to_dict(orient='records')

X_exp_scaled= []

for x in X_exp:
    X_exp_scaled.append(prepr_transf.transform_one(x))

X_exp_final = pd.DataFrame(X_exp_scaled)

# %%
set_all_seeds(42)
experts_obj= {}

expert_names = ['accurate_trusting', 'accurate_not_trusting', 
                'inaccurate_trusting', 'inaccurate_not_trusting']

for name in expert_names:
    expert_type= config['experts']['groups'][name]

    experts_obj[name]= BetaUser(
        belief_level= expert_type['belief_value'],
        rethink_level= 0.8, # as suggested by the og FRANK implementation
        fairness= True,
        fpr= expert_type['target_FPR'],
        fnr= expert_type['target_FNR'],
        alpha= 0.9,
        features_dict= params_dict,
        seed= expert_type['group_seed']
        )
    res = experts_obj[name].fit(X_exp_final, y_hic_train, tol= 0.001)
    
    print(f"{'='*30}")
    print(f" EXPERT CALIBRATION REPORT ")
    print(f"{'='*30}")

    print(f"\n[EXPERT: {name}]")
    print(f"\n[FALSE POSITIVE RATE]")
    print(f"  - Iters:      {res['fpr iters number']}")
    print(f"  - Beta:       {res['calibrated_fpr_beta']:.4f}")
    print(f"  - Target:     {res['target_fpr']}")
    print(f"  - Achieved:   {res['achieved_fpr']:.4f}")

    print(f"\n[FALSE NEGATIVE RATE]")
    print(f"  - Iters:      {res['fnr iters number']}")
    print(f"  - Beta:       {res['calibrated_fnr_beta']:.4f}")
    print(f"  - Target:     {res['target_fnr']}")
    print(f"  - Achieved:   {res['achieved_fnr']:.4f}")
# Out:
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: accurate_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      11
#   - Beta:       -4.0039
#   - Target:     0.05
#   - Achieved:   0.0502
#
# [FALSE NEGATIVE RATE]
#   - Iters:      12
#   - Beta:       -1.8066
#   - Target:     0.05
#   - Achieved:   0.0500
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: accurate_not_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      12
#   - Beta:       -3.8574
#   - Target:     0.05
#   - Achieved:   0.0501
#
# [FALSE NEGATIVE RATE]
#   - Iters:      9
#   - Beta:       -1.9531
#   - Target:     0.05
#   - Achieved:   0.0494
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: inaccurate_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      14
#   - Beta:       -1.8677
#   - Target:     0.3
#   - Achieved:   0.3003
#
# [FALSE NEGATIVE RATE]
#   - Iters:      11
#   - Beta:       0.2930
#   - Target:     0.3
#   - Achieved:   0.2997
# ==============================
#  EXPERT CALIBRATION REPORT
# ==============================
#
# [EXPERT: inaccurate_not_trusting]
#
# [FALSE POSITIVE RATE]
#   - Iters:      15
#   - Beta:       -1.8005
#   - Target:     0.3
#   - Achieved:   0.3001
#
# [FALSE NEGATIVE RATE]
#   - Iters:      15
#   - Beta:       0.2625
#   - Target:     0.3
#   - Achieved:   0.3000

# %% [markdown]
# ## BRIDGET decision making

# %% [markdown]
# ### Expert: Accurate, Trusting

# %% [markdown]
# budgets -->
# hic_train lenght= 7376, budgets: [2459, 2459, 2458]
# [:2459], [2459: 4918], [4918:]
#
# mic length: 3688, budgets: [1229, 1229, 1230]
# [: 1229] , [1229: 2458], [2458:]

# %% [markdown]
# #### Iter 1

# %% [markdown]
# ##### HiC
#
# 2459 records

# %%
# defining necessary instantiation params for HiC class
hic_iter= 1
set_all_seeds(42)

clean_prepr = copy.deepcopy(prepr_transf)
arf_mod= copy.deepcopy(trained_arf)

current_expert= experts_obj['accurate_trusting']
name= "accurate_trusting"
mod_name="ARF"


hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 
                mod_name, arf_mod,
                start_performance= 68,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1, df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= hic_iter 
                    )

                    #17 min

# %%
set_all_seeds(42)
acc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  

# saving the results in their folder 
path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_t.to_csv(file_path, index=False)
# Out:
#  34%|███▍      | 2507/7376 [14:38<28:26,  2.85it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: HiC
# Current desired perfomance: 71.4
# Last 5 FEA values: [0.7698622382962309, 0.7721636159133126, 0.7744419797542225, 0.7666975599565357, 0.7590305843568286]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.6
# Out:
# 410

# %% [markdown]
# Applying learned scaler to the calibration and mic batches

# %%
# retrieving the preprocessor
hic_iter=1

set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_accurate_trusting\HIC_DRIFT_User_accurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 1

acc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.0) #tanto va in eval non serve il dropout
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr".\nets\dutch\iter_{mic_iter}\acc_t_models\32_16_acc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.79

# %%
set_all_seeds(42)
acc_t_mic= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65, #nel primo run è irrilevante
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.7,
                 tau_threshold= 0.79,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



acc_t_mic_df =acc_t_mic.start_MiC(X_stream, y_stream, acc_t_switch)   #3 minutes
# Out:
#  45%|████▌     | 1678/3688 [04:01<04:48,  6.96it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.7
# Last 5 FEA values: [0.7101467350247183, 0.7130452678146765, 0.7059148147950707, 0.6988556663124561, 0.6918671093213274]

# %%
plt.plot(acc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
acc_t_mic.deferred_decisions
# Out:
# 616

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.318305

# %%
r_net_acc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_t.load_state_dict(torch.load(fr'r_nets/dutch/iter_{mic_iter}/r_net_acc_t.pth'))
r_net_acc_t.to(device)
r_net_acc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_t_strat_2= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.7,
                 tau_threshold= 0.0,
                 anqi_mao_thresh=0.318305, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



acc_t_df_2= acc_t_strat_2.start_MiC(X_stream, y_stream, acc_t_switch, r_net= r_net_acc_t, two_step_deferral=True)   #3 minutes
# Out:
#  43%|████▎     | 1569/3688 [03:16<04:25,  7.99it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.7
# Last 5 FEA values: [0.7668168511891896, 0.7591486815680165, 0.7615571950972689, 0.7639416234843648, 0.7663022075808621]

# %%
plt.plot(acc_t_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
print(acc_t_mic.mic_acc)
print(acc_t_mic.model_acc)
acc_t_mic.deferred_decisions
# Out:
# 0.7492555092316855
# 0.726027397260274
# 616

# %%
print(acc_t_strat_2.mic_acc)
print(acc_t_strat_2.model_acc)
acc_t_strat_2.deferred_decisions
# Out:
# 0.7401273885350318
# 0.7305732484076433
# 276

# %%
acc_t_mic.deferred_decisions/len(acc_t_mic_df)
# Out:
# 0.14886418559690673

# %%
acc_t_strat_2.deferred_decisions/len(acc_t_df_2)
# Out:
# 0.06850335070737155

# %%
acc_t_mic.stats
# Out:
# {False: {'user': {'tried': 305, 'got': 305, 'conf': 1},
#   'machine': {'tried': 1089, 'got': 737, 'conf': 0}},
#  True: {'user': {'tried': 311, 'got': 311, 'conf': 1},
#   'machine': {'tried': 590, 'got': 326, 'conf': 0}}}

# %%
acc_t_strat_2.stats
# Out:
# {False: {'user': {'tried': 156, 'got': 156, 'conf': 1},
#   'machine': {'tried': 1017, 'got': 812, 'conf': 0}},
#  True: {'user': {'tried': 120, 'got': 120, 'conf': 1},
#   'machine': {'tried': 553, 'got': 482, 'conf': 0}}}

# %% [markdown]
# #### Iter 2

# %% [markdown]
# ##### HiC
#
# previous mean FEA: 71.93

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_1\results_accurate_trusting\HIC_DRIFT_User_accurate_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
path= fr"HIC_res\dutch\iter_1\results_accurate_trusting\HIC_DRIFT_User_accurate_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)
hic_iter= 2

set_all_seeds(42)

current_expert= experts_obj['accurate_trusting']
name= f"{'accurate_trusting'}"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 71.93,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[2459:4918], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
acc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_t.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2459/2459 [14:46<00:00,  2.77it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 588

# %%
# retrieving the preprocessor
hic_iter= 2
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_accurate_trusting\User_accurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, hic_inst.preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], hic_inst.preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC Conf

# %%
mic_iter= 2
acc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\acc_t_models\32_16_acc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.77
#
# previous system FEA (mean): 75.44

# %%
set_all_seeds(42)
acc_t_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 75.44,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.77,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



acc_t_mic_df =acc_t_mic.start_MiC(X_stream, y_stream, acc_t_switch)   #4 minutes
# Out:
#  47%|████▋     | 1748/3688 [04:23<04:52,  6.63it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7041664137377491, 0.7071247496711821, 0.7100535022438716, 0.7129529672894531, 0.7158234376832253]

# %%
plt.plot(acc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
acc_t_mic.low_belief_count
# Out:
# 1230

# %%
print(acc_t_mic.mic_acc)
print(acc_t_mic.model_acc)
acc_t_mic.deferred_decisions
# Out:
# 0.743281875357347
# 0.7238421955403087
# 645

# %%
print(acc_t_mic.deferred_decisions/len(acc_t_mic_df))
# Out:
# 0.15478761699064075

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.336735
#
# previous system FEA: 74.35

# %%
r_net_acc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_t.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_acc_t.pth"))
r_net_acc_t.to(device)
r_net_acc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_t_strat_2= MiC(mic_net, 'Def_Net', 
                benchmark_performance=74.35,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.336735, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



acc_t_df_2= acc_t_strat_2.start_MiC(X_stream, y_stream, acc_t_switch, r_net= r_net_acc_t, two_step_deferral=True)   #3 minutes
# Out:
#  48%|████▊     | 1767/3688 [04:39<05:03,  6.33it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7358236376705727, 0.738465401346108, 0.7410807473838485, 0.7436699399601927, 0.7462332406097748]

# %%
plt.plot(acc_t_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(acc_t_strat_2.mic_acc)
print(acc_t_strat_2.model_acc)
acc_t_strat_2.deferred_decisions
# Out:
# 0.744343891402715
# 0.7245475113122172
# 422

# %%
acc_t_mic.deferred_decisions/len(acc_t_mic_df)
# Out:
# 0.15478761699064075

# %%
acc_t_strat_2.deferred_decisions/len(acc_t_df_2)
# Out:
# 0.10081223124701386

# %%
acc_t_mic.stats
# Out:
# {False: {'user': {'tried': 330, 'got': 330, 'conf': 1},
#   'machine': {'tried': 1081, 'got': 697, 'conf': 0}},
#  True: {'user': {'tried': 315, 'got': 315, 'conf': 1},
#   'machine': {'tried': 668, 'got': 407, 'conf': 0}}}

# %%
acc_t_strat_2.stats
# Out:
# {False: {'user': {'tried': 228, 'got': 228, 'conf': 1},
#   'machine': {'tried': 1094, 'got': 813, 'conf': 0}},
#  True: {'user': {'tried': 194, 'got': 194, 'conf': 1},
#   'machine': {'tried': 674, 'got': 533, 'conf': 0}}}

# %% [markdown]
# #### Iter 3

# %% [markdown]
# ##### HiC
#
# previous mean FEA = 75.48

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_2\results_accurate_trusting\User_accurate_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
hic_iter= 3
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_2\results_accurate_trusting\User_accurate_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)

current_expert= experts_obj['accurate_trusting']
name= f"{'accurate_trusting'}"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 75.48,
                allocated_budget= 2458,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[4918:], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
acc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_t.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2458/2458 [15:28<00:00,  2.65it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 651

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_3\results_accurate_trusting\User_accurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, hic_inst.preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], hic_inst.preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 3
acc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\acc_t_models\32_16_acc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.81
#
# previous FEA: 74.64

# %%
set_all_seeds(42)
acc_t_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.64,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.81,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



acc_t_mic_df =acc_t_mic.start_MiC(X_stream, y_stream, acc_t_switch)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [09:40<00:00,  6.35it/s]

# %%
plt.plot(acc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
acc_t_mic.low_belief_count
# Out:
# 2196

# %%
print(acc_t_mic.mic_acc)
print(acc_t_mic.model_acc)
acc_t_mic.deferred_decisions
# Out:
# 0.7521691973969631
# 0.7383405639913232
# 1467

# %%
acc_t_mic.deferred_decisions/len(acc_t_mic_df)
# Out:
# 0.2405706789111184

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau=0.35
#
#
# Previous FEA: 74.60

# %%
r_net_acc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_t.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_acc_t.pth"))
r_net_acc_t.to(device)
r_net_acc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_t_strat_3= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.60,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.3571473, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



acc_t_df_3= acc_t_strat_3.start_MiC(X_stream, y_stream, acc_t_switch, r_net= r_net_acc_t, two_step_deferral=True)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [09:46<00:00,  6.29it/s]

# %%
plt.plot(acc_t_strat_3.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_t_strat_3.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(acc_t_strat_3.mic_acc)
print(acc_t_strat_3.model_acc)
acc_t_strat_3.deferred_decisions
# Out:
# 0.7467462039045553
# 0.7383405639913232
# 757

# %%
acc_t_mic.deferred_decisions /len(acc_t_mic_df)
# Out:
# 0.2405706789111184

# %%
acc_t_strat_3.deferred_decisions/len(acc_t_df_3)
# Out:
# 0.1241390619875369

# %%
acc_t_mic.stats
# Out:
# {False: {'user': {'tried': 718, 'got': 718, 'conf': 1},
#   'machine': {'tried': 2181, 'got': 1352, 'conf': 0}},
#  True: {'user': {'tried': 749, 'got': 749, 'conf': 1},
#   'machine': {'tried': 1507, 'got': 869, 'conf': 0}}}

# %%
acc_t_strat_3.stats
# Out:
# {False: {'user': {'tried': 390, 'got': 390, 'conf': 1},
#   'machine': {'tried': 2181, 'got': 1770, 'conf': 0}},
#  True: {'user': {'tried': 367, 'got': 367, 'conf': 1},
#   'machine': {'tried': 1507, 'got': 1161, 'conf': 0}}}

# %% [markdown]
# ### Expert: Inaccurate, Trusting

# %% [markdown]
# #### Iter 1

# %% [markdown]
# ##### HiC, 2459 record batch

# %%
# defining necessary instantiation params for HiC class
hic_iter= 1

set_all_seeds(42)
clean_prepr = copy.deepcopy(prepr_transf)
arf_mod= copy.deepcopy(trained_arf)

current_expert= experts_obj['inaccurate_trusting']
name= "inaccurate_trusting"
mod_name="ARF"


hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 
                mod_name, arf_mod,
                start_performance= 65,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1, df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= hic_iter 
                    )

# 15 min

# %%
set_all_seeds(42)
inacc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  

# saving the results in their folder 
path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_t.to_csv(file_path, index=False)
# Out:
#  34%|███▍      | 2507/7376 [14:33<28:16,  2.87it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: HiC
# Current desired perfomance: 68.25
# Last 5 FEA values: [0.6896923769822991, 0.6927954532125354, 0.6958674986804679, 0.6889088236935332, 0.6820197354564707]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.6
# Out:
# 740

# %% [markdown]
# Applying learned scaler to the calibration and mic batches

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_inaccurate_trusting\HIC_DRIFT_User_inaccurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 1

inacc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.0) #tanto va in eval non serve il dropout
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr".\nets\dutch\iter_{mic_iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau =0.75

# %%
set_all_seeds(42)
inacc_t_mic= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65, #nel primo run è irrilevante
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.6,
                 tau_threshold= 0.75,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



inacc_t_mic_df =inacc_t_mic.start_MiC(X_stream, y_stream, inacc_t_switch)   #3 minutes
# Out:
#  63%|██████▎   | 2329/3688 [04:10<02:26,  9.31it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.6
# Last 5 FEA values: [0.740511236133731, 0.7431061237725745, 0.7356750625343361, 0.7383183119091733, 0.7409351287902585]

# %%
plt.plot(inacc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.435593

# %%
r_net_inacc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_t.load_state_dict(torch.load(fr'r_nets/dutch/iter_{mic_iter}/r_net_inacc_t.pth'))
r_net_inacc_t.to(device)
r_net_inacc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_t_strat_2= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.7,
                 tau_threshold= 0.56,
                 anqi_mao_thresh=0.435593, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



inacc_t_df_2= inacc_t_strat_2.start_MiC(X_stream, y_stream, inacc_t_switch, r_net= r_net_inacc_t, two_step_deferral=True)   #3 minutes
# Out:
#  37%|███▋      | 1362/3688 [02:14<03:49, 10.14it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.7
# Last 5 FEA values: [0.7242728101199192, 0.7270300852127923, 0.7197597760228404, 0.7125621700907109, 0.7154365516206377]

# %%
plt.plot(inacc_t_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
plt.plot(inacc_t_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
print(inacc_t_mic.mic_acc)
print(inacc_t_mic.model_acc)
inacc_t_mic.deferred_decisions
# Out:
# 0.7412017167381975
# 0.723175965665236
# 869

# %%
print(inacc_t_strat_2.mic_acc)
print(inacc_t_strat_2.model_acc)
inacc_t_strat_2.deferred_decisions
# Out:
# 0.7454145267791636
# 0.7300073367571533
# 293

# %%
inacc_t_mic.deferred_decisions/len(inacc_t_mic_df)
# Out:
# 0.18145750678638548

# %%
inacc_t_strat_2.deferred_decisions/len(inacc_t_df_2)
# Out:
# 0.07666143380429094

# %%
inacc_t_mic.stats
# Out:
# {False: {'user': {'tried': 433, 'got': 433, 'conf': 1},
#   'machine': {'tried': 1484, 'got': 965, 'conf': 0}},
#  True: {'user': {'tried': 436, 'got': 436, 'conf': 1},
#   'machine': {'tried': 846, 'got': 496, 'conf': 0}}}

# %%
inacc_t_strat_2.stats
# Out:
# {False: {'user': {'tried': 153, 'got': 153, 'conf': 1},
#   'machine': {'tried': 871, 'got': 643, 'conf': 0}},
#  True: {'user': {'tried': 140, 'got': 140, 'conf': 1},
#   'machine': {'tried': 492, 'got': 427, 'conf': 0}}}

# %% [markdown]
# #### Iter 2

# %% [markdown]
# ##### HiC
#
# previous mean FEA: 70.27

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_1\results_inaccurate_trusting\HIC_DRIFT_User_inaccurate_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_1\results_inaccurate_trusting\HIC_DRIFT_User_inaccurate_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)

hic_iter= 2

current_expert= experts_obj['inaccurate_trusting']
name= 'inaccurate_trusting'
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 70.27,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[2459: 4918], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
inacc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_t.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2459/2459 [14:38<00:00,  2.80it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 906

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_inaccurate_trusting\User_inaccurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 2
inacc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.74
#
# previous mean FEA: 74.20

# %%
set_all_seeds(42)
inacc_t_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.20,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.74,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



inacc_t_mic_df =inacc_t_mic.start_MiC(X_stream, y_stream, inacc_t_switch)   #3 minutes
# Out:
#  44%|████▎     | 1612/3688 [03:19<04:16,  8.09it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7216517715063269, 0.7144352531136361, 0.7172909008479621, 0.7101179911793531, 0.7030168106205669]

# %%
plt.plot(inacc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(inacc_t_mic.mic_acc)
print(inacc_t_mic.model_acc)
inacc_t_mic.deferred_decisions
# Out:
# 0.7402355858648481
# 0.7247365158090514
# 612

# %%
print(inacc_t_mic.deferred_decisions/len(inacc_t_mic_df))
# Out:
# 0.15182336889109402

# %%
inacc_t_mic.low_belief_count
# Out:
# 1230

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.387755
#
# previous system FEA: 74.92

# %%
r_net_inacc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_t.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_inacc_t.pth"))
r_net_inacc_t.to(device)
r_net_inacc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_t_strat_2= MiC(mic_net, 'Def_Net', 
                benchmark_performance=74.92,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.387755, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



inacc_t_df_2= inacc_t_strat_2.start_MiC(X_stream, y_stream, inacc_t_switch, r_net= r_net_inacc_t, two_step_deferral=True)   #3 minutes
# Out:
#  45%|████▍     | 1644/3688 [03:27<04:17,  7.94it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7479442520743261, 0.7504648097251706, 0.7429601611221466, 0.7455305596824237, 0.748075254253685]

# %%
plt.plot(inacc_t_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_t_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(inacc_t_strat_2.mic_acc)
print(inacc_t_strat_2.model_acc)
inacc_t_strat_2.deferred_decisions
# Out:
# 0.7440729483282674
# 0.7246200607902735
# 419

# %%
inacc_t_mic.deferred_decisions/len(inacc_t_mic_df)
# Out:
# 0.15182336889109402

# %%
inacc_t_strat_2.deferred_decisions/len(inacc_t_df_2)
# Out:
# 0.10312576913610633

# %%
inacc_t_mic.stats
# Out:
# {False: {'user': {'tried': 309, 'got': 309, 'conf': 1},
#   'machine': {'tried': 984, 'got': 620, 'conf': 0}},
#  True: {'user': {'tried': 303, 'got': 303, 'conf': 1},
#   'machine': {'tried': 629, 'got': 381, 'conf': 0}}}

# %%
inacc_t_strat_2.stats
# Out:
# {False: {'user': {'tried': 234, 'got': 234, 'conf': 1},
#   'machine': {'tried': 1007, 'got': 719, 'conf': 0}},
#  True: {'user': {'tried': 185, 'got': 185, 'conf': 1},
#   'machine': {'tried': 638, 'got': 507, 'conf': 0}}}

# %% [markdown]
# #### Iter 3

# %% [markdown]
# ##### HiC
#
# previous mean FEA was 74.25

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_2\results_inaccurate_trusting\User_inaccurate_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
hic_iter= 3
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_2\results_inaccurate_trusting\User_inaccurate_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)


current_expert= experts_obj['inaccurate_trusting']
name= f"{'inaccurate_trusting'}"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 74.25,
                allocated_budget= 2458,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[4918:], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
inacc_t, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_t.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2458/2458 [15:04<00:00,  2.72it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 904

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_3\results_inaccurate_trusting\User_inaccurate_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'],trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_t_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 3
inacc_t_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_t_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\inacc_t_models\32_16_inacc_t_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.74
#
# previous FEA: 74.37

# %%
set_all_seeds(42)
inacc_t_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.37,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.74,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



inacc_t_mic_df =inacc_t_mic.start_MiC(X_stream, y_stream, inacc_t_switch)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [08:35<00:00,  7.16it/s]

# %%
plt.plot(inacc_t_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_t_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_t_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
inacc_t_mic.low_belief_count
# Out:
# 2746

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.395918
#
# Previous FEA: 74.65

# %%
r_net_inacc_t = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_t.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_inacc_t.pth"))
r_net_inacc_t.to(device)
r_net_inacc_t.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_t_strat_3= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.65,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.395918, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



inacc_t_df_3= inacc_t_strat_3.start_MiC(X_stream, y_stream, inacc_t_switch, r_net= r_net_inacc_t, two_step_deferral=True)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [08:36<00:00,  7.13it/s]

# %%
plt.plot(inacc_t_strat_3.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_t_strat_3.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_t_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(inacc_t_mic.mic_acc)
print(inacc_t_mic.model_acc)
inacc_t_mic.deferred_decisions
# Out:
# 0.7478308026030369
# 0.7348156182212582
# 1398

# %%
print(inacc_t_strat_3.mic_acc)
print(inacc_t_strat_3.model_acc)
inacc_t_strat_3.deferred_decisions
# Out:
# 0.7532537960954447
# 0.7348156182212582
# 953

# %%
inacc_t_mic.deferred_decisions /len(inacc_t_mic_df)
# Out:
# 0.2292554936044605

# %%
inacc_t_strat_3.deferred_decisions/len(inacc_t_df_3)
# Out:
# 0.15628074778615939

# %%
inacc_t_mic.stats
# Out:
# {False: {'user': {'tried': 697, 'got': 697, 'conf': 1},
#   'machine': {'tried': 2208, 'got': 1359, 'conf': 0}},
#  True: {'user': {'tried': 701, 'got': 701, 'conf': 1},
#   'machine': {'tried': 1480, 'got': 931, 'conf': 0}}}

# %%
inacc_t_strat_3.stats
# Out:
# {False: {'user': {'tried': 489, 'got': 489, 'conf': 1},
#   'machine': {'tried': 2208, 'got': 1593, 'conf': 0}},
#  True: {'user': {'tried': 464, 'got': 464, 'conf': 1},
#   'machine': {'tried': 1480, 'got': 1142, 'conf': 0}}}

# %% [markdown]
# ### Expert: Accurate, Not Trusting

# %% [markdown]
# #### Iter 1

# %% [markdown]
# ##### HiC
#
# 2459 record batch

# %%
# defining necessary instantiation params for HiC class

hic_iter= 1
set_all_seeds(42)
clean_prepr = copy.deepcopy(prepr_transf)
arf_mod= copy.deepcopy(trained_arf)

current_expert= experts_obj['accurate_not_trusting']
name= "accurate_not_trusting"
mod_name="ARF"


hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 
                mod_name, arf_mod,
                start_performance= 65,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1, df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
acc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  

# saving the results in their folder 
path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_nt.to_csv(file_path, index=False)
# Out:
#  34%|███▍      | 2507/7376 [15:04<29:16,  2.77it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: HiC
# Current desired perfomance: 68.25
# Last 5 FEA values: [0.7351129776347357, 0.7377618478584389, 0.7403842293799039, 0.7329803870859666, 0.7256505832149714]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.6
# Out:
# 305

# %% [markdown]
# Applying learned scaler to the calibration and mic batches

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_accurate_not_trusting\HIC_DRIFT_User_accurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 1

acc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.0) #tanto va in eval non serve il dropout
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr".\nets\dutch\iter_{mic_iter}\acc_nt_models\32_16_acc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.73

# %%
set_all_seeds(42)
acc_nt_mic= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65, #nel primo run è irrilevante
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.6,
                 tau_threshold= 0.73,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



acc_nt_mic_df =acc_nt_mic.start_MiC(X_stream, y_stream, acc_nt_switch)   #3 minutes
# Out:
#  59%|█████▉    | 2177/3688 [04:55<03:24,  7.37it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.6
# Last 5 FEA values: [0.7606670854320353, 0.7630604145784832, 0.7654298104334515, 0.767775512329855, 0.7700977572072798]

# %%
plt.plot(acc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
acc_nt_mic.deferred_decisions
# Out:
# 830

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.202034

# %%
r_net_acc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_nt.load_state_dict(torch.load(fr'r_nets/dutch/iter_{mic_iter}/r_net_acc_nt.pth'))
r_net_acc_nt.to(device)
r_net_acc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_nt_strat_2= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.7,
                 tau_threshold= 0.62,
                 anqi_mao_thresh= 0.202034, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



acc_nt_df_2= acc_nt_strat_2.start_MiC(X_stream, y_stream, acc_nt_switch, r_net= r_net_acc_nt, two_step_deferral=True)   #3 minutes
# Out:
#  37%|███▋      | 1363/3688 [03:25<05:50,  6.63it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.7
# Last 5 FEA values: [0.7377850673505818, 0.7304072082159101, 0.7231031278409625, 0.7258720996749053, 0.71861337060086]

# %%
plt.plot(acc_nt_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_nt_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
plt.plot(acc_nt_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_nt_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
print(acc_nt_mic.mic_acc)
print(acc_nt_mic.model_acc)
acc_nt_mic.deferred_decisions
# Out:
# 0.7543617998163453
# 0.7355371900826446
# 830

# %%
print(acc_nt_strat_2.mic_acc)
print(acc_nt_strat_2.model_acc)
acc_nt_strat_2.deferred_decisions
# Out:
# 0.749266862170088
# 0.7382697947214076
# 212

# %%
acc_nt_mic.deferred_decisions/len(acc_nt_mic_df)
# Out:
# 0.1789950398964848

# %%
acc_nt_strat_2.deferred_decisions/len(acc_nt_df_2)
# Out:
# 0.055453832069055714

# %%
acc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 412, 'got': 412, 'conf': 1},
#   'machine': {'tried': 1339, 'got': 854, 'conf': 0}},
#  True: {'user': {'tried': 418, 'got': 418, 'conf': 1},
#   'machine': {'tried': 839, 'got': 494, 'conf': 0}}}

# %%
acc_nt_strat_2.stats
# Out:
# {False: {'user': {'tried': 107, 'got': 107, 'conf': 1},
#   'machine': {'tried': 846, 'got': 696, 'conf': 0}},
#  True: {'user': {'tried': 105, 'got': 105, 'conf': 1},
#   'machine': {'tried': 518, 'got': 456, 'conf': 0}}}

# %% [markdown]
# #### Iter 2

# %% [markdown]
# ##### HiC
#
# previous mean FEA: 73.68

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_1\results_accurate_not_trusting\HIC_DRIFT_User_accurate_not_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
hic_iter= 2
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_1\results_accurate_not_trusting\HIC_DRIFT_User_accurate_not_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)

current_expert= experts_obj['accurate_not_trusting']
name= f"{'accurate_not_trusting'}"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 73.68,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[2459: 4918], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)

acc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_nt.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2459/2459 [15:00<00:00,  2.73it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 442

# %%
# retrieving the preprocessor
hic_iter= 2
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_accurate_not_trusting\User_accurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC Conf

# %%
mic_iter= 2
acc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\acc_nt_models\32_16_acc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.81
#
# previous system FEA (mean): 75.53

# %%
set_all_seeds(42)
acc_nt_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 75.53,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.81,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



acc_nt_mic_df =acc_nt_mic.start_MiC(X_stream, y_stream, acc_nt_switch)   #3 minutes
# Out:
#  59%|█████▊    | 2165/3688 [05:22<03:46,  6.72it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.761261289016375, 0.7636486761270759, 0.7560121893630671, 0.7484520674667529, 0.7409675467894551]

# %%
plt.plot(acc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(acc_nt_mic.mic_acc)
print(acc_nt_mic.model_acc)
acc_nt_mic.deferred_decisions
# Out:
# 0.7414589104339797
# 0.7289935364727609
# 804

# %%
acc_nt_mic.deferred_decisions/len(acc_nt_mic_df)
# Out:
# 0.17539267015706805

# %%
acc_nt_mic.low_belief_count
# Out:
# 1230

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.228571
#
# previous system FEA: 75.67

# %%
r_net_acc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_nt.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_acc_nt.pth"))
r_net_acc_nt.to(device)
r_net_acc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_nt_strat_2= MiC(mic_net, 'Def_Net', 
                benchmark_performance=75.67,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.228571, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )


acc_nt_df_2= acc_nt_strat_2.start_MiC(X_stream, y_stream, acc_nt_switch, r_net= r_net_acc_nt, two_step_deferral=True)   #3 minutes
# Out:
#  62%|██████▏   | 2276/3688 [05:26<03:22,  6.98it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7398943462942228, 0.7324954028304023, 0.7351704488024127, 0.7378187443146967, 0.7304405568707]

# %%
plt.plot(acc_nt_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_nt_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_nt_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(acc_nt_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(acc_nt_strat_2.mic_acc)
print(acc_nt_strat_2.model_acc)
acc_nt_strat_2.deferred_decisions
# Out:
# 0.7483530961791831
# 0.7281510759771629
# 460

# %%
acc_nt_mic.deferred_decisions/len(acc_nt_mic_df)
# Out:
# 0.17539267015706805

# %%
acc_nt_strat_2.deferred_decisions/len(acc_nt_df_2)
# Out:
# 0.0979765708200213

# %%
acc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 385, 'got': 385, 'conf': 1},
#   'machine': {'tried': 1345, 'got': 931, 'conf': 0}},
#  True: {'user': {'tried': 419, 'got': 419, 'conf': 1},
#   'machine': {'tried': 821, 'got': 431, 'conf': 0}}}

# %%
acc_nt_strat_2.stats
# Out:
# {False: {'user': {'tried': 259, 'got': 259, 'conf': 1},
#   'machine': {'tried': 1421, 'got': 1070, 'conf': 0}},
#  True: {'user': {'tried': 201, 'got': 201, 'conf': 1},
#   'machine': {'tried': 856, 'got': 747, 'conf': 0}}}

# %% [markdown]
# #### Iter 3

# %% [markdown]
# ##### HiC
#
# previous mean FEA = 75.25

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_2\results_accurate_not_trusting\User_accurate_not_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
hic_iter= 3
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_2\results_accurate_not_trusting\User_accurate_not_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)


current_expert= experts_obj['accurate_not_trusting']
name= f"{'accurate_not_trusting'}"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 75.25,
                allocated_budget= 2458,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[4918:], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
acc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

acc_nt.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2458/2458 [15:17<00:00,  2.68it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 542

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_3\results_accurate_not_trusting\User_accurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"acc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 3
acc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\acc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\acc_nt_models\32_16_acc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.79
#
# previous FEA: 74.25

# %%
set_all_seeds(42)
acc_nt_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.25,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.79,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



acc_nt_mic_df =acc_nt_mic.start_MiC(X_stream, y_stream, acc_nt_switch)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [09:37<00:00,  6.39it/s]

# %%
plt.plot(acc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(acc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
acc_nt_mic.low_belief_count
# Out:
# 2262

# %%
print(acc_nt_mic.mic_acc)
print(acc_nt_mic.model_acc)
acc_nt_mic.deferred_decisions
# Out:
# 0.7443058568329718
# 0.7364425162689805
# 1312

# %%
acc_nt_mic.deferred_decisions/len(acc_nt_mic_df)
# Out:
# 0.2151525090193506

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.246939
#
#
# Previous FEA: 75.24

# %%
r_net_acc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_acc_nt.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_acc_nt.pth"))
r_net_acc_nt.to(device)
r_net_acc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
acc_nt_strat_3= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 75.24,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.246939, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



acc_nt_df_3= acc_nt_strat_3.start_MiC(X_stream, y_stream, acc_nt_switch, r_net= r_net_acc_nt, two_step_deferral=True)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [08:55<00:00,  6.89it/s]

# %%
plt.plot(acc_nt_strat_3.fea_mic, linestyle='-', color='royalblue')
avg_fea_3= np.mean(acc_nt_strat_3.fea_mic)
plt.axhline(y=avg_fea_3, color='red', linestyle='--', label=f'Avg: {avg_fea_3:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(acc_nt_strat_3.fea_net, linestyle='-', color='royalblue')
avg_fea_3= np.mean(acc_nt_strat_3.fea_net)
plt.axhline(y=avg_fea_3, color='red', linestyle='--', label=f'Avg: {avg_fea_3:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(acc_nt_strat_3.mic_acc)
print(acc_nt_strat_3.model_acc)
acc_nt_strat_3.deferred_decisions
# Out:
# 0.7551518438177874
# 0.7364425162689805
# 850

# %%
acc_nt_mic.deferred_decisions /len(acc_nt_mic_df)
# Out:
# 0.2151525090193506

# %%
acc_nt_strat_3.deferred_decisions/len(acc_nt_df_3)
# Out:
# 0.13938996392259756

# %%
acc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 638, 'got': 638, 'conf': 1},
#   'machine': {'tried': 2196, 'got': 1547, 'conf': 0}},
#  True: {'user': {'tried': 674, 'got': 674, 'conf': 1},
#   'machine': {'tried': 1492, 'got': 829, 'conf': 0}}}

# %%
acc_nt_strat_3.stats
# Out:
# {False: {'user': {'tried': 477, 'got': 477, 'conf': 1},
#   'machine': {'tried': 2196, 'got': 1598, 'conf': 0}},
#  True: {'user': {'tried': 373, 'got': 373, 'conf': 1},
#   'machine': {'tried': 1492, 'got': 1240, 'conf': 0}}}

# %% [markdown]
# ### Expert: Inaccurate, Not Trusting

# %% [markdown]
# #### Iter 1

# %% [markdown]
# ##### HiC

# %%
# defining necessary instantiation params for HiC class
hic_iter= 1
set_all_seeds(42)

clean_prepr = copy.deepcopy(prepr_transf)
arf_mod= copy.deepcopy(trained_arf)

current_expert= experts_obj['inaccurate_not_trusting']
name= "inaccurate_not_trusting"
mod_name="ARF"


hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, 
                mod_name, arf_mod,
                start_performance= 65,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1, df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=prepr_transf,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
inacc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  

# saving the results in their folder 
path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_nt.to_csv(file_path, index=False)

#18 min
# Out:
#  34%|███▍      | 2507/7376 [16:05<31:15,  2.60it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: HiC
# Current desired perfomance: 68.25
# Last 5 FEA values: [0.7239264870299514, 0.7266872221597046, 0.7294203499381592, 0.7221261464386414, 0.7149048849741214]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.6
# Out:
# 558

# %% [markdown]
# Applying learned scaler to the calibration and mic batches

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_inaccurate_not_trusting\HIC_DRIFT_User_inaccurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 1

inacc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.0) #tanto va in eval non serve il dropout
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr".\nets\dutch\iter_{mic_iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.68

# %%
set_all_seeds(42)
inacc_nt_mic= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65, #nel primo run è irrilevante
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.6,
                 tau_threshold= 0.68,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



inacc_nt_mic_df =inacc_nt_mic.start_MiC(X_stream, y_stream, inacc_nt_switch)   #3 minutes
# Out:
#  47%|████▋     | 1746/3688 [04:06<04:33,  7.09it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.6
# Last 5 FEA values: [0.7030738942091693, 0.7060431553395926, 0.7089827238572687, 0.7118928966883535, 0.7147739677897414]

# %%
plt.plot(inacc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
inacc_nt_mic.deferred_decisions
# Out:
# 697

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.245763

# %%
r_net_inacc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_nt.load_state_dict(torch.load(fr'r_nets/dutch/iter_{mic_iter}/r_net_inacc_nt.pth'))
r_net_inacc_nt.to(device)
r_net_inacc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_nt_strat_2= MiC(mic_net, 'Def_Net', 
               benchmark_performance= 65,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.7,
                 tau_threshold= 0.62,
                 anqi_mao_thresh= 0.245763, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= mic_iter
 )



inacc_nt_df_2= inacc_nt_strat_2.start_MiC(X_stream, y_stream, inacc_nt_switch, r_net= r_net_inacc_nt, two_step_deferral=True)   #3 minutes
# Out:
#  34%|███▍      | 1246/3688 [03:19<06:31,  6.24it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.7
# Last 5 FEA values: [0.7210473343028458, 0.7238368713282762, 0.7265985127771193, 0.7293325376092469, 0.7220391859295769]

# %%
plt.plot(inacc_nt_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_nt_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
plt.plot(inacc_nt_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_nt_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()



# sospetto che sia uguale no?

# %%
print(inacc_nt_mic.mic_acc)
print(inacc_nt_mic.model_acc)
inacc_nt_mic.deferred_decisions
# Out:
# 0.7435603892386949
# 0.7160847166571265
# 697

# %%
print(inacc_nt_strat_2.mic_acc)
print(inacc_nt_strat_2.model_acc)
inacc_nt_strat_2.deferred_decisions
# Out:
# 0.731355252606255
# 0.7201283079390537
# 269

# %%
inacc_nt_mic.deferred_decisions/len(inacc_nt_mic_df)
# Out:
# 0.16571564431764146

# %%
inacc_nt_strat_2.deferred_decisions/len(inacc_nt_df_2)
# Out:
# 0.07258499730167296

# %%
inacc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 359, 'got': 359, 'conf': 1},
#   'machine': {'tried': 1017, 'got': 610, 'conf': 0}},
#  True: {'user': {'tried': 338, 'got': 338, 'conf': 1},
#   'machine': {'tried': 730, 'got': 440, 'conf': 0}}}

# %%
inacc_nt_strat_2.stats
# Out:
# {False: {'user': {'tried': 154, 'got': 154, 'conf': 1},
#   'machine': {'tried': 738, 'got': 542, 'conf': 0}},
#  True: {'user': {'tried': 115, 'got': 115, 'conf': 1},
#   'machine': {'tried': 509, 'got': 436, 'conf': 0}}}

# %% [markdown]
# #### Iter 2

# %% [markdown]
# ##### HiC
#
# previous mean FEA: 71.53

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_1\results_inaccurate_not_trusting\HIC_DRIFT_User_inaccurate_not_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
hic_iter= 2
set_all_seeds(42)
path= fr"HIC_res\dutch\iter_1\results_inaccurate_not_trusting\HIC_DRIFT_User_inaccurate_not_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)

current_expert= experts_obj['inaccurate_not_trusting']
name= "inaccurate_not_trusting"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 71.53,
                allocated_budget= 2459,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[2459:4918], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
inacc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_nt.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2459/2459 [15:26<00:00,  2.66it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 671

# %%
# retrieving the preprocessor
hic_iter= 2
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_{hic_iter}\results_inaccurate_not_trusting\User_inaccurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 2
inacc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.76
#
# previous system FEA (mean): 74.67

# %%
set_all_seeds(42)
inacc_nt_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.67,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.76,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )



inacc_nt_mic_df =inacc_nt_mic.start_MiC(X_stream, y_stream, inacc_nt_switch)   #3 minutes
# Out:
#  46%|████▌     | 1691/3688 [04:09<04:54,  6.78it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7389319526564602, 0.7315426328162435, 0.7342272066008929, 0.7368849346454508, 0.7395160854073627]

# %%
plt.plot(inacc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
inacc_nt_mic.low_belief_count
# Out:
# 1230

# %%
print(inacc_nt_mic.mic_acc)
print(inacc_nt_mic.model_acc)
inacc_nt_mic.deferred_decisions
# Out:
# 0.7434988179669031
# 0.7133569739952719
# 792

# %%
inacc_nt_mic.deferred_decisions/len(inacc_nt_mic_df)
# Out:
# 0.1927007299270073

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.271429
#
# previous system FEA: 73.58

# %%
r_net_inacc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_nt.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_inacc_nt.pth"))
r_net_inacc_nt.to(device)
r_net_inacc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_nt_strat_2= MiC(mic_net, 'Def_Net', 
                benchmark_performance=73.58,
                 user_patience= 1229,
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.271429, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 2
 )


inacc_nt_df_2= inacc_nt_strat_2.start_MiC(X_stream, y_stream, inacc_nt_switch, r_net= r_net_inacc_nt, two_step_deferral=True)   #3 minutes
# Out:
#  45%|████▍     | 1659/3688 [03:54<04:47,  7.06it/s]
#  ALERT
#
# Drift detected, loading metrics...
# Current phase: MiC
# Current belief_threshold: 0.65
# Last 5 FEA values: [0.7875860424585921, 0.7797101815728845, 0.7819130798848428, 0.7840939492111405, 0.7762530092735872]

# %%
plt.plot(inacc_nt_strat_2.fea_mic, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_nt_strat_2.fea_mic)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_nt_strat_2.fea_net, linestyle='-', color='royalblue')
avg_fea_2= np.mean(inacc_nt_strat_2.fea_net)
plt.axhline(y=avg_fea_2, color='red', linestyle='--', label=f'Avg: {avg_fea_2:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(inacc_nt_strat_2.mic_acc)
print(inacc_nt_strat_2.model_acc)
inacc_nt_strat_2.deferred_decisions
# Out:
# 0.7409638554216867
# 0.7162650602409638
# 370

# %%
inacc_nt_strat_2.deferred_decisions/len(inacc_nt_df_2)
# Out:
# 0.09073075036782736

# %%
inacc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 393, 'got': 393, 'conf': 1},
#   'machine': {'tried': 1159, 'got': 687, 'conf': 0}},
#  True: {'user': {'tried': 399, 'got': 399, 'conf': 1},
#   'machine': {'tried': 533, 'got': 213, 'conf': 0}}}

# %%
inacc_nt_strat_2.stats
# Out:
# {False: {'user': {'tried': 213, 'got': 213, 'conf': 1},
#   'machine': {'tried': 1139, 'got': 809, 'conf': 0}},
#  True: {'user': {'tried': 157, 'got': 157, 'conf': 1},
#   'machine': {'tried': 521, 'got': 481, 'conf': 0}}}

# %% [markdown]
# #### Iter 3

# %% [markdown]
# ##### HiC
#
# previous mean FEA= 73.06

# %%
#retrieving the trained model

# actually maybe i should train the baseline model again
file_path = r"HIC_res\dutch\iter_2\results_inaccurate_not_trusting\User_inaccurate_not_trusting_ARFmodel.pkl"

with open(file_path, "rb") as f:
    prev_arf = pickle.load(f)

# %%
set_all_seeds(42)
hic_iter= 3
path= fr"HIC_res\dutch\iter_2\results_inaccurate_not_trusting\User_inaccurate_not_trusting_ARFpreprocessor.pkl"
previous_preprocessor = joblib.load(path)


current_expert= experts_obj['inaccurate_not_trusting']
name= "inaccurate_not_trusting"
mod_name="ARF"



hic_inst= HiC(RULE, PAST, SKEPT, GROUP, EVA, N_BINS, N_VAR, MAX, 
                rule_att, rule_value, mod_name, prev_arf,
                start_performance= 73.06,
                allocated_budget= 2458,
                skepticism_threshold= 0.2,
                performance_delta= 0.05,
                dataset_name= 'dutch',
                user_name= name,
                df_batch1=df_batch_1.iloc[4918:], df_batch3=mic_data, batch1_test=test_batch_1, 
                target=target, 
                user_model=current_expert, 
                protected=protected, cats=categoricals, num=numericals,
                preprocessor=previous_preprocessor,
                training_iter= hic_iter 
                    )

# %%
set_all_seeds(42)
inacc_nt, _, equality, skept_count= hic_inst.start_HiC(df_avv)  


path= f".\processed_data\dutch\hic_results_ds\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"hic_{name}.csv")

inacc_nt.to_csv(file_path, index=False)
# Out:
# 100%|██████████| 2458/2458 [15:19<00:00,  2.67it/s]

# %%
equality
# Out:
# []

# %%
skept_count #none overcame the skept threshold set at 0.3
# Out:
# 777

# %%
# retrieving the preprocessor
set_all_seeds(42)
prepr_path= fr"HIC_res\dutch\iter_3\results_inaccurate_not_trusting\User_inaccurate_not_trusting_ARFpreprocessor.pkl"
trained_preprocessor = joblib.load(prepr_path)

df_batch_3= scale_df(mic_data, trained_preprocessor, target)
df_batch_3= apply_order(df_batch_3)

df_calibration= scale_df(dfs['calibration'], trained_preprocessor,target)
df_calibration= apply_order(df_calibration)


path= f".\processed_data\dutch\calibration_datasets\iter_{hic_iter}"
os.makedirs(path, exist_ok=True)
file_path = os.path.join(path, f"inacc_nt_calibration.csv")

df_calibration.to_csv(file_path, index=False)


# applying scaler to calibration batch 3

# %%
plt.plot(hic_inst.machine_fea, linestyle='-', color='royalblue')

avg_fea= np.mean(hic_inst.machine_fea)

plt.title('Evolution of FEA values (HiC phase)', fontsize=10)
plt.axhline(y= avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)

plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)  
plt.tight_layout()
plt.show()

# forgot to change the name again

# %% [markdown]
# ##### MiC

# %%
mic_iter= 3
inacc_nt_switch= pd.read_csv(fr".\processed_data\dutch\switch_ds\iter_{mic_iter}\inacc_nt_switch.csv")

device = torch.device("cpu")
# prendo la struttura della mic 
mic_net = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=2, dropout_coeff= 0.2) 
mic_net.to(device)
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %%
X_stream= torch.tensor(data= df_batch_3.drop(columns=['occupation']).values, dtype=torch.float32).to(device)
y_stream= torch.tensor(data=df_batch_3['occupation'].values, dtype= torch.long).to(device)


net_path= fr"nets\dutch\iter_{mic_iter}\inacc_nt_models\32_16_inacc_nt_model_20.pt"
mic_net.load_state_dict(torch.load(net_path, map_location=device))

mic_net.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.2, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.2, inplace=False)
#     (6): Linear(in_features=16, out_features=2, bias=True)
#   )
# )

# %% [markdown]
# ##### Confidence based Deferral
#
# Tau = 0.72
#
# previous FEA: 74.24

# %%
set_all_seeds(42)
inacc_nt_mic= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.24,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.72,
                 anqi_mao_thresh=None, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



inacc_nt_mic_df =inacc_nt_mic.start_MiC(X_stream, y_stream, inacc_nt_switch)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [07:20<00:00,  8.36it/s]

# %%
plt.plot(inacc_nt_mic.fea_mic, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_mic)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_nt_mic.fea_net, linestyle='-', color='royalblue')

avg_fea= np.mean(inacc_nt_mic.fea_net)
plt.axhline(y=avg_fea, color='red', linestyle='--', label=f'Avg: {avg_fea:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
inacc_nt_mic.low_belief_count
# Out:
# 3054

# %%
print(inacc_nt_mic.mic_acc)
print(inacc_nt_mic.model_acc)
inacc_nt_mic.deferred_decisions
# Out:
# 0.7386117136659436
# 0.7318329718004338
# 1343

# %% [markdown]
# ##### Two Stage Deferral
#
# Optimal tau= 0.268571
#
# Previous FEA: 74.46

# %%
r_net_inacc_nt = DeferralNet(input_size=11, hidden_layer1=32, hidden_layer2=16, output_size=1, dropout_coeff=0.0)

r_net_inacc_nt.load_state_dict(torch.load(fr"r_nets\dutch\iter_{mic_iter}\r_net_inacc_nt.pth"))
r_net_inacc_nt.to(device)
r_net_inacc_nt.eval()
# Out:
# DeferralNet(
#   (softmax): Softmax(dim=1)
#   (linear_relu_stack): Sequential(
#     (0): Linear(in_features=11, out_features=32, bias=True)
#     (1): ReLU()
#     (2): Dropout(p=0.0, inplace=False)
#     (3): Linear(in_features=32, out_features=16, bias=True)
#     (4): ReLU()
#     (5): Dropout(p=0.0, inplace=False)
#     (6): Linear(in_features=16, out_features=1, bias=True)
#   )
# )

# %%
set_all_seeds(42)
inacc_nt_strat_3= MiC(mic_net, 'Def_Net', 
                benchmark_performance= 74.46,
                 user_patience= len(df_batch_3),
                 performance_delta= 0.05,
                 belief_threshold= 0.65,
                 tau_threshold= 0.0,
                 anqi_mao_thresh= 0.268571, 
                 dataset_name= 'dutch', 
                 user_name=name, 
                 df_batch1=df_batch_1, df_batch3=df_batch_3, batch1_test=test_batch_1, 
                 target=target, 
                 user_model=current_expert, 
                 protected=protected, cats=categoricals, num=numericals,
                 preprocessor=trained_preprocessor,
                 training_iter= 3
 )



inacc_nt_df_3= inacc_nt_strat_3.start_MiC(X_stream, y_stream, inacc_nt_switch, r_net= r_net_inacc_nt, two_step_deferral=True)   #3 minutes
# Out:
# 100%|██████████| 3688/3688 [08:34<00:00,  7.17it/s]

# %%
plt.plot(inacc_nt_strat_3.fea_mic, linestyle='-', color='royalblue')
avg_fea_3= np.mean(inacc_nt_strat_3.fea_mic)
plt.axhline(y=avg_fea_3, color='red', linestyle='--', label=f'Avg: {avg_fea_3:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
plt.plot(inacc_nt_strat_3.fea_net, linestyle='-', color='royalblue')
avg_fea_3= np.mean(inacc_nt_strat_3.fea_net)
plt.axhline(y=avg_fea_3, color='red', linestyle='--', label=f'Avg: {avg_fea_3:.4f}')
plt.title('Evolution of FEA values (MiC phase)', fontsize=10)
plt.xlabel('Records', fontsize=10)
plt.ylabel('FEA values', fontsize=10)
plt.ylim(0.0, 1.0)
plt.legend(loc= 'lower right')
plt.grid(True, alpha=0.3)
plt.tight_layout()

plt.show()

# %%
print(inacc_nt_strat_3.mic_acc)
print(inacc_nt_strat_3.model_acc)
inacc_nt_strat_3.deferred_decisions
# Out:
# 0.7405097613882863
# 0.7318329718004338
# 893

# %%
inacc_nt_mic.deferred_decisions /len(inacc_nt_mic_df)
# Out:
# 0.22023614299770417

# %%
inacc_nt_strat_3.deferred_decisions/len(inacc_nt_df_3)
# Out:
# 0.1464414562151525

# %%
inacc_nt_mic.stats
# Out:
# {False: {'user': {'tried': 664, 'got': 664, 'conf': 1},
#   'machine': {'tried': 2245, 'got': 1510, 'conf': 0}},
#  True: {'user': {'tried': 679, 'got': 679, 'conf': 1},
#   'machine': {'tried': 1443, 'got': 835, 'conf': 0}}}

# %%
inacc_nt_strat_3.stats
# Out:
# {False: {'user': {'tried': 511, 'got': 511, 'conf': 1},
#   'machine': {'tried': 2245, 'got': 1522, 'conf': 0}},
#  True: {'user': {'tried': 382, 'got': 382, 'conf': 1},
#   'machine': {'tried': 1443, 'got': 1273, 'conf': 0}}}
